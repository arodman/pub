# %%
### 000_top <a id="title_page"></a

### 000_packages <a id="title_page"></a

owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image


parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
    
    

    

country_database = "ANZ"

### 001_nz cpi  yy 

horizon_tb_nz_001_001_m = 24
#Loading tickers

horizon_1 = 24
country_database = "ANZ"
nzi_m_tickers = ['nzspc', 'nzspclt', 'nzspcnt',
                 'nzspcf', 'nzspcb', 'nzspca',
                 'nzspch', 'nzspcg',
                 'nzspcm', 'nzspct',
                 'nzspcc', 'nzspcr','nzspce']
hv_tb_nz_001_001_m = Haver.data(nzi_m_tickers, country_database, dates=True)
print(hv_tb_nz_001_001_m)
for x in range(len(nzi_m_tickers)):
    print(x)
    variable = str(nzi_m_tickers[x])
    print(variable)
    hv_tb_nz_001_001_m[variable] = hv_tb_nz_001_001_m[variable].pct_change(4).multiply(100).round(3)
    print(hv_tb_nz_001_001_m[variable])

hv_tb_nz_001_001_m.rename(columns={"nzspc": "CPI All Groups Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspclt": "CPI Tradeables Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcnt": "CPI No Tradeables Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcf": "CPI Food Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcb": "CPI Alcoholic Beverages Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspca": "CPI Clothing & Footwear Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspch": "CPI Housing Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcg": "CPI Household Services Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcm": "CPI Health Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspct": "CPI Transport Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcc": "CPI Communication Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspcr": "CPI Recreation Y/Y SA"}, inplace=True)
hv_tb_nz_001_001_m.rename(columns={"nzspce": "CPI Education Y/Y SA"}, inplace=True)
#hv_tb_nz_001_001_m_g_001 = hv_tb_nz_001_001_m.copy()
#hv_tb_nz_001_001_m = hv_tb_nz_001_001_m.tail(horizon_tb)
#hv_tb_nz_001_001_m = hv_tb_nz_001_001_m.transpose()
#hv_tb_nz_001_001_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_nz_001_001_m)
#dashboard.to_clipboard()
#dashboard.to_clipboard()
#print(hv_tb_nz_001_001_m)
#dashboard.to_clipboard()
#path_display = r'\\rivagecapital.com\root\BHCM\Trading\TeamVS\Alan_data_sandbox\dashboard_eco\table_nz_001_001_m.csv'
#print(path_display)
#hv_tb_nz_001_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_nz_001_001_m)
#print("step2")

### 001_nz cpi  yy table 

hv_tb_nz_001_001_m_g = hv_tb_nz_001_001_m.copy()
hv_tb_nz_001_001_m_g_001 = hv_tb_nz_001_001_m.copy()

hv_tb_nz_001_001_m.index=hv_tb_nz_001_001_m.index.date
hv_tb_nz_001_001_m = hv_tb_nz_001_001_m.tail(horizon_tb)
hv_tb_nz_001_001_t1=hv_tb_nz_001_001_m.tail(horizon_tb)

hv_tb_nz_001_001_m_t = hv_tb_nz_001_001_m.transpose()
hv_tb_nz_001_001_m_t.index.names = ['Variable']

hv_tb_nz_001_001_t1_t = hv_tb_nz_001_001_t1.transpose()
hv_tb_nz_001_001_t1_t.index.names = ['Variable']
############################################################
######Table 1

#####here*******
title_table="nz_cpi_yy"
df =hv_tb_nz_001_001_t1.copy()
df_transposed = hv_tb_nz_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_nz_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_nz_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_nz_001_001_m_t_002.png')




### 001_nz cpi  yy graph 

title_r = "NZ CPI Y/Y SA"
y_label = "Index %"
x_label = title_r
list_c = ["CPI All Groups Y/Y SA",
          "CPI Tradeables Y/Y SA",
          "CPI No Tradeables Y/Y SA"]
df1 = hv_tb_nz_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI All Groups Y/Y SA"], color="darkgreen", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Tradeables Y/Y SA"], color="darkblue", linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI No Tradeables Y/Y SA"], color="darkred", linewidth=l1, linestyle='-', marker='>', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["PCE Core SA Y/Y"], color="black", linewidth=11, linestyle='-', marker='s', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["PCE Core SA Y/Y"], color="black", Linewidth= L1, Linestyle='-',marker='o', markersize=s2)
#plt.axhiine(0, color='black', Lw=1, Linestyle 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_nz_001_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2



title_r="NZ CPI Y/Y SA"
y_label="Index %"
x_label=title_r
list_c=["CPI All Groups Y/Y SA",
        "CPI Tradeables Y/Y SA",
        "CPI No Tradeables Y/Y SA"]

df1=hv_tb_nz_001_001_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CPI All Groups Y/Y SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind="line", ax=ax,y=["CPI Tradeables Y/Y SA"], color="darkblue", linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CPI No Tradeables Y/Y SA"], color="darkred", linewidth=l1, linestyle='-',
        marker='>', markersize=s2)
#pLt.axhline(0, color='black', Lw=1, Linestyle 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_001_001_m_g_001z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2







#hv_tb_nz_001_001_m.rename(columns={"nzspcf": "CPI Food Y/Y SA"}, inplace=True)
#hv_tb_nz_001_001_m.rename(columns={"nzspcb": "CPI Alcoholic Beverages Y/Y SA"}, inplace=True)
#hv_tb_nz_001_001_m.rename(columns={"nzspca": "CPI Clothing & Footwear Y/Y SA"}, inplace=True)

title_r="NZ CPI Y/Y SA"
y_label="Index %"
x_label=title_r
list_c=["CPI Food Y/Y SA",
        "CPI Clothing & Footwear Y/Y SA"]
df1=hv_tb_nz_001_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Food Y/Y SA"], color="darkgreen", linewidth=l1, linestyle="-", marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Clothing & Footwear Y/Y SA"], color="darkblue", linewidth=l1, linestyle='-', marker="D", markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["CPI No Tradeables Y/Y SA"], color="darkred", linewidth= L1, Linestyle='-',
##marker'>', markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["PCE Core SA Y/Y"], color="black", Linewidth= L1, Linestyle'-',                   marker='o', markersize=s2)
#plt.axhLine(0, color='black', Lw=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_001_001_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

import matplotlib.pyplot as plt
title_r="NZ CPI Y/Y SA"
y_label="Index %"
x_label=title_r
list_c=["CPI Food Y/Y SA",
        "CPI Clothing & Footwear Y/Y SA"]
df1=hv_tb_nz_001_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Food Y/Y SA"],
        color="darkgreen", linewidth=l1, linestyle="-", marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Clothing & Footwear Y/Y SA"], 
        color="darkblue", linewidth=l1, linestyle='-', marker="D", markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.savefig("hv_tb_nz_001_001_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2

# ... (more code for renaming columns)

title_r = "NZ CPI Y/Y SA"
y_label = "Index %"
list_c = ["CPI Housing Y/Y SA",
          "CPI Household Services Y/Y SA",
          "CPI Health Y/Y SA",]
df1 = hv_tb_nz_001_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Housing Y/Y SA"], color="darkgreen", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Household Services Y/Y SA"], color="darkblue", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Health Y/Y SA"], color="darkred", linewidth=l1, linestyle='-', marker='>', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_003.jpg", bbox_inches='tight')
plt.savefig("hv_tb_nz_001_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "NZ CPI Y/Y SA"
y_label = "Index %"
x_label = title_r
list_c = [
    "CPI Housing Y/Y SA",
    "CPI Household Services Y/Y SA",
    "CPI Health Y/Y SA"]
df1 = hv_tb_nz_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Housing Y/Y SA"], color="darkgreen", linewidth=11, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Household Services Y/Y SA"], color="darkblue", linewidth=11, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Health Y/Y SA"], color="darkred", linewidth=11, linestyle='-', marker='>', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_003z.jpg", bbox_inches='tight')
plt.savefig("hv_tb_nz_001_001_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

#hv_tb_nz_001_001_m.rename(columns={"nzspct": "CPI Transport Y/Y SA"}, inplace=True)
#hv_tb_nz_001_001_m.rename(columns={"nzspcc": "CPI Communication Y/Y SA"}, inplace=True)
#hv_tb_nz_001_001_m.rename(columns={"nzspcr": "CPI Recreation Y/Y SA"}, inplace=True)

title_r="NZ CPI Y/Y SA"
y_label="Index %"
x_label=title_r
list_c=["CPI Transport Y/Y SA",
        "CPI Communication Y/Y SA",
        "CPI Recreation Y/Y SA"]
df1=hv_tb_nz_001_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CPI Transport Y/Y SA"], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CPI Communication Y/Y SA"], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CPI Recreation Y/Y SA"], color="darkred", linewidth= l1, linestyle="-",
        marker='D', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c

title_r = "NZ CPI Y/Y SA"
y_label = "Index %"
x_label = title_r
list_c = [
    "CPI Transport Y/Y SA",
    "CPI Communication Y/Y SA",
    "CPI Recreation Y/Y SA"]
df1 = hv_tb_nz_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Transport Y/Y SA"], color="darkgreen", linewidth=l1, linestyle='-', marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Communication Y/Y SA"], color="darkblue", linewidth=l1, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Recreation Y/Y SA"], color="darkred", linewidth=l1, linestyle='-', marker='D', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_001_001_m_g_004z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_nz cpi mm 

nzi_m_tickers = ['nzspc', 'nzspclt', 'nzspcnt', 'nzspcf', 'nzspcb', 'nzspca', 
                 'nzspch', 'nzspcg', 'nzspcm', 'nzspct', 'nzspcc', 'nzspcr', 'nzspce']
hv_tb_nz_002_001_m = Haver.data(nzi_m_tickers, country_database, dates=True)
#print(hv_tb_nz_002_001_m)
for x in range(len(nzi_m_tickers)):
    print(x)
    variable = str(nzi_m_tickers[x])
    hv_tb_nz_002_001_m[variable] = hv_tb_nz_002_001_m[variable].pct_change(periods=1, fill_method='bfill').multiply(100).round(3)
    print(hv_tb_nz_002_001_m[variable])
hv_tb_nz_002_001_m.rename(columns={'nzspc': 'CPI All Groups Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspclt': 'CPI Tradeables Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcnt': 'CPI No Tradeables Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcf': 'CPI Food Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcb': 'CPI Alcoholic Beverages Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspca': 'CPI Clothing & Footwear Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspch': 'CPI Housing Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcg': 'CPI Household Services Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcm': 'CPI Health Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspct': 'CPI Transport Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcc': 'CPI Communication Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspcr': 'CPI Recreation Q/Q SA'}, inplace=True)
hv_tb_nz_002_001_m.rename(columns={'nzspce': 'CPI Education Q/Q SA'}, inplace=True)
#hv_tb_nz_002_001_m_g_001 = hv_tb_nz_002_001_m.copy()
#hv_tb_nz_002_001_m = hv_tb_nz_002_001_m.tail(horizon_tb)
#hv_tb_nz_002_001_m = hv_tb_nz_002_001_m.transpose()
#hv_tb_nz_002_001_m.index.names = ['Variable']
## dashboard.to_clipboard()
#print(hv_tb_nz_001_001_m)
## dashboard.to_clipboard()
#path_display =ashboard_eco\table_nz_002_001_m.csv'
#print(path_display)

### 001_nz cpi mm table

hv_tb_nz_002_001_m_g = hv_tb_nz_002_001_m.copy()
hv_tb_nz_002_001_m_g_001 = hv_tb_nz_002_001_m.copy()

hv_tb_nz_002_001_m.index=hv_tb_nz_002_001_m.index.date
hv_tb_nz_002_001_m = hv_tb_nz_002_001_m.tail(horizon_tb)
hv_tb_nz_002_001_t1=hv_tb_nz_002_001_m.tail(horizon_tb)

hv_tb_nz_002_001_m_t = hv_tb_nz_002_001_m.transpose()
hv_tb_nz_002_001_m_t.index.names = ['Variable']

hv_tb_nz_002_001_t1_t = hv_tb_nz_002_001_t1.transpose()
hv_tb_nz_002_001_t1_t.index.names = ['Variable']
############################################################
######Table 1

#####here*******
title_table="nz_cpi_qq"
df =hv_tb_nz_002_001_t1.copy()
df_transposed = hv_tb_nz_002_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_nz_002_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_nz_002_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_nz_002_001_m_t_002.png')






### 001_nz phillips curve <a id="title_page"></a

print("Philips Curve")
### cORE PCE VS UNEMPLTOEMTN
nzi_m_tickers = ['nznpcxq','nzselur']
hv_tb_nz_003_001_m = Haver.data(nzi_m_tickers, "ANZ", dates=True)
#hv_tb_us_002_006_m.index = hv_tb_us_002_006_m.index.floor('D')

nzi_m_tickers = ['nznpcxq']
for x in range(len(nzi_m_tickers)):
    variable = str(nzi_m_tickers[x])
    hv_tb_nz_003_001_m[variable] = hv_tb_nz_003_001_m[variable].pct_change(periods=4,
                                                                           fill_method='bfill').multiply(100).round(3)
    
hv_tb_nz_003_001_m.rename(columns={'nznpcxq': 'NZ CPI Core yy nsa Q'}, inplace=True)
hv_tb_nz_003_001_m.rename(columns={'nzselur': 'NZ Unemployment Rate Q'}, inplace=True)
hv_tb_nz_003_001_m['year'] = hv_tb_nz_003_001_m.index.year
hv_tb_nz_003_001_m = hv_tb_nz_003_001_m.tail(60)

list_pc=hv_tb_nz_003_001_m.columns.tolist()
print(hv_tb_nz_003_001_m.tail(5))
x = hv_tb_nz_003_001_m[list_pc[1]]
y = hv_tb_nz_003_001_m[list_pc[0]]
t = hv_tb_nz_003_001_m['year']
y_label = list_pc[0]
x_label = list_pc[1]
print(len(x))
print(len(y))


title_r="PHILLIPS CURVE CORE VS UNEMPLOYMENT"
df1=hv_tb_nz_003_001_m.copy()
df1.index= df1.index.date

#df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1[list_pc[1]],
            g1[list_pc[0]], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1[list_pc[1]],
         g1[list_pc[0]], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1[list_pc[1]].iloc[line], 
         g1[list_pc[0]].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_003_001_m_g_001.jpg", bbox_inches='tight')
plt.savefig("hv_tb_nz_003_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#hv_tb_nz_001_001_m_g_004z



### 001_nz heatmap <a id="title_page"></a

from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
country_database = "ANZ"
horizon_00=120

print("monthly")
aui_m_tickers1 = [ 'nzsrmcc','nzsrmfc','nzspcigc','nzspcifc',
                  'nzsetj2', 'nzsetj3', 'nzsee2', 'nzsee3', 'nznjmc', 
                  'nzntrsy', 'nzsrmidx', 'nznfch', 'nzspf','nzsgviy']
hv_tb_au_000_001_m=Haver.data(aui_m_tickers1, "ANZ", dates=True)
#print(hv_tb_au_000_001_m)
#ausww annual
print("quarterly")

aui_m_tickers2 = ['nzqngdt', 'nznphd', 'nznvec2y', 'nzspc', 'nzspclt', 'nzspcnt',
                  'nznpcwp', 'nznpl',
                  'nzsngdt', 'nzsncct', 'nzsngct',
                  'nzsnfbt', 'nzselpr', 'nzselt', 'nzselur', 'nzsdx']
hv_tb_au_000_002_m=Haver.data(aui_m_tickers2, "ANZ", dates=True)
#print(hv_tb_au_000_002_m)
hv_tb_au_000_001_m=pd.concat([hv_tb_au_000_001_m, hv_tb_au_000_002_m], axis=1, join="outer")
au_m_tickers=aui_m_tickers1+aui_m_tickers2
hv_tb_au_000_001_m= hv_tb_au_000_001_m.fillna (method='bfill')

#KeyError: "["Real: NZ Retail Sales', 'Price: NZ Expected annual inflation 2y',
#'Employment: NZ Job vacancies yy'] not in index
hv_tb_au_000_001_m["nzspf"] = hv_tb_au_000_001_m["nzspf"].pct_change (periods=12,
                                                                      fill_method="bfill").multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"nzspf":"Price: NZ CPI Food Inflation Monthly SA"}, inplace=True)
hv_tb_au_000_001_m["nzspc"]= hv_tb_au_000_001_m["nzspc"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"nzspc": "Price: NZ CPI Headline SA"}, inplace=True)                     
hv_tb_au_000_001_m["nzspclt"]= hv_tb_au_000_001_m["nzspclt"].pct_change (periods=12, fill_method='bfill').multiply (100).round(1)                          
hv_tb_au_000_001_m.rename(columns={"nzspclt": "Price: NZ CPI tradeables SA"}, inplace=True)
hv_tb_au_000_001_m["nzspcnt"] = hv_tb_au_000_001_m["nzspcnt"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"nzspcnt": "Price: NZ CPI non tradeables SA"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"nznpcwp": "Price: NZ CPI Weighted Median QQ NSA"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"nznpctp": "Price: NZ CPI Trimmed Mean All Groups NSA"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"nznvec2y":"Price: NZ Expected annual inflation 2y"}, inplace=True)
hv_tb_au_000_001_m["nznp1"] = hv_tb_au_000_001_m["nznpl"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"nznpl": "Price: Household Living Cost price Index YY NSA"}, inplace=True)
hv_tb_au_000_001_m["nzsrmidx"] = hv_tb_au_000_001_m["nzsrmidx"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzsrmidx": "Cycle: ANZ Consumer Confidence"}, inplace=True)
hv_tb_au_000_001_m["nzsrmcc"] = hv_tb_au_000_001_m["nzsrmcc"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzsrmcc": "Cycle: ANZ Consumer Confidence Current Condition"}, inplace=True)
hv_tb_au_000_001_m["nzsrmfc"] = hv_tb_au_000_001_m["nzsrmfc"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzsrmfc": "Cycle: ANZ Consumer Confidence Future Condition"}, inplace=True)
hv_tb_au_000_001_m["nzspcigc"] = hv_tb_au_000_001_m["nzspcigc"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzspcigc": "Cycle: Combined PMI PSI Gdp w"}, inplace=True)
hv_tb_au_000_001_m["nzspcifc"] = hv_tb_au_000_001_m["nzspcifc"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzspcifc": "Cycle: Combined PMI PSI Free w"}, inplace=True)

hv_tb_au_000_001_m["nzsdx"] = hv_tb_au_000_001_m["nzsdx"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzsdx": "Real: NZ Industrial Production excluding Construction"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"nzntrsy": "Real: NZ Retail Sales"}, inplace=True)
hv_tb_au_000_001_m["nznphd"] = hv_tb_au_000_001_m["nznphd"].pct_change(periods=12, fill_method="bfill").multiply(100).round(0)
hv_tb_au_000_001_m.rename(columns={"nznphd": "Real: NZ CoreLogic House price"}, inplace=True)

hv_tb_au_000_001_m["nzqngdt"] = hv_tb_au_000_001_m["nzqngdt"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzqngdt": "Real: GDP YY"}, inplace=True)
hv_tb_au_000_001_m["nzsngdt"] = hv_tb_au_000_001_m["nzsngdt"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzsngdt": "Real: GDP QQ"}, inplace=True)
hv_tb_au_000_001_m["nzsncct"] = hv_tb_au_000_001_m["nzsncct"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzsncct": "Real: GDP Private Consumption QQ"}, inplace=True)
hv_tb_au_000_001_m["nzsnfbt"] = hv_tb_au_000_001_m["nzsnfbt"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzsnfbt": "Real: GDP Capital Formation QQ"}, inplace=True)
hv_tb_au_000_001_m["nzsngct"] = hv_tb_au_000_001_m["nzsngct"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzsngct": "Real: GDP Government QQ"}, inplace=True)

hv_tb_au_000_001_m["nznfch"] = hv_tb_au_000_001_m["nznfch"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"nznfch": "Real: NZ Household Debt yy"}, inplace=True)
hv_tb_au_000_001_m["nzsgviy"] = hv_tb_au_000_001_m["nzsgviy"].round(1)
hv_tb_au_000_001_m.rename(columns={"nzsgviy": "Real: NZ Activity Index NAZC"}, inplace=True)
hv_tb_au_000_001_m["nznjmc"] = hv_tb_au_000_001_m["nznjmc"].round(0)
hv_tb_au_000_001_m.rename(columns={"nznjmc": "Employment: NZ Job vacancies Index monthly yy"}, inplace=True)
hv_tb_au_000_001_m["nzselpr"] = hv_tb_au_000_001_m["nzselpr"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzselpr": "Employment: Labor force participation sa"}, inplace=True)
hv_tb_au_000_001_m["nzselt"] = hv_tb_au_000_001_m["nzselt"].round(0)
hv_tb_au_000_001_m.rename(columns={"nzselt": "Employment: employment rate sa"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"nzselur": "Employment: unemployment rate sa"}, inplace=True)
# nad unemples rm,
hv_tb_au_000_001_m["nzsetj2"] = hv_tb_au_000_001_m["nzsetj2"].pct_change(periods=12, fill_method='bfill').multiply(100).round(0)
hv_tb_au_000_001_m.rename(columns={"nzsetj2": "Employment: MEI Filled Goods Jobs Monthly yy"}, inplace=True)
hv_tb_au_000_001_m["nzsetj3"] = hv_tb_au_000_001_m["nzsetj3"].pct_change(periods=12, fill_method='bfill').multiply(100).round(0)
hv_tb_au_000_001_m.rename(columns={"nzsetj3": "Employment: MEI Filled Services Jobs Monthly yy"}, inplace=True)
hv_tb_au_000_001_m["nzsee2"] = hv_tb_au_000_001_m["nzsee2"].pct_change(periods=12, fill_method='bfill').multiply(100).round(0)
hv_tb_au_000_001_m.rename(columns={"nzsee2": "Employment: MEI Earnings Goods Jobs Monthly yy"}, inplace=True)
hv_tb_au_000_001_m["nzsee3"] = hv_tb_au_000_001_m["nzsee3"].pct_change(periods=12, fill_method='bfill').multiply(100).round(0)
hv_tb_au_000_001_m.rename(columns={"nzsee3": "Employment: MEI Earnings Services Jobs Monthly yy"}, inplace=True)
##monthly infaiton
#KeyError: "['Real: NZ CoreLogic House price', 
#'Price: NZ CPI tradeables SA',
#'Price: NZ CPI non tradeables SA', 
#'Price: NZ Expected annual inflation 2y',
#'Employment: NZ Job vacancies yy'] not in index"
###rba comm price.
###ip clec cosntrucitons, ip mnings, ip manfactirun,
#KeyError: "['Real: NZ CoreLogic House price', 'Price: NZ Expected annual inflation 2y', 'Employment: NZ Job vacancies yy']
## retial sales values, tinrovers,
hv_tb_au_000_001_m.index=hv_tb_au_000_001_m.index.date

list_c=["Real: GDP YY", "Real: GDP QQ",  
        "Real: GDP Private Consumption QQ",
        "Real: GDP Capital Formation QQ",
        "Real: GDP Government QQ",
        "Real: NZ Industrial Production excluding Construction",
        "Real: NZ Retail Sales",
        "Real: NZ CoreLogic House price",
        "Real: NZ Household Debt yy",
        "Real: NZ Activity Index NAZC",
         "Price: NZ CPI Headline SA",
         "Price: NZ CPI tradeables SA",
         "Price: NZ CPI non tradeables SA",
         "Price: NZ CPI Weighted Median QQ NSA",
         "Price: NZ CPI Food Inflation Monthly SA",
         "Price: Household Living Cost price Index YY NSA",
#         "Price: NZ Expected annual inflation 2y",
#         "Employment: NZ Job vacancies yy",
         "Employment: NZ Job vacancies Index monthly yy",
         "Employment: Labor force participation sa",
         "Employment: employment rate sa",
         "Employment: unemployment rate sa",
         "Employment: MEI Filled Goods Jobs Monthly yy",
         "Employment: MEI Filled Services Jobs Monthly yy",
         "Employment: MEI Earnings Goods Jobs Monthly yy",
         "Employment: MEI Earnings Services Jobs Monthly yy",
         "Cycle: ANZ Consumer Confidence",
         "Cycle: ANZ Consumer Confidence Current Condition",
         "Cycle: ANZ Consumer Confidence Future Condition",
         "Cycle: Combined PMI PSI Gdp w",
         "Cycle: Combined PMI PSI Free w",]
hv_tb_au_000_001_m=hv_tb_au_000_001_m[list_c]
hv_tb_au_000_001_m_c=hv_tb_au_000_001_m.copy()
hv_tb_au_000_001_m_c=hv_tb_au_000_001_m_c.tail(120)
hv_tb_au_000_001_m=hv_tb_au_000_001_m.tail(60)

n_time=42
size1=28


size2=size1/1
font_size_h=15
number_vbs=29
x_sizel=16
x2_sizel=x_sizel-4
xlabel_size=20
title_s=25
df1=hv_tb_au_000_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows= df1.shape[0]
for x in range(num_rows):
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals() [str(str("vmin_")+str(x))] = hv_tb_au_000_001_m_c.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = hv_tb_au_000_001_m_c.iloc[:,x].max()
    
    #print("end Loop")

print(vmin_0)
print(vmax_0)
#data= np.random.random((10,12))
#df=pd.DataFrame (data)
red_to_blue= sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue =sns.color_palette("coolwarm")
reversed_red_to_blue=list(reversed (reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)





fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g', 
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g', 
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g', 
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g', 
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g', 
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n = 0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n = (n + 1)

# axes[0].set_xticks([])
# axes[1].set_xticks([])
# axes[1].set_xticks([])

axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])
#set_xticklabels(axis="x", which="both", length=0, labelrotation=45)
fig.suptitle("New Zealand Economic Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "New Zealand Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('newzealand_heatmap_001.jpg', bbox_inches='tight', dpi=200)
plt.savefig('newzealand_heatmap_001.png', bbox_inches='tight', dpi=200)
plt.show()
plt.close()


# RBNZ forecasts
# RBNZ forecasts
# RBNZ forecasts
# RBNZ forecasts
# RBNZ forecasts

### 001_nz RBNZ forecasts <a id="title_page"></a



country_database = "ANZ"
uki_m_tickers1 = ['nzgp','nzpc','nzpcy','nztw','nzrc',
                 'nzgpp','nzpcp','nzpcyp','nztwp','nzrcp']
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)

table_F=hv_tb_uk_000_001_m.copy()
table_F.rename(columns={"nzgp": "RBNZ-F: Real GDP QQ SA"}, inplace=True)
table_F.rename(columns={"nzpc": "RBNZ-F: CPI QQ NSA"}, inplace=True)
table_F.rename(columns={"nzpcy": "RBNZ-F: CPI YY NSA"}, inplace=True)
table_F.rename(columns={"nztw": "RBNZ-F: FX TWI NSA"}, inplace=True)
table_F.rename(columns={"nzrc": "RBNZ-F: official cash rate"}, inplace=True)

table_F.rename(columns={"nzgpp": "RBNZ-F: Real GDP QQ SA Previous"}, inplace=True)
table_F.rename(columns={"nzpcp": "RBNZ-F: CPI QQ NSA Previous"}, inplace=True)
table_F.rename(columns={"nzpcyp": "RBNZ-F: CPI YY NSA Previous"}, inplace=True)
table_F.rename(columns={"nztwp": "RBNZ-F: FX TWI NSA Previous"}, inplace=True)
table_F.rename(columns={"nzrcp": "RBNZ-F: official cash rate Previous"}, inplace=True)



df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[380, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=600,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_nz_forecast_001.png')


### 001_nz RBNZ forecasts <a id="title_page"></a

country_database = "ANZ"
uki_m_tickers1 = ['nzrc', 'nzpc','nzpcy',
                 'nzrcp' ,'nzpcp','nzpcyp',]
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)

table_F=hv_tb_uk_000_001_m.copy()
table_F.rename(columns={"nzpc": "RBNZ-F: CPI QQ NSA"}, inplace=True)
table_F.rename(columns={"nzpcy": "RBNZ-F: CPI YY NSA"}, inplace=True)
table_F.rename(columns={"nzrc": "RBNZ-F: official cash rate"}, inplace=True)
table_F.rename(columns={"nzpcp": "RBNZ-F: CPI QQ NSA Previous"}, inplace=True)
table_F.rename(columns={"nzpcyp": "RBNZ-F: CPI YY NSA Previous"}, inplace=True)
table_F.rename(columns={"nzrcp": "RBNZ-F: official cash rate Previous"}, inplace=True)



df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[380, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=600,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_nz_forecast_002.png')

country_database = "ANZ"
uki_m_tickers1 = ['nzrc','nzgp',
                 'nzrcp','nzgpp']
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)

table_F=hv_tb_uk_000_001_m.copy()
table_F.rename(columns={"nzgp": "RBNZ-F: Real GDP QQ SA"}, inplace=True)
table_F.rename(columns={"nzrc": "RBNZ-F: official cash rate"}, inplace=True)

table_F.rename(columns={"nzgpp": "RBNZ-F: Real GDP QQ SA Previous"}, inplace=True)
table_F.rename(columns={"nzrcp": "RBNZ-F: official cash rate Previous"}, inplace=True)

df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[380, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=600,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_nz_forecast_003.png')










### 001_nz RBNZ forecasts ocr path <a id="title_page"></a


#Monthly CPI headlines
#Components of ONTLHY CPI
#MONTOSN ON MOENTS ANNUALEIS
#mLBEOEUNRNGY cPu
#rba com cprices
#unemployment
#particiaptins rates
#WAGES
#COMPOENSATION
#GDP
#gdp PER HORUS WORERD
#hh soending s
#industrial rpodcutions
#ip mining
#ip manuacturing
#RETAIL SAELS
#westpac ocnusmuer sneitnesn
#ANZ
#ROY MORGAN



nzi_m_tickers1 = ["nzrc", "nzrcp", "nzrc242", "nzrc241",
                  "nzrc234", "nzrc233", "nzrc232", "nzrc231",
                  "nzrc224", "nzrc223", "nzrc222", "nzrc221",
                  "nzrc214", "nzrc213", "nzrc212", "nzrc211",
                  "nzrc204", "nzrc203", "nzrc202", "nzrc201",
                  "nzrc194", "nzrc193", "nzrc192", "nzrc191",
                  "nzrc184", "nzrc183", "nzrc182", "nzrc181",
                  "nzrc174", "nzrc173", "nzrc172", "nzrc171"]

hv_tb_nz_000_001_m=Haver.data(nzi_m_tickers1, "ANZ", dates=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc": "ocr path current"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrcp": "ocr path previous"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc242": "ocr path 2024-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc241": "ocr path 2024-1"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc234": "ocr path 2023-4"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc233": "ocr path 2023-3"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc232": "ocr path 2023-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc231": "ocr path 2023-1"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc224": "ocr path 2022-4"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc223": "ocr path 2022-3"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc222": "ocr path 2022-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc221": "ocr path 2022-1"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc214": "ocr path 2021-4"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc213": "ocr path 2021-3"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc212": "ocr path 2021-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc211": "ocr path 2021-1"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc204": "ocr path 2020-4"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc203": "ocr path 2020-3"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc202": "ocr path 2020-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc201": "ocr path 2020-1"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc194": "ocr path 2019-4"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc193": "ocr path 2019-3"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc192": "ocr path 2019-2"}, inplace=True)
hv_tb_nz_000_001_m.rename(columns={"nzrc191": "ocr path 2019-1"}, inplace=True)

title_r="NZ OCR path"
title=title_r
y_label="Index %"
x_label=title_r
df1=hv_tb_nz_000_001_m.copy()
#df1=df1.tail(12)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))

# Plot each series with custom colors for the first two lines, then black for the rest
for i, column in enumerate(g1.columns):
    if i == 0:
        color = "orange"  # First line
    elif i == 1:
        color = "green"   # Second line
    else:
        color = "black"   # Rest of the lines
    ax.plot(g1.index, g1[column], color=color, linewidth=l1, linestyle='-')

# Add horizontal reference lines
for y in range(-1, 5):  # Dashed lines at -1, 0, 1, 2, 3, 4
    ax.axhline(y, color='black', lw=1, linestyle='dashed', alpha=0.5)

# Add labels, title, and grid
ax.set_ylabel(y_label, fontsize=12)
ax.set_xlabel(x_label, fontsize=12)
ax.set_title(title, fontsize=14)
ax.tick_params(labelsize=10)
ax.grid(axis='both', alpha=0.3)
plt.axhline(0, color='black', lw=1, linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_004_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_004_001_m_g_001.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del fig
del ax
del ax2

title_r="NZ OCR path"
title=title_r
y_label="Index %"
x_label=title_r
df1=hv_tb_nz_000_001_m.copy()
df1=df1.tail(60)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))

# Plot each series with custom colors for the first two lines, then black for the rest
for i, column in enumerate(g1.columns):
    if i == 0:
        color = "orange"  # First line
    elif i == 1:
        color = "green"   # Second line
    else:
        color = "black"   # Rest of the lines
    ax.plot(g1.index, g1[column], color=color, linewidth=l1, linestyle='-')

# Add horizontal reference lines
for y in range(-1, 5):  # Dashed lines at -1, 0, 1, 2, 3, 4
    ax.axhline(y, color='black', lw=1, linestyle='dashed', alpha=0.5)

# Add labels, title, and grid
ax.set_ylabel(y_label, fontsize=12)
ax.set_xlabel(x_label, fontsize=12)
ax.set_title(title, fontsize=14)
ax.tick_params(labelsize=10)
ax.grid(axis='both', alpha=0.3)
plt.axhline(0, color='black', lw=1, linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_004_001_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_004_001_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del fig
del ax
del ax2

title_r="NZ OCR path"
title=title_r
y_label="Index %"
x_label=title_r
df1=hv_tb_nz_000_001_m.copy()
df1=df1.tail(36)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))

# Plot each series with custom colors for the first two lines, then black for the rest
for i, column in enumerate(g1.columns):
    if i == 0:
        color = "orange"  # First line
    elif i == 1:
        color = "green"   # Second line
    else:
        color = "black"   # Rest of the lines
    ax.plot(g1.index, g1[column], color=color, linewidth=l1, linestyle='-')

# Add horizontal reference lines
for y in range(-1, 5):  # Dashed lines at -1, 0, 1, 2, 3, 4
    ax.axhline(y, color='black', lw=1, linestyle='dashed', alpha=0.5)

# Add labels, title, and grid
ax.set_ylabel(y_label, fontsize=12)
ax.set_xlabel(x_label, fontsize=12)
ax.set_title(title, fontsize=14)
ax.tick_params(labelsize=10)
ax.grid(axis='both', alpha=0.3)
plt.axhline(0, color='black', lw=1, linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_004_001_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_004_001_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del fig
del ax
del ax2

title_r="NZ OCR path"
title=title_r
y_label="Index %"
x_label=title_r
df1=hv_tb_nz_000_001_m.copy()
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))

# Plot each series with custom colors for the first two lines, then black for the rest
for i, column in enumerate(g1.columns):
    if i == 0:
        color = "orange"  # First line
    elif i == 1:
        color = "green"   # Second line
    else:
        color = "black"   # Rest of the lines
    ax.plot(g1.index, g1[column], color=color, linewidth=l1, linestyle='-')

# Add horizontal reference lines
for y in range(-1, 5):  # Dashed lines at -1, 0, 1, 2, 3, 4
    ax.axhline(y, color='black', lw=1, linestyle='dashed', alpha=0.5)

# Add labels, title, and grid
ax.set_ylabel(y_label, fontsize=12)
ax.set_xlabel(x_label, fontsize=12)
ax.set_title(title, fontsize=14)
ax.tick_params(labelsize=10)
ax.grid(axis='both', alpha=0.3)
plt.axhline(0, color='black', lw=1, linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_nz_004_001_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_nz_004_001_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del fig
del ax
del ax2



### cleaning  

import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
