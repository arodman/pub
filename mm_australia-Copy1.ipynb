# %%
### 001_  TOP   <a id="title_page"></a

### 001_  PACKAGES    <a id="title_page"></a

owner="[]"
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from PIL import Image

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)

### 001_  TABLE    <a id="title_page"></a

#AUSTRALIA
#Australia

#paye data
country_database = "ANZ"
horizon_00=120
aui_m_tickers1 = ['austrs', 'auwpc', 'aunigi', 'aunigic',
                  'ausvcc', 'ausvcp', 'aunvrmc', 'aunvrm','aunelat']
hv_tb_au_000_001_m=Haver.data(aui_m_tickers1, "ANZ", dates=True)
print(hv_tb_au_000_001_m)
#ausww annual
aui_m_tickers2 = ['ausngdpc', 'ausdgv', 'auwncpi',
                  'aunpc', 'auspctr', 'auswpiv', 'auswpig', 
                  'ausncdgv', 'ausahw', 'ausgahwm', 'aunhjn', ]
hv_tb_au_000_002_m=Haver.data(aui_m_tickers2, "ANZ", dates=True)
#print(hv_tb_au_000_002_m)
hv_tb_au_000_001_m=pd.concat([hv_tb_au_000_001_m, hv_tb_au_000_002_m], axis=1, join="outer")
au_m_tickers=aui_m_tickers1+aui_m_tickers2
#print(hv_tb_au_000_001_m)
#hv_tb_au_000_001_m.rename(columns={"aunpcy": "Price: CPI ALL Groups NSA Y/Y"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"auspctry":"Price: CPI Trimmed YY NSA"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausngdpc": "Real: GDP"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"austrs": "Real: Retail Turnover"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausdgv":"Real: IP"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausahw": "Real: Hours Worked"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausgahwm": "Real: Value Added per Hour"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auwncpi": "Real: Household Spending"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpc": "Price: CPI All Groups"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auspctr": "Price: CPI Trimmed"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auwpc":"Price: CPI Monthly Headline"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunigi": "Price: MI Monthly Headline"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aunpcy": "Price: CPI All Groups NSA Y/Y"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"auspctry": "Price: CPI Trimmed YY NSA"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausngdpc":"Real: GDP"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"austrs": "Real: Retail Turnover"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausdgv": "Real: IP"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausahw": "Real: Hours Worked"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausgahwm": "Real: Value Added per Hour"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auwncpi": "Real: Household Spending"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpc": "Price: CPI All Groups"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auspctr": "Price: CPI Trimmed"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auwpc": "Price: CPI Monthly Headline"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunigi": "Price: MI Monthly Headline"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunigic": "Price: MI Monthly Core"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunhjn": "Price: Mean Price Residential Dwelling"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausvcc":"Cycle: Westpac Consumer Sentiment"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausvcp": "Cycle: Westpac Consumer Expectations"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunvrmc": "Cycle: ANZ Monthly Consumer Confidence"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunvrm": "Cycle: RM Consumer Confidence"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auswpiv": "Employment: Wage Price Index private"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auswpig": "Employment: Wage Price Index public"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"ausww": "Employment: Avg Weekly Earnings"}, inplace=True)

hv_tb_au_000_001_m.rename(columns={"ausncdgv":"Employment: Compensation Employees"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunelat": "Employment: Participation Rate"}, inplace=True)
hv_tb_au_000_001_m=hv_tb_au_000_001_m.fillna(method='bfill')
hv_tb_au_000_001_m =hv_tb_au_000_001_m.fillna(method='ffill')
hv_tb_au_000_001_m.drop(hv_tb_au_000_001_m.tail(1).index, inplace =True)
#view alli data in elvels, see if trasnformation amkes sensFFIL FORWARD

hv_tb_au_000_001_m.sort_index(ascending=False, axis=1, inplace=True)
#hv_tb_au_000_001_m.to_clipboard()
#CPI HEADLINE
#COMPNESAITON EMPLOYEES
#REAL PAETAIL SLEAS
#rEAL Industrila PRODUCITON
#GRELA GDP EPR HOUR WORKERD
#I HEADLINE
#CPI Trimmed maine
#ontly
#Melbourne
#Inflaiton expectaitons
#House PPRICE
#Employment mlabour force
#CPI HEADLINE
#COMPNESAITON EMPLOYEES
#REAL PAETAIL SLEAS
#rEAL Industrila PRODUCITON
#GRELA GDP EPR HOUR WORKERD
#I HEADLINE
#CPI Trimmed maine
#ontly
#Melbourne
#Inflaiton expectaitons
#House PPRICE
#Employment mlabour force
#Emplyment Earninsg s
#Partiticaocpiont Rate
#COMPNESAITON EMPLOYEES
#Cycle Westapce
#Cycle ANZ CONSUMER CONFIDEN CE
#CYCLE pi
#cucle
#REAL PAETAIL SLEAS
#rEAL Industrila PRODUCITON
#GRELA GDP EPR HOUR WORKERD

aui_m_tickers=hv_tb_au_000_001_m.columns
for x in range(len(aui_m_tickers)):
    variable=str(aui_m_tickers[x])
    print(hv_tb_au_000_001_m[variable])
    hv_tb_au_000_001_m[ (str(variable)+str("_yy"))] = hv_tb_au_000_001_m[variable].pct_change(periods=12, 
                                                                                              fill_method='bfill').multiply(100).round(3)
    hv_tb_au_000_001_m[ (str(variable)+str("_qq"))] = hv_tb_au_000_001_m[variable].pct_change(periods=4, 
                                                                                              fill_method='bfill').multiply(100).round(3)
    hv_tb_au_000_001_m[ (str(variable)+str("_mm"))] = hv_tb_au_000_001_m[variable].pct_change(periods=1, 
                                                                                              fill_method='bfill').multiply(100).round(3)

window_z10=[12,24,36,60,100]
window_zl=window_z10

aui_m_tickers=hv_tb_au_000_001_m.columns
for x in range(len(aui_m_tickers)):
    variable=str(aui_m_tickers[x])
    for y in range(len(window_zl)):
        window_z=(window_zl[y])
        hv_tb_au_000_001_m[ (str(variable)+str("_zscore")+str(window_z))]=(zscore (hv_tb_au_000_001_m[variable], 
                                                                                   window_z)).round(2)
        hv_tb_au_000_001_m[ (str(variable)+str("_zavg")+str(window_z))]=(zscore_avg(hv_tb_au_000_001_m[variable], 
                                                                                    window_z)).round(2)

window_z1 = window_z10
# window_zl = [12]

for x in range(len(window_zl)):
    window_z = (window_z1[x])
    window_z_1 = str("zscore" + str(window_z))
    print(window_z)
    aui_m_tickers = [
        "Real: GDP_yy_zscore" + str(window_z),
        "Real: Retail Turnover_yy_zscore" + str(window_z),
        "Real: IP_yy_zscore" + str(window_z),
        "Real: Hours Worked_yy_zscore" + str(window_z),
        "Real: Value Added per Hour_yy_zscore" + str(window_z),
        "Real: Household Spending_yy_zscore" + str(window_z),
        "Employment: Wage Price Index private_yy_zscore" + str(window_z),
        "Employment: Wage Price Index public_yy_zscore" + str(window_z),
        "Employment: Compensation Employees_yy_zscore" + str(window_z),
        "Employment: Participation Rate_yy_zscore" + str(window_z),
        "Price: CPI All Groups_yy_zscore" + str(window_z),
        "Price: CPI Trimmed_yy_zscore" + str(window_z),
        "Price: CPI Monthly Headline_yy_zscore" + str(window_z),
        "Price: MI Monthly Headline_yy_zscore" + str(window_z),
        "Price: MI Monthly Core_yy_zscore" + str(window_z),
        "Price: MI Monthly Core_yy_zscore" + str(window_z),
        "Price: Mean Price Residential Dwelling_yy_zscore" + str(window_z),
        "Cycle: Westpac Consumer Sentiment_zscore" + str(window_z),
        "Cycle: Westpac Consumer Expectations_zscore" + str(window_z),
        "Cycle: ANZ Monthly Consumer Confidence_zscore" + str(window_z),
        "Cycle: RM Consumer Confidence_zscore" + str(window_z)
    ]

    print("tickers updated")
    print(aui_m_tickers)
    hv_tb_au_000_002_m = hv_tb_au_000_001_m[aui_m_tickers]
    hv_tb_au_000_002_m.sort_index(ascending=False, axis=1, inplace=True)
    hv_tb_au_000_002_m = hv_tb_au_000_002_m.tail(24)
    hv_tb_au_000_002_m = hv_tb_au_000_002_m.transpose()

    hv_tb_au_000_002_m.index.names = ['Variable']
    #path_display = 'table_au_000_002z'
    #path_display = str(path_display) + str(window_z) + ".csv"
    #print(path_display)
    print(hv_tb_au_000_002_m)

    #####STACKED BARCHART
    #####STACKED BARCHART
    hv_tb_au_000_003_m=hv_tb_au_000_001_m[aui_m_tickers]
    div=len(aui_m_tickers)
    div=div+0
    print(div)
    
    hv_tb_au_000_003_m= (hv_tb_au_000_003_m/div)
    hv_tb_au_000_003_m=hv_tb_au_000_003_m.tail(120)
    print(hv_tb_au_000_003_m)
    
    ########## bar chart
    ########## bar chart
    df1=hv_tb_au_000_003_m.copy()
    h1=df1.copy()
    fig,ax =plt.subplots (figsize=(parameter3_s, parameter4_s))
    #ax= df.plot(kind='bar', stacked=True, figsize=(10, 6))
    colors =["orange", "orange", "orange", "orange", "orange", "orange",
    "blue", "blue", "blue", "blue",
    "green", "green", "green", "green", "green", "green", "green",
    "yellow", "yellow", "yellow", "yellow"]
    h1.plot(kind='bar', stacked=True, ax=ax, color=colors,)
    title_r=str('AU_MacroMomentum_z'+str(window_z))
    plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
    plt.style.use('default')
    plt.title(str(title_r), size=parameter5)
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(title_r), size=parameter3)
    plt.legend(title='labels', bbox_to_anchor=(1.0, 1), loc='upper left')
    plt.grid(axis="both", alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    
    #Loc = piticker.MultipleLocator (base=4) # this locator puts ticks at regular intervals
    #ax.xaxis.set_major_Locator(Loc)
    #Loc = plt.MultipleLocator(base=4) # this locator puts ticks at regular intervals
    #ax.xaxis.set_major_locator(Loc)
    #date_form = DateFormatter("%m-%Y")
    #ax.xaxis.set_major_formatter(date_form)
    #ax.xaxis.set_major_locator(mdates.YearLocator())
    #half_year_locator = mdates.MonthLocator(interval=1)
    #ax.xaxis.set_major_locator(half_year_locator)
    #ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.savefig(str('AU_MacroMomentum_bar_z'+str(window_z)+".png"), bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del h1    
    del df1
    del fig    
    del ax
    del ax2



    
    ########timeseries
    hv_tb_au_000_003_m[str('AU_MacroMomentum_z'+str(window_z))] = hv_tb_au_000_003_m[aui_m_tickers].mean(axis=1)
    hv_tb_au_000_004_m=hv_tb_au_000_003_m[str('AU_MacroMomentum_z'+str(window_z))]    
    df1=hv_tb_au_000_004_m.copy()
    g1=df1.copy()    
    title_r=str('AU_MacroMomentum_z'+str(window_z))
    fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('AU_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-',
            marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('AU_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('AU_MacroMomentum_z'+str(window_z)+".png"), bbox_inches="tight")
    plt.show()
    plt.close()
    plt.close('all')


    hv_tb_au_000_003_m[str('AU_MacroMomentum_z'+str(window_z))] = hv_tb_au_000_003_m[aui_m_tickers].mean(axis=1)
    hv_tb_au_000_004_m=hv_tb_au_000_003_m[str('AU_MacroMomentum_z'+str(window_z))]
    df1=hv_tb_au_000_004_m.copy()
    g1=df1.copy()    
    title_r=str('AU_MacroMomentum_z'+str(window_z))
    fig, ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y= [str('AU_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)                                           
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('AU_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2= ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('AU_MacroMomentum_z'+str(window_z)+".png"), bbox_inches='tight')
    plt.show()  
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    del fig
    del ax
    del ax2
    #######################################################
    df1=hv_tb_au_000_004_m.tail(24)
    g1=df1.copy()
    title_r=str('AU_MacroMomentum_z'+str(window_z))
    fig, ax= plt.subplots(figsize=(parameter1_s,parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('AU_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)                                          
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('AU_MacroMomentum_z'+str(window_z))), size=parameter3) 
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("AU_MacroMomentum_z" + str(window_z) + "z.png"), bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    del fig
    del ax
    del ax2
    del hv_tb_au_000_002_m
    del hv_tb_au_000_003_m
    del hv_tb_au_000_004_m















### 001_  TABLE    <a id="title_page"></a

country_database = 'ANZ'
#Loading tickers
horizon_1 = 24
cpi_q_tickers = ['AUNPC', 'AUNPCF', 'AUNPCF', 'AUNPCB', 'AUNPCA', 'AUNPCH', 
                 'AUNPCO', 'AUNPCPH', 'AUNPCT', 'AUNPCC', 'AUNPCR', 'AUNPCD', 'AUNPCIF', 
                 'AUSPCP', 'AUSPCTRP', 'AUSPCWP', 'AUSPCXVY', 'AUSPCXXY', 'AUSPCXBY', 
                 'AUSPCXMY', 'AUSPCXLY', 'AUSPCXIY', 'AUSPCY', 'AUSPCTRY', 'AUSPCWY', 
                 'AUNPCY', 'AUNPCXVYW', 'AUNPCXXY', 'AUNPCXBY', 'AUNPCXMY', 'AUNPCXLY', 'AUNPCXIY']
cpi_m_tickers = ['AUNIGI', 'AUNIGIC', 'AUNIGIT', 'AUNIGIY']
comd_m_tickers = ['AUNPMAD', 'AUNPMRD', 'AUNPMND', 'AUNPMMD', 'AUNPMBD', 'AUNPMSD']
##employment
empl_m_tickers = ['AUSELL', 'AUSELU', 'AUSELUR', 'AUSELPR', 'AUSELER']
##gdp
gdp_q_tickers = ['AUSECUC', 'AUSECUN', 'AUSECUCN', 'AUSNGDPC', 'AUSNCC', 'AUSNGSC', 'AUSNHC', 'AUSNFPC']
#AUSECUC@ANZ Australia: Non-Farm Unit Labor Costs: Nominal (SA, FY, 2020-100)
#AUSECUN@ANZ Australia: Unit Labor Costs: Real (SA, FY, 2020-100)
#AUSECUCN@ANZ Australia: Non-Farm Unit Labor Costs: Real (SA, FY, 2020-100)

#yryr%(AUSNGDPC@ANZ) Australia: Gross Domestic Product (SA, Chn. FY 2020.A$) % Change Year to Year
#yryr%(AUSNCC@ANZ) Australia: GDP: Final Consumption Expenditure (SA, Chn. FY 2020.A$) % Change Year to Year
#yryr%(AUSNGSC@ANZ) Australia: Final Consumptn Exp: Gen Gov: State & Loc (SA, Chn. FY 2020.AS) % Change Year to Year
#yryr%(AUSNHC@ANZ) Australia: GDP: Final Consumption Exp: Households (SA, Chn. FY 2020.A$) % Change Year to Year
#yryr%(AUSNFPC@ANZ) Australia: GDP: Private Gross Fixed Cap Formation (SA, Chn. FY 2020.A$) % Change Year to Year
ip_q_tickers = ['AUSDGV', 'AUSDN', 'AUSDM']

#yryr%(AUSDGV@ANZ) Australia: Industrial Production excl Construction (SA, FY, 2020-100)
#yryr%(AUSDN@ANZ) Australia: Industrial Production: Mining (SA, FY, 2020-100) % Change Year to Year
#yryr%(AUSDM@ANZ) Australia: Industrial Production: Manufacturing (SA, FY, 2020-100)
# activity
# gdp
# survey
# currency
repo_m_tickers = ['AUEROCR']
# surveys
surveys_m_tickers = ['AUSVCC']
# AUNPC Consumer Price Index
# AUNPCXVY@ANZ Australia: CPI excluding Volatile Items (NSA, Vr/Yr % Chg)
#hv_cpi_q = Haver.data(cpi_q_tickers, 
#                      country_database, 
#                      dates=True)
# AUSPCTRYBANZ Australia: CPI Trimmed Mean (SA, Year-End % Change)
#hv_cpi_q.rename(columns={'aunpc': 'CPI_q_SA_YY'}, inplace=True)
#hv_cpi_q["CPI_q_SA_YY"] = hv_cpi_q["CPI_q_SA_YY"].pct_change(periods=4, 
#                                                             fill_method='bfill').multiply(100).round(2)
#hv_cpi_q.rename(columns={'auspctry': 'CPI_Trimmed_Mean_SA_YY'}, inplace=True)
#hv_cpi_m = Haver.data(cpi_m_tickers, country_database, dates=True)
#hv_cpi_m.rename(columns={'aunigi': 'CPI_Melb_Monthly_NSA_YY'}, inplace=True)
#hv_cpi_m["CPI_Melb_Monthly_NSA_YY"] = hv_cpi_m["CPI_Melb_Monthly_NSA_YY"].pct_change(periods=12, 
#                                                                                     fill_method='bfill').multiply(100).round(2)
# .round(1)
# historical['cpi_headline_m_print'] = historical['cpi_headline_m_print'].round(2)
# print_data = print_data.multiply(100)

#hv_database = pd.concat([hv_cpi_q, hv_cpi_m], axis=1, join='outer')
#hv_comd_m = Haver.data(comd_m_tickers, country_database, dates=True)
#hv_comd_m.rename(columns={'aunpmad': 'RBA_Comm_Prices'}, inplace=True)
#hv_database = pd.concat([hv_database, hv_comd_m], axis=1, join="outer")
#hv_empl_m = Haver.data(empl_m_tickers, country_database, dates=True)
#hv_empl_m.rename(columns={'ausell': 'Labor_force_m'}, inplace=True)
#hv_empl_m["Labor_force_m"] = hv_empl_m["Labor_force_m"].pct_change(periods=12, 
#                                                                   fill_method='bfill').multiply(100).round(2)
#hv_empl_m.rename(columns={'auselur': 'unemployment_rate_m'}, inplace=True)
#hv_empl_m.rename(columns={'auselpr': 'participation_rate_m'}, inplace=True)
#hv_empl_m.rename(columns={'auseler': 'employment_to_pop_m'}, inplace=True)
#hv_database = pd.concat([hv_database, hv_empl_m], axis=1, join="outer")
#hv_lc_q = Haver.data(lc_q_tickers, country_database, dates=True)
#hv_lc_q.rename(columns={'ausecuc': 'unit_labor_q_sa'}, inplace=True)
#hv_lc_q["unit_labor_q_sa"] = hv_lc_q["unit_labor_q_sa"].pct_change(periods=1, 
#                                                                   fill_method='bfill').multiply(100).round(2)
##AUSECUC@ANZ
##Australia: Unit Labor Costs: Real (SA, FY, 2020-100)
##Australia: Non-Farm Unit Labor#
#
##AUSECUN@ANZ#
#Costs: Nomin#al (SA, FY, 2020-100)
#AUSECUCN@ANZ# Australia: Non-Farm Unit Labor Costs: Real (SA, FY, 2020-100)
#AUSECUCN@ANZ# Australia: Non-Farm Unit Labor Costs: Real (SA, FY, 2020-100)
##
#h#v_gdp_q=Haver.data(gdp_q_tickers, country_database, dates=True)
#h#v_gdp_q.rename(columns={'ausngdpc': 'gdp_q_sa'}, inplace=True)
#hv#_gdp_q["gdp_q_sa"]=hv_gdp_q["gdp_q_sa"].pct_change(periods=1, 
#  #                                                   fill_method='bfill').multiply(100).round(2)
##hv_gdp_q["gdp_a_sa1"]=hv_gdp_q["gdp_q_sa"].pct_change()###

#hv_gdp_q["gdp_q_sa2"]=hv_gdp_q["gdp_q_sa"].pct_change (1)
#print(hv_gdp_q)
#hv_gdp_q.rename(columns={'ausncc':'gdp_c_q_sa'}, inplace=True)
#hv_gdp_q["gdp_c_q_sa"]=hv_gdp_q["gdp_c_q_sa"].pct_change().multiply(100).round(2)#
#hv_gdp_q.rename(columns={'ausngsc':'gdp_g_q_sa'}, inplace=True)
#hv_gdp_q["gdp_g_q_sa"]=hv_gdp_q["gdp_g_q_sa"].pct_change().multiply(100).round(2)
#hv_gdp_q.rename(columns={'ausnhc': 'gdp_hh_q_sa'}, inplace=True)
#hv_gdp_q["gdp_hh_q_sa"]=hv_gdp_q["gdp_hh_q_sa"].pct_change().multiply(100).round(2)
#hv_gdp_q.rename(columns={'ausnfpc':'gdp_i_q_sa'}, inplace=True)
#hv_gdp_q["gdp_i_q_sa"]=hv_gdp_q["gdp_i_q_sa"].pct_change().multiply(100).round(2)
#hv_database = pd.concat([hv_database, hv_gdp_q], axis=1, join="outer")
#hv_ip_q=Haver.data(ip_q_tickers, 
#                   country_database, dates=True)
#hv_ip_q.rename(columns={'ausdgv': 'ip_excl_construction_q'}, inplace=True)
#hv_ip_q.rename(columns={'ausdn': 'ip_mining_q'}, inplace=True)
#hv_ip_q.rename(columns={'ausdm': 'ip_manufacturing_q'}, inplace=True)

#hv_database=pd.concat([hv_database, hv_ip_q], axis=1, join="outer")
#hv_repo_m=Haver.data(repo_m_tickers, country_database, dates=True)
#hv_repo_m.rename(columns={'auerocr': 'repo'}, inplace=True)
#hv_database= pd.concat([hv_database, hv_repo_m], axis=1, join="outer")

#hv_surveys_m=Haver.data(surveys_m_tickers, country_database, dates=True)
#hv_surveys_m.rename(columns={'ausvcc':'wp_consumer_sentiment'}, inplace=True)
#hv_surveys_m.rename(columns={'ausvce': 'survey_eco_conditions'}, inplace=True)
#hv_surveys_m.rename(columns={'aunve': 'survey_unemployment_expectations'}, inplace=True)

#hv_database = pd.concat([hv_database, hv_surveys_m], axis=1, join="outer")#
##v_database = hv_database.loc['2018-12-31':]
# print(hv_database)

#list_display = ["CPI_q_SA_YY", "CPI_Trimmed_Mean_SA_YY",
#                "CPI_Melb_Monthly_NSA_YY", "RBA_Comm_Prices",
#                "Labor_force_m", "unemployment_rate_m", "participation_rate_m", "employment_to_pop_m",
#                "gdp_q_sa", "gdp_c_q_sa", "gdp_g_q_sa", "gdp_hh_q_sa", "gdp_i_q_sa",  #"unit_Labor_q_sa",
#            
#                "ip_excl_construction_q","ip_mining_q", "ip_manufacturing_q",
#                "wp_consumer_sentiment", "repo"]
#dashboard = hv_database[list_display]
#dashboard = dashboard.tail(horizon_1)
#dashboard_q = dashboard.loc[dashboard.index.is_quarter_end]
#print(dashboard_q)
## transpose
#dashboard = dashboard.transpose()
#dashboard.index.names = ['Variable']
##dashboard.to_clipboard()
#print(path_display)
#dashboard.to_csv(path_display, index=True, header=True)

# print(display)

#dashboard.to_clipboard()
#print(dashboard)

#path_display= tb_au_001_001_m.csv'
#print(path_display)
#dashboard.to_csv (path_display, index=True, header=True)
#print(display)

#dashboard_q = dashboard_q.transpose()
#dashboard_q.index.names = ['Variable']

#path_display =
#print(path_display)
#dashboard_q.to_csv (path_display, index=True, header=True)
#hv_database=hv_database.loc["2018-12-31":]
#dashboard=dashboard. (horizon_1)
#dashboard = dashboard.transpose()
#dashboard.index.names = ['Variable']
#dashboard.to_clipboard()
#print(dashboard)
#path_display = rtable_au_001.csv"
#print(path_display)
#

























### 001_  cpi  nsa yy 2 01

horizon_tb = 24
country_database = 'ANZ'
aui_m_tickers=['aunpcy', 'aunpcxvy', 'aunpcxxy',
               'aunpcxby', 'aunpcxmy', 'aunpcxly', 'aunpcxiy',]
hv_tb_au_002_001_q=Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_001_q)
#print(hv_tb_au_002_001_q.columns)
#auselur unemplyment rate montihy # auselpr pariticapotion rate
hv_tb_au_002_001_q.rename(columns={"aunpcy":"AU CPI All Groups NSA Y/Y"}, inplace=True)
#hv_tb_ou_002_001_q.rename(columns={"auspctrp": "AU CPI Trimmed Mean Y/Y"}, inplace=True)
#hv_tb_ou_002_001_q.rename(columns={"auspcwp": "AU CPI Weighted Median Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxvy":"AU CPI Excluding Volatile NSA Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxxy":"AU CPI Tradables NSA Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxby": "AU CPI Tradables Excluding Volatile NSA Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxmy": "AU CPI Non Tradables NSA Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxly": "AU CPI Non Tradables Excluding Deposit NSA Y/Y"}, inplace=True)
hv_tb_au_002_001_q.rename(columns={"aunpcxiy": "AU CPI Excluding Interest Charges NSA Y/Y"}, inplace=True)
#hv_tb_au_002_001_q_g_001=hv_tb_au_002_001_q.copy()
##hv_tb_au_002_001_q_g_001.index.name = 'date'
##hv_tb_au_002_001_q_g_002=hv_tb_au_002_001_q[["AU CPI Excluding Volatile NSA Y/Y"]]
##hv_tb_au_002_001_q_g_002.index.name = 'date'
#hv_tb_au_002_001_q=hv_tb_au_002_001_q.tail(horizon_tb)
#hv_tb_au_002_001_q=hv_tb_au_002_001_q.transpose()
#hv_tb_au_002_001_q.index.names = [ 'Variable']
##dashboard.to_clipboard()
#print(hv_tb_au_002_001_q)
#dashboard.to_clipboard()print("step2")
#print("step2")
# hv_tb_au_002_001_q_a_001 = hv_tb_au_002_001_a_g_001.tail(40)

# hv_tb_ou_002_001_q_g_001.to_csv(path_display, index=True, header=True)
# hv_tb_au_002_001_q_a_002 = hv_tb_au_002_001_q_a_002.tail(40)
# print(path_display)
# hv_tb_au_002_001_q_a_002.to_csv(path_display, index=True, header=True)


hv_tb_au_002_001_q_g = hv_tb_au_002_001_q.copy()
hv_tb_au_002_001_q_g_001 = hv_tb_au_002_001_q.copy()

hv_tb_au_002_001_q.index=hv_tb_au_002_001_q.index.date
hv_tb_au_002_001_q = hv_tb_au_002_001_q.tail(horizon_tb)
hv_tb_au_002_001_t1=hv_tb_au_002_001_q.tail(horizon_tb)

hv_tb_au_002_001_q_t = hv_tb_au_002_001_q.transpose()
hv_tb_au_002_001_q_t.index.names = ['Variable']

hv_tb_au_002_001_t1_t = hv_tb_au_002_001_t1.transpose()
hv_tb_au_002_001_t1_t.index.names = ['Variable']

### 001_  cpi nsa yy  table 


############################################################
######Table 1

#####here*******
title_table="au_inflation_yy_table"
df =hv_tb_au_002_001_t1.copy()
df_transposed = hv_tb_au_002_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_001_q_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_001_q_t_002.png')



### 001_  cpi nsa yy  graph 

#hv_tb_au_002_001_q_g_001

title_r = "Australia Inflation NSA Y/Y"
y_label = "Index %"
x_label = title_r
list_c = ["AU CPI All Groups NSA Y/Y", 
          "AU CPI Excluding Volatile NSA Y/Y"]
df1 = hv_tb_au_002_001_q_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU CPI All Groups NSA Y/Y"],
        color="darkgreen", linewidth=11, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU CPI Excluding Volatile NSA Y/Y"], color="darkblue", linewidth=11, linestyle='-', marker='D', markersize=s2)
# g1.plot(kind='Line', ax=ax, y=["CA BOC Core Inflation CPI Common Y/Y"], color="darkred", Linewidth= Li, Linestyle='-', marker='X', markersize=s2)
# g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, linestyle="-", marker='s', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_001_q_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2






title_r="Australia Inflation NSA Y/Y"
y_label="Index %"
x_label=title_r
list_c=["AU CPI All Groups NSA Y/Y", 
        "AU CPI Excluding Volatile NSA Y/Y"]
df1=hv_tb_au_002_001_q_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["AU CPI All Groups NSA Y/Y",], color="darkgreen", linewidth= l1, linestyle="-",
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU CPI Excluding Volatile NSA Y/Y"], color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["CA BOC Core Inflation CPI Common Y/Y"], color="darkred", Linewidth= Li, Linestyle='-',
#marker="X", markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle'-',marker's", markersize=s2)
#
plt.axhline(0, color='black', lw=1,linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_001_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

### 001_  cpi qq  2 02 <a id="title_page"></a

aui_m_tickers = ['auspcp', 'auspctrp', 'auspcwp', 'auspcxvy', 'auspcxxy',
                 'auspcxby', 'auspcxmy', 'auspcxly', 'auspcxiy',]

hv_tb_au_002_002_q=Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_002_q)
#print(hv_tb_au_002_002_q.columns)
#auselur unemplyment rate montlhy
# auselpr pariticapotion rate
hv_tb_au_002_002_q.rename(columns={"auspcp": "AU CPI All Groups NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspctrp": "AU CPI Trimmed Mean NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcwp": "AU CPI Weighted Median NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxvy":"AU CPI Excluding Volatile NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxxy":"AU CPI Tradables NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxby": "AU CPI Tradables Excluding Volatile NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxmy": "AU CPI Non Tradables NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxly": "AU CPI Non Tradables Excluding Deposit NSA Q/Q"}, inplace=True)
hv_tb_au_002_002_q.rename(columns={"auspcxiy":"AU CPI Excluding Interest Charges NSA Q/Q"}, inplace=True)
#hv_tb_au_002_002_q_g_001=hv_tb_au_002_002_q.copy()
#hv_tb_au_002_002_q=hv_tb_au_002_002_q.tail(horizon_tb)
#hv_tb_au_002_002_q = hv_tb_au_002_002_q.transpose()
#hv_tb_au_002_002_q.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_002_002_q)
#dashboard.to_clipboard()
#print(path_display)
#v_tb_au_002_002_q.to_csv (path_display, index = True, header=True)
#print(hv_tb_au_002_002_q)
#print("step2")


###

hv_tb_au_002_002_q_g = hv_tb_au_002_002_q.copy()
hv_tb_au_002_002_q_g_001 = hv_tb_au_002_002_q.copy()

hv_tb_au_002_002_q.index=hv_tb_au_002_002_q.index.date
hv_tb_au_002_002_q = hv_tb_au_002_002_q.tail(horizon_tb)
hv_tb_au_002_002_t1=hv_tb_au_002_002_q.tail(horizon_tb)

hv_tb_au_002_002_q_t = hv_tb_au_002_002_q.transpose()
hv_tb_au_002_002_q_t.index.names = ['Variable']

hv_tb_au_002_002_t1_t = hv_tb_au_002_002_t1.transpose()
hv_tb_au_002_002_t1_t.index.names = ['Variable']



### 001_  cpi qq  table

############################################################
######Table 1

#####here*******
title_table="au_inflation_qq_table"
df =hv_tb_au_002_002_t1.copy()
df_transposed = hv_tb_au_002_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_002_q_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_002_q_t_002.png')

### 001_  cpi qq  2 02 graphs

#hv_tb_au_002_002_q_g_001
title_r="Australia Inflation NSA Q/Q"
y_label="Index %"
x_label=title_r
list_c=["AU CPI All Groups NSA Q/Q",
        "AU CPI Excluding Volatile NSA Q/Q"]
df1=hv_tb_au_002_002_q_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["AU CPI All Groups NSA Q/Q",], color="darkgreen", linewidth= l1, linestyle='-',marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=["AU CPI Excluding Volatile NSA Q/Q"], color="darkblue", linewidth= l1, linestyle='-',marker='D', markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["CA BOC Core Inflation CPI Common. Y/Y"], color="darkred", Linewidth= L1, Linestyle='marker="X", markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',
#plt.axhline(0, color='black', lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_002_q_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


#

title_r="Australia Inflation NSA Q/Q"
y_label="Index %"
x_label=title_r
list_c=["AU CPI All Groups NSA Q/Q",
        "AU CPI Excluding Volatile NSA Q/Q"]
df1=hv_tb_au_002_002_q_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["AU CPI All Groups NSA Q/Q",], color="darkgreen", linewidth= l1, linestyle='-',marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=["AU CPI Excluding Volatile NSA Q/Q"], color="darkblue", linewidth= l1, linestyle='-',marker='D', markersize=s2)
#g1.plot(kind='Line', ax=ax, y=["CA BOC Core Inflation CPI Common Y/Y"], color="darkred", Linewidth= L1, Linestyle="-",marker='X', markersize=s2)
##g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle'-',marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_002_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_  cpi vs foreecast   <a id="title_page"></a

#Australia
#Forecasts vs Print
aui_m_tickers = ['aunpcy', 'aupc',
                 'auspctry', 'auin',]
hv_tb_au_002_004_q=Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_004_q)
#print(hv_tb_au_002_004_q.columns)
#auselur unempLyment rate mont Lhy
# auselpr pariticapotion rate
hv_tb_au_002_004_q.rename(columns={"aunpcy":"AU CPI All Groups NSA Y/Y"}, inplace=True)
hv_tb_au_002_004_q.rename(columns={"aupc": "AU RBA CPI Forecast NSA Y/Y"}, inplace=True)
hv_tb_au_002_004_q.rename(columns={"auspctry":"AU CPI Trimmed Mean NSA Y/Y"}, inplace=True)
hv_tb_au_002_004_q.rename(columns={"auin": "AU RBA CPI Trimmed Mean Forecast NSA Y/Y"}, inplace=True)
#hv_tb_au_002_004_q=hv_tb_au_002_004_q.tail(24)
#hv_tb_au_002_004_q = hv_tb_au_002_004_q.transpose()
#hv_tb_au_002_004_q.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_002_004_q)
#dashboard.to_clipboard()
#print(path_display)
#hv_tb_au_002_004_q.to_csv (path_display, index True, header=True)
#print(hv_tb_au_002_004_q)
print("step2")


hv_tb_au_002_004_q_g = hv_tb_au_002_004_q.copy()
hv_tb_au_002_004_q_g_001 = hv_tb_au_002_004_q.copy()

hv_tb_au_002_004_q.index=hv_tb_au_002_004_q.index.date
hv_tb_au_002_004_q = hv_tb_au_002_004_q.tail(horizon_tb)
hv_tb_au_002_004_t1=hv_tb_au_002_004_q.tail(horizon_tb)

hv_tb_au_002_004_q_t = hv_tb_au_002_004_q.transpose()
hv_tb_au_002_004_q_t.index.names = ['Variable']

hv_tb_au_002_004_t1_t = hv_tb_au_002_004_t1.transpose()
hv_tb_au_002_004_t1_t.index.names = ['Variable']

### 001_  cpi vs foreecast table


############################################################
######Table 1

#####here*******
title_table="au_forecast_mm_table"
df =hv_tb_au_002_004_t1.copy()
df_transposed = hv_tb_au_002_004_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_004_q_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_004_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_004_q_t_002.png')

### 001_  cpi vs foreecast graph 

### 001_ Melb Monthly Inflation Gauge mm 2- 06   <a id="title_page"></a

horizon_tb = 24
country_database = 'ANZ'
aui_m_tickers = ['aunigi', 'aunigic', 'aunigit',]
hv_tb_au_002_006_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_006_m)
#print(hv_tb_au_002_006_m.columns)
#auselur unemplyment rate montlhy
hv_tb_au_002_006_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_006_m)
#print(hv_tb_au_002_006_m.columns)
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    #print(variable)
    hv_tb_au_002_006_m[variable] = hv_tb_au_002_006_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
    #print(hv_tb_au_002_006_m[variable])
# auselpr pariticapotion rate
hv_tb_au_002_006_m.rename(columns={"aunigi": "AU Melb Monthly Inflation Gauge m/m"}, inplace=True)
hv_tb_au_002_006_m.rename(columns={"aunigic": "AU Melb Monthly Inflation Core m/m"}, inplace=True)
hv_tb_au_002_006_m.rename(columns={"aunigit": "AU Melb Monthly Inflation Trimmed m/m"}, inplace=True)
#hv_tb_au_002_006_m = hv_tb_au_002_006_m.tail(horizon_tb)
#hv_tb_au_002_006_m = hv_tb_au_002_006_m.transpose()
#hv_tb_au_002_006_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_au_002_006_m)
#dashboard.to_clipboard()
#print(path_display)
#hv_tb_au_002_006_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_002_006_m)


hv_tb_au_002_006_m_g = hv_tb_au_002_006_m.copy()
hv_tb_au_002_006_m_g_001 = hv_tb_au_002_006_m.copy()

hv_tb_au_002_006_m.index=hv_tb_au_002_006_m.index.date
hv_tb_au_002_006_m = hv_tb_au_002_006_m.tail(horizon_tb)
hv_tb_au_002_006_t1=hv_tb_au_002_006_m.tail(horizon_tb)

hv_tb_au_002_006_m_t = hv_tb_au_002_006_m.transpose()
hv_tb_au_002_006_m_t.index.names = ['Variable']

hv_tb_au_002_006_t1_t = hv_tb_au_002_006_t1.transpose()
hv_tb_au_002_006_t1_t.index.names = ['Variable']


print("step2")

### 001_ Melb Monthly Inflation Gauge  mm  2- 06 table

############################################################
######Table 1

#####here*******
title_table="au_melbourne_inflation_mm_table"
df =hv_tb_au_002_006_t1.copy()
df_transposed = hv_tb_au_002_006_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_006_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_006_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_006_m_t_002.png')





### 001_ Melb Monthly Inflation Gauge q/q 2- 07  <a id="title_page"></a

horizon_tb = 24
country_database = 'ANZ'
aui_m_tickers = ['aunigi', 'aunigic', 'aunigit',]
hv_tb_au_002_007_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_007_m)
#rint(hv_tb_au_002_007_m.columns)
# auselur unemplyment rate montthy
hv_tb_au_002_007_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_007_m)
#print(hv_tb_au_002_007_m.columns)
for x in range(len(aui_m_tickers)):
    #print(x)
    variable = str(aui_m_tickers[x])
    #print(variable)
    hv_tb_au_002_007_m[variable] = hv_tb_au_002_007_m[variable].pct_change(periods=4, fill_method="bfill").multiply(100).round(3)
    #print(hv_tb_au_002_007_m[variable])
# auselpr pariticopotion rate
hv_tb_au_002_007_m.rename(columns={"aunigi": "AU Melb Monthly Inflation Gauge q/q"}, inplace=True)
hv_tb_au_002_007_m.rename(columns={"aunigic": "AU Melb Monthly Inflation Core q/q"}, inplace=True)
hv_tb_au_002_007_m.rename(columns={"aunigit": "AU Melb Monthly Inflation Trimmed q/q"}, inplace=True)
#hv_tb_au_002_007_m = hv_tb_au_002_007_m.tail(horizon_tb)
#hv_tb_au_002_007_m = hv_tb_au_002_007_m.transpose()
#hv_tb_au_002_007_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_au_002_007_m)
# dashboard.to_clipboard()

hv_tb_au_002_007_m_g = hv_tb_au_002_007_m.copy()
hv_tb_au_002_007_m_g_001 = hv_tb_au_002_007_m.copy()

hv_tb_au_002_007_m.index=hv_tb_au_002_007_m.index.date
hv_tb_au_002_007_m = hv_tb_au_002_007_m.tail(horizon_tb)
hv_tb_au_002_007_t1=hv_tb_au_002_007_m.tail(horizon_tb)

hv_tb_au_002_007_m_t = hv_tb_au_002_007_m.transpose()
hv_tb_au_002_007_m_t.index.names = ['Variable']

hv_tb_au_002_007_t1_t = hv_tb_au_002_007_t1.transpose()
hv_tb_au_002_007_t1_t.index.names = ['Variable']


### 001_ Melb Monthly Inflation Gauge q/q 2- 07 table

############################################################
######Table 1

#####here*******
title_table="au_melbourne_inflation_qq_table"
df =hv_tb_au_002_007_t1.copy()
df_transposed = hv_tb_au_002_007_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_007_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_007_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_007_m_t_002.png')


### 001_ Melb Monthly Inflation Gauge q/q 2-07 graph



### 001  Infl Expectations  002_008

horizon_tb = 24
country_database = 'ANZ'
aui_m_tickers = ['aunvit30', 'aunviw', 
                 'aunviw05', 'aunvrmi']
hv_tb_au_002_008_m=Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_002_008_m)
print(hv_tb_au_002_008_m.columns)
#auselur unemplyment rate montihy
# auselpr pariticapotion rate
hv_tb_au_002_008_m.rename(columns={"aunvit30": "AU Infl Expectations Trimmed Mean"}, inplace=True)
hv_tb_au_002_008_m.rename(columns={"aunviw":"AU Infl Expectations WM"}, inplace=True)
hv_tb_au_002_008_m.rename(columns={"aunviw05": "AU Infl Expectations WM 0-5"}, inplace=True)
hv_tb_au_002_008_m.rename(columns={"aunvrmi": "AU RM Infl Expectations next 2y"}, inplace=True)
#hv_tb_au_002_008_m=hv_tb_au_002_008_m.tail(horizon_tb)
#hv_tb_au_002_008_m =hv_tb_au_002_008_m.transpose()
#hv_tb_au_002_008_m.index.names = ["Variable"]
#dashboard.to_clipboard()
#print(hv_tb_au_002_008_m)
##dashboard.to_clipboard()

#hv_tb_au_002_008_m.to_csv (path_display, index True, header=True)
#print(hv_tb_au_002_008_m)
print("step2")


hv_tb_au_002_008_m_g = hv_tb_au_002_008_m.copy()
hv_tb_au_002_008_m_g_001 = hv_tb_au_002_008_m.copy()

hv_tb_au_002_008_m.index=hv_tb_au_002_008_m.index.date
hv_tb_au_002_008_m = hv_tb_au_002_008_m.tail(horizon_tb)
hv_tb_au_002_008_t1=hv_tb_au_002_008_m.tail(horizon_tb)

hv_tb_au_002_008_m_t = hv_tb_au_002_008_m.transpose()
hv_tb_au_002_008_m_t.index.names = ['Variable']

hv_tb_au_002_008_t1_t = hv_tb_au_002_008_t1.transpose()
hv_tb_au_002_008_t1_t.index.names = ['Variable']

### 001  Infl Expectations 002_008 table


############################################################
######Table 1

#####here*******
title_table="au_exp_inflation_mm_table"
df =hv_tb_au_002_008_t1.copy()
df_transposed = hv_tb_au_002_008_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_008_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_008_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_008_m_t_002.png')

### Infl Expectations  graph

### 001 cpi nsa  2 09

country_database = 'ANZ'
#aui_m_tickers = ['aunpcy', 'aupc', 'aupcp', 'auspctry', 'quin", "αυτηρ']
aui_m_tickers = ['aunpcy', 'aupc',
                 'auspctry', 'auin',]
hv_tb_au_002_009_m=Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_002_009_m)
#print(hv_tb_au_002_009_m.columns)
#ausetur unemplyment rate montlhy
# auselpr pariticapotion rate
hv_tb_au_002_009_m.rename(columns={"aunpcy": "CPI Headline YY NSA"}, inplace=True)
hv_tb_au_002_009_m.rename(columns={"aupc": "CPI Headline YY NSA RBA"}, inplace=True)
#hv_tb_au_002_009_m.rename(columns={"aupcp": "CPIHeadline YY NSA RBA Previous"}, inplace=True)
hv_tb_au_002_009_m.rename(columns={"auspctry": "CPI Trimmed YY NSA"}, inplace=True)
hv_tb_au_002_009_m.rename(columns={"auin": "CPI Trimmed YY NSA RBA"}, inplace=True)
#hv_tb_au_002_009_m.rename(columns={"auinp": "CPI Trimmed YY NSA RBA Previous"}, inplace=True)
#hv_tb_au_002_009_m_g_001=hv_tb_au_002_009_m.copy()
#hv_tb_au_002_009_m=hv_tb_au_002_009_m.tail(horizon_tb)
#hv_tb_au_002_009_m =hv_tb_au_002_009_m.transpose()
#hv_tb_au_002_009_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_002_009_m)
#dashboard.to_clipboard()

#hv_tb_au_002_009_m.to_csv (path_display, index True, header=True)
#print(hv_tb_au_002_009_m)
#print("step2")

hv_tb_au_002_009_m_g = hv_tb_au_002_009_m.copy()
hv_tb_au_002_009_m_g_001 = hv_tb_au_002_009_m.copy()

hv_tb_au_002_009_m.index=hv_tb_au_002_009_m.index.date
hv_tb_au_002_009_m = hv_tb_au_002_009_m.tail(horizon_tb)
hv_tb_au_002_009_t1=hv_tb_au_002_009_m.tail(horizon_tb)

hv_tb_au_002_009_m_t = hv_tb_au_002_009_m.transpose()
hv_tb_au_002_009_m_t.index.names = ['Variable']

hv_tb_au_002_009_t1_t = hv_tb_au_002_009_t1.transpose()
hv_tb_au_002_009_t1_t.index.names = ['Variable']
############################################################



### 001  cpi nsa  2 09 table

######Table 1

#####here*******
title_table="au_inflation_mm_table"
df =hv_tb_au_002_009_t1.copy()
df_transposed = hv_tb_au_002_009_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_009_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_009_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_009_m_t_002.png')

#hv_tb_au_002_009_m_g_001
title_r="Australia Headline Inflation RBA"
y_label="Index %"
x_label=title_r
list_c=["CPI Headline YY NSA",
        "CPI Headline YY NSA RBA",]
df1=hv_tb_au_002_009_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CPI Headline YY NSA",], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA"], color="darkblue", linewidth= l1, linestyle='-',
        marker= 'D', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_009_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

#  #  #

#hv_tb_au_002_009_m_g_002
title_r="Australia Trimmed Inflation RBA"
y_label="Index %"
x_label=title_r
list_c=["CPI Trimmed YY NSA", "CPI Trimmed YY NSA RBA", ]
#        "CPI Trimmed YY NSA RBA Previous"]
df1=hv_tb_au_002_009_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["CPI Trimmed YY NSA",], color="darkgreen", linewidth=11, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Trimmed YY NSA RBA"], color="darkblue", linewidth=11, linestyle='-', marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CPI Trimmed YY NSA RBA Previous"], color="darkred", linewidth=11, linestyle='-', marker='X', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle='-', marker='s', markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_009_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2

print("complete")
print("Experimental monthly ")

title_r="Australia Trimmed Inflation RBA"
y_label="Index %"

x_label=title_r
list_c=["CPI Trimmed YY NSA",
        "CPI Trimmed YY NSA RBA",
#        "CPI Trimmed YY NSA RBA Previous"
       ]

df1=hv_tb_au_002_009_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots (figsize= (parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CPI Trimmed YY NSA"], color="darkgreen", 
        linewidth=l1, linestyle='',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Trimmed YY NSA RBA"], color="darkblue", 
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_009_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
print("complete")
print("Experimental monthly ")

### 001  Exp Monthly CPI Headline t   002_010 <a id="title_page"></a

#print('experimental monthly')
country_database = 'ANZ'
aui_m_tickers = ['auwpc', 'auwpcxh', 'aumpc', 'aumpcx',
                 'aumpcxh', 'aumpcmg', 'aumpcms', 'aumpctr', 'aumpcntr']
hv_tb_au_002_010_m = Haver.data(aui_m_tickers, country_database, dates=True)

print(hv_tb_au_002_010_m.columns)

for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_002_010_m[variable] = hv_tb_au_002_010_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)

#auslpur unemployment rate monthly
#auslpr participation rate

hv_tb_au_002_010_m.rename(columns={"auwpc":"AU Exp Monthly CPI Headline YY SA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"auwpcxh":"AU Exp Monthly CPI ex Vol HT YY SA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpc":"AU Exp Monthly CPI Headline YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpcx":"AU Exp Monthly CPI ex Vol YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpcxh":"AU Exp Monthly CPI ex Vol HT YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpcmg":"AU Exp Monthly CPI Goods YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpcms":"AU Exp Monthly CPI Services YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpctr":"AU Exp Monthly CPI Tradeables YY NSA"}, inplace=True)
hv_tb_au_002_010_m.rename(columns={"aumpcntr":"AU Exp Monthly CPI nontradeables YY NSA"}, inplace=True)
#hv_tb_au_002_010_m_g_001=hv_tb_au_002_010_m.copy()

#hv_tb_au_002_010_m=hv_tb_au_002_010_m.tail(horizon_tb)
#hv_tb_au_002_010_m=hv_tb_au_002_010_m.transpose()
#hv_tb_au_002_010_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_au_002_010_m)



hv_tb_au_002_010_m_g = hv_tb_au_002_010_m.copy()
hv_tb_au_002_010_m_g_001 = hv_tb_au_002_010_m.copy()

hv_tb_au_002_010_m.index=hv_tb_au_002_010_m.index.date
hv_tb_au_002_010_m = hv_tb_au_002_010_m.tail(horizon_tb)
hv_tb_au_002_010_t1=hv_tb_au_002_010_m.tail(horizon_tb)

hv_tb_au_002_010_m_t = hv_tb_au_002_010_m.transpose()
hv_tb_au_002_010_m_t.index.names = ['Variable']

hv_tb_au_002_010_t1_t = hv_tb_au_002_010_t1.transpose()
hv_tb_au_002_010_t1_t.index.names = ['Variable']
############################################################

### 001  Exp Monthly table 002_010



######Table 1

#####here*******
title_table="au_exp_inflation_mm_table"
df =hv_tb_au_002_010_t1.copy()
df_transposed = hv_tb_au_002_010_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_002_010_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_002_010_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_002_010_m_t_002.png')

### 001  Exp Monthly graph 002_010

print("step2")
df1 = hv_tb_au_002_010_m_g_001
df1 = df1.tail(36)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = list_c[0]
y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth=11, linestyle='-', marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkblue", linewidth=11, linestyle='-', marker='D', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["CPI HeadLine YY NSA RBA Previous"], color="darkred", Linewidth= L1, Linestyle-'-', marker='X', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-', markers", markersize=s2)
for x, y in zip(g1.index, g1[list_c[0]]):
  label = "{:.2f}".format(y)
  plt.annotate(label,  # this is the text
                (x, y),  # these are the coordinates to position the label
                textcoords="offset points",  # how to position the text
                xytext=(0, 18),  # distance from text to points (x,y)
                ha='center',
                size=6)

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

df1=hv_tb_au_002_010_m_g_001.copy()
df1=df1.tail(24)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=list_c[0]
y_label="Index %"
x_label=title_r
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[0], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkblue", linewidth=l1, linestyle='-',
        marker="D", markersize=s2)

for x, y in zip(g1.index, g1[list_c[0]]):
  label = "{:.2f}".format(y)
  plt.annotate(label,  # this is the text
                (x, y),  # these are the coordinates to position the label
                textcoords="offset points",  # how to position the text
                xytext=(0, 18),  # distance from text to points (x,y)
                ha='center',
                size=6)

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))


plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

df1 = hv_tb_au_002_010_m_g_001
df1 = df1.tail(36)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = list_c[1]
y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=11, linestyle='',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=list_c[4], color="darkblue", linewidth=11, linestyle='',
        marker='D', markersize=s2)

for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha="center")

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))

plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')

df1=hv_tb_au_002_010_m_g_001
df1=df1.tail(24)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=list_c[1]
y_label="Index %"
x_label=title_r
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[1], color="darkgreen", linewidth= l1, linestyle="-",
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=list_c[4], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind="Line",ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth= 11, Linestyle="-",
#marker='X', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle-'-',
#marker's', markersize=s2)
#
for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha="center")

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))


plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')

df1=hv_tb_au_002_010_m_g_001.copy()
df1=df1.tail(36)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[5] +" "+ list_c[6])
y_label="Index %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=list_c[5], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind="line", ax=ax,y=list_c[6], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
for x,y in zip(g1.index,g1 [list_c[5]]):
    plt.annotate(label, # this is the text (x,y), #these are the coordinates to position the label
                  (x, y), 
                  textcoords="offset points", # how to position the text
                  xytext=(0,18), # distance from text to points (x,y)
                  size=6,
                  ha='center')
for x, y in zip(g1.index, g1[list_c[6]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha="center")
for series_name in list_c[5:7]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))


plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_005.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

df1=hv_tb_au_002_010_m_g_001.copy()
df1=df1.tail(24)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[5] +" "+ list_c[6])
y_label="Index %"
x_label=title_r
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=list_c[5], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=list_c[6], color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CPI HeadLine YY NSA RBA Previous"], color="darkred", Linewidth= (1, Linestyle="-",marker="X", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-",marker='s', markersize=s2)
#
for x, y in zip(g1.index, g1[list_c[6]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center')

for series_name in list_c[5:7]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f"{series_name}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_006.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

df1=hv_tb_au_002_010_m_g_001.copy()
df1=df1.tail(36)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[7]+" "+ list_c[8])
y_label="Index %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind="line", ax=ax,y=list_c[7], color="darkgreen", linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind="line", ax=ax,y=list_c[8], color="darkblue", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", Linewidth= 11, Linestyle="-",marker="X", markersize=s2)
##g1.plot(kind='Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="
#marker's', markersize=s2)
for x, y in zip(g1.index, g1[list_c[8]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
        (x, y),  # these are the coordinates to position the Label
        textcoords="offset points",  # how to position the text
        xytext=(0, 18),  # distance from text to points (x, y)
        size=6,
        ha='center')

for series_name in list_c[7:9]:
    last_y_value = g1[series_name][-1]
    # print(Last_y_value)
    plt.annotate(f' (series_name)', xy=(g1.index.max(), last_y_value),
        xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')

plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_007.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

df1=hv_tb_au_002_010_m_g_001.copy()
df1=df1.tail(24)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[7] +" "+ list_c[8])
y_label="Index %"
x_label=title_r
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[7], color="darkgreen", linewidth= 11, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind="line", ax=ax,y=list_c[8], color="darkblue", linewidth= 11, linestyle='-',
        marker= "D", markersize=s2)


#hv_tb_au_002_010_m_g_008
for x, y in zip(g1.index, g1[list_c[8]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha="center")

for series_name in list_c[7:9]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f" ({series_name})", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_002_010_m_g_008.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

























                                                                                                                          





















































































    























































### 001_ AU Unemployment Rate Monthly  003_001  <a id="title_page"></a

print("complete")
country_database = 'ANZ'
aui_m_tickers = ['auselur', 'aunerlur', 'aunerlrl', 'aunerlrp', 'aunerlrd']
hv_tb_au_003_001_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_003_001_m)
#print(hv_tb_au_003_001_m.columns)
# auselur unemployment rate monthly
# auselpr participation rate
hv_tb_au_003_001_m.rename(columns={"auselur": "AU Unemployment Rate Monthly SA"}, inplace=True)
hv_tb_au_003_001_m.rename(columns={"aunerlur": "AU Unemployment Rate RM"}, inplace=True)
hv_tb_au_003_001_m.rename(columns={"aunerlrl": "AU Unemployment FT Rate RM"}, inplace=True)
hv_tb_au_003_001_m.rename(columns={"aunerlrp": "AU Unemployment PT Rate RM"}, inplace=True)
hv_tb_au_003_001_m.rename(columns={"aunerlrd": "AU Underemployment Rate RM"}, inplace=True)
#hv_tb_au_003_001_m_g_001 = hv_tb_au_003_001_m.copy()
#hv_tb_au_003_001_m = hv_tb_au_003_001_m.tail(horizon_tb)
#hv_tb_au_003_001_m = hv_tb_au_003_001_m.transpose()
#hv_tb_au_003_001_m.index.names = ['Variable']
## dashboard.to_clipboard()
#print(hv_tb_au_003_001_m)
# dashboard.to_clipboard()
#path_display = tb_au_003_001_m.csv'
#print(path_display)
#hv_tb_au_003_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_003_001_m)
#print("step2")


hv_tb_au_003_001_m_g = hv_tb_au_003_001_m.copy()
hv_tb_au_003_001_m_g_001 = hv_tb_au_003_001_m.copy()

hv_tb_au_003_001_m.index=hv_tb_au_003_001_m.index.date
hv_tb_au_003_001_m = hv_tb_au_003_001_m.tail(horizon_tb)
hv_tb_au_003_001_t1=hv_tb_au_003_001_m.tail(horizon_tb)

hv_tb_au_003_001_m_t = hv_tb_au_003_001_m.transpose()
hv_tb_au_003_001_m_t.index.names = ['Variable']

hv_tb_au_003_001_t1_t = hv_tb_au_003_001_t1.transpose()
hv_tb_au_003_001_t1_t.index.names = ['Variable']


### 001_ AU Unemployment Rate Monthly 003_001 table

############################################################
######Table 1

#####here*******
title_table="au_unemployment_table"
df =hv_tb_au_003_001_t1.copy()
df_transposed = hv_tb_au_003_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_001_m_t_002.png')



### 001_ AU Unemployment Rate Monthly 003_001 graphs

#hv_tb_au_003_001_m_g_001
title_r="AU Unemployment Rate Monthly SA"
y_label="Growth %"
x_label="Growth %"
list_c=["AU Unemployment Rate Monthly SA"]
df1=hv_tb_au_003_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[0], color="darkgreen", linewidth=11, linestyle="-",
        marker='P', markersize=83)
for x,y in zip(g1.index,g1[list_c[0]]):
    label="{:.1f}".format(y)
    plt.annotate(label, # this is the text
    (x,y), # these are the coordinates to position the label
    textcoords="offset points", #how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha="center", weight='bold')
plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

#hv_tb_au_003_001_m_g_002
title_r = "AU Unemployment Rate Monthly SA"
y_label = "Growth %"
x_label = title_r
list_c = ["AU Unemployment Rate Monthly SA"]
df1 = hv_tb_au_003_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s3)
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center',
                 weight="bold")
# plt.axhLine(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ AU labor force employed 003_002 <a id="title_page"></a

#monthly
#ausele Labor force employed
#auselel Labor force employed full time
#auselep Labor force employed part time
aui_m_tickers = ['ausele', 'auselel', 'auselep']
hv_tb_au_003_002_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_003_002_m)
#print(hv_tb_au_003_002_m.columns)
for x in range(len(aui_m_tickers)):
#    print(x)
    variable = str(aui_m_tickers[x])
#    print(variable)
    hv_tb_au_003_002_m[variable] = hv_tb_au_003_002_m[variable].diff(periods=1).round(8)
#    print(hv_tb_au_003_002_m[variable])

hv_tb_au_003_002_m.rename(columns={'ausele': 'AU labor force employed'}, inplace=True)
hv_tb_au_003_002_m.rename(columns={'auselel': 'AU labor force employed full time'}, inplace=True)
hv_tb_au_003_002_m.rename(columns={'auselep': 'AU labor force employed part time'}, inplace=True)
#hv_tb_au_003_002_m_g_001 = hv_tb_au_003_002_m.copy()
#hv_tb_au_003_002_m = hv_tb_au_003_002_m.tail(horizon_tb)
#hv_tb_au_003_002_m = hv_tb_au_003_002_m.transpose()
#hv_tb_au_003_002_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_003_002_m)
#dashboard.to_clipboard()
#hv_tb_au_003_002_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_003_002_m)
#print("step2")


hv_tb_au_003_002_m_g = hv_tb_au_003_002_m.copy()
hv_tb_au_003_002_m_g_001 = hv_tb_au_003_002_m.copy()

hv_tb_au_003_002_m.index=hv_tb_au_003_002_m.index.date
hv_tb_au_003_002_m = hv_tb_au_003_002_m.tail(horizon_tb)
hv_tb_au_003_002_t1=hv_tb_au_003_002_m.tail(horizon_tb)

hv_tb_au_003_002_m_t = hv_tb_au_003_002_m.transpose()
hv_tb_au_003_002_m_t.index.names = ['Variable']

hv_tb_au_003_002_t1_t = hv_tb_au_003_002_t1.transpose()
hv_tb_au_003_002_t1_t.index.names = ['Variable']

### 001_ AU labor force employed 003_002 table

############################################################
######Table 1

#####here*******
title_table="au_labor_force"
df =hv_tb_au_003_002_t1.copy()
df_transposed = hv_tb_au_003_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_002_m_t_002.png')

### 001_ AU labor force employed 003_002 graph

df1 = hv_tb_au_003_002_m_g_001.copy()
df1 = df1.tail(72)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth=11, linestyle="-", marker="P", markersize=s2)
# g1.plot(kind="Line", ax=ax, y=list_c[2], color="darkblue", Linewidth=11, Linestyle="-", marker="D", markersize=s2)
# g1.plot(kind='Line", ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=11, Linestyle="-", marker="X", markersize=s2)
# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, Linestyle="-", marker="s", markersize=s2)
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.0f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 ha='center', weight='bold')
#    size=6
for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle='->'))
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_001.png", bbox_inches='tight')
plt.close()





df1=hv_tb_au_003_002_m_g_001.copy()
df1=df1.tail(36)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[0])
y_label="Index %"
x_label=title_r
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[0], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)

for x,y in zip(g1.index,g1[list_c[1]]):
    label = "(:.0f)".format(y)
    plt.annotate(label, # this is the text
        (x,y), #these are the coordinates to position the label
        textcoords="offset points", # how to position the text
        xytext=(0,18), # distance from text to points (x,y)
        ha='center', weight='bold')
for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_002.png", bbox_inches='tight')
plt.close()


df1=hv_tb_au_003_002_m_g_001.copy()
df1=df1.tail(72)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[1])
y_label="Index %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s2)


for x, y in zip(g1.index, g1[list_c[1]]):
    label = "(:.0f)".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha="center", weight='bold')

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_003.png", bbox_inches='tight')
plt.close()




df1 = hv_tb_au_003_002_m_g_001.copy()
df1 = df1.tail(36)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
y_label = "Index"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s2)

# g1.plot(kind="line", ax=ax, y=list_c[2], color="darkblue", linewidth=l1, linestyle='-',
#         marker='D', markersize=s2)

# g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=l1, linestyle='-',
#         marker='X', markersize=s2)

# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle='-',
#         marker='s', markersize=s2)

for x, y in zip(g1.index, g1[list_c[1]]):
    label = "(:.0f)".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha="center", weight='bold')

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_004.png", bbox_inches='tight')
plt.close()



#hv_tb_au_003_002_m_g_005
df1 = hv_tb_au_003_002_m_g_001.copy()
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=11, linestyle='-', marker='P', markersize=s2)
# g1.plot(kind='Line', ax=ax, y=list_c[2], color="darkblue", linewidth= L1, Linestyle="-", marker='D', markersize=s2)
# g1.plot(kind='Line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", Linewidth= L1, Linestyle='-', marker="X", markersize=s2)
# g1.plot(kind="Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-', marker='s', markersize=s2)
for x, y in zip(g1.index, g1[list_c[2]]):
    label = "{:.0f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 ha='center', weight='bold',
                 size=6)

for series_name in list_c[2:3]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_005.png", bbox_inches="tight")

plt.close()

print('a')

df1 = hv_tb_au_003_002_m_g_001.copy()
df1 = df1.tail(36)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[2])
y_label = "Index"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s2)

# g1.plot(kind="line", ax=ax, y=list_c[2], color="darkblue", linewidth=l1, linestyle='-',
#         marker='D', markersize=s2)

# g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=l1, linestyle='-',
#         marker='X', markersize=s2)

# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle='-',
#         marker='s', markersize=s2)

for x, y in zip(g1.index, g1[list_c[2]]):
    label = "(:.0f)".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x,y)
                 size=6,
                 ha="center", weight='bold')

for series_name in list_c[2:3]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_002_m_g_006.png", bbox_inches='tight')

### 001_ Wage Price Index All sectors 003_003

# QUARTERLY
# # WAGE PRICE INDEX
# # TOTAL HOURLY RATES OF PAY EXCLUDING BONUSES
horizon_tb = 24
aui_m_tickers = ['auswpi', 'auswpiv', 'auswpig', 'auneht', 'aunehtv', 'aunehtu', 'ausww', 'auswwlt', 'auswwlr']
hv_tb_au_003_003_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_003_003_q)
#print(hv_tb_au_003_003_q.columns)
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_003_003_m[variable] = hv_tb_au_003_003_m[variable].pct_change(periods=12, fill_method="bfill").multiply(100).round(3)


# # auswpi wage price index sa all sectors excl bonus
# # auswpiv wage index private sector excl bonus
# # auswpig wage price index public sector sa excl bonus
# # auneht wage price index all sectors incl bonus
# # aunehty wage price index incl bonus private sector
# # aunehtu wage price index incl bonus public sector
# # AVERAGE WEEKLY EARNINGS
# # ausww average weekly earnings
# # auswwlt avg weekly earnings ft total time
# # auswwlr avg weekly earnings ft ordinary time

hv_tb_au_003_003_m.rename(columns={'auswpi': 'AU Wage Price Index All sectors excl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'auswpiv': 'AU Wage Price Index private sectors excl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'auswpig': 'AU Wage Price Index public sectors excl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'auneht': 'AU Wage Price Index All sectors incl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'aunehtv': 'AU Wage Price Index private sectors incl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'aunehtu': 'AU Wage Price Index public sectors incl Bonus Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'ausww': 'AU Avg Weekly Earnings Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'auswwlt': 'AU Avg Weekly Earnings Total time Y/Y'}, inplace=True)
hv_tb_au_003_003_m.rename(columns={'auswwlr': 'AU Avg Weekly Earnings Ordinary time Y/Y'}, inplace=True)
#hv_tb_au_003_003_q_g_001=hv_tb_au_003_003_q.copy()
##[["AU Wage Price Index All sectors excl Bonus Y/Y"]]'date'
##hv_tb_au_003_003_q_g_001.index.name
#hv_tb_au_003_003_q = hv_tb_au_003_003_q.tail(horizon_tb)
#hv_tb_au_003_003_q = hv_tb_au_003_003_q.transpose()
#hv_tb_au_003_003_q.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_au_003_003_q)
#dashboard.to_clipboard()

#hv_tb_au_003_003_q.to_csv (path_display, index = True, header=True)
#print(hv_tb_au_003_003_q)
print("step2")

hv_tb_au_003_003_m_g = hv_tb_au_003_003_m.copy()
hv_tb_au_003_003_m_g_001 = hv_tb_au_003_003_m.copy()

hv_tb_au_003_003_m.index=hv_tb_au_003_003_m.index.date
hv_tb_au_003_003_m = hv_tb_au_003_003_m.tail(horizon_tb)
hv_tb_au_003_003_t1=hv_tb_au_003_003_m.tail(horizon_tb)

hv_tb_au_003_003_m_t = hv_tb_au_003_003_m.transpose()
hv_tb_au_003_003_m_t.index.names = ['Variable']

hv_tb_au_003_003_t1_t = hv_tb_au_003_003_t1.transpose()
hv_tb_au_003_003_t1_t.index.names = ['Variable']

### 001_ Wage Price Index All sectors 003_003  table

############################################################
######Table 1

#####here*******
title_table="au_wage_price_yy_table"
df =hv_tb_au_003_003_t1.copy()
df_transposed = hv_tb_au_003_003_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_003_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_003_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_003_m_t_002.png')




### 001_ Wage Price Index All sectors 003_003  graphs

title_r0="AU Wage Price Index Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["AU Wage Price Index All sectors excl Bonus Y/Y",
        "AU Wage Price Index private sectors excl Bonus Y/Y",
        "AU Wage Price Index public sectors excl Bonus Y/Y"]
df1=hv_tb_au_003_003_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["AU Wage Price Index All sectors excl Bonus Y/Y"], color="darkgreen", linewidth= 11, linestyle="-",marker='P', markersize=s2)
g1.plot(kind="line",ax=ax,y=["AU Wage Price Index private sectors excl Bonus Y/Y"], color="darkblue", linewidth= 11, linestyle='-',marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["AU Wage Price Index public sectors excl Bonus Y/Y"], color="darkred", linewidth= 11, linestyle='-',marker = 'X',markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',marker='s', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle = "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2












title_r="AU Wage Price Index Y/Y"
y_label="Index %"
x_label=title_r
list_c=["AU Wage Price Index All sectors excl Bonus Y/Y",
        "AU Wage Price Index private sectors excl Bonus Y/Y",
        "AU Wage Price Index public sectors excl Bonus Y/Y"]
df1=hv_tb_au_003_003_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, 
        y=["AU Wage Price Index All sectors excl Bonus Y/Y",], 
        color="darkgreen", linewidth= 11, linestyle="-",
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax,
        y=["AU Wage Price Index private sectors excl Bonus Y/Y"],
        color="darkblue", linewidth= 11, linestyle="-",
        marker='D', markersize=s2)
g1.plot(kind="line",ax=ax,
        y=["AU Wage Price Index public sectors excl Bonus Y/Y"], 
        color="darkred", linewidth= 11, linestyle='-',
        marker='X',markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, Linestyle="-",marker='s', markersize=s2)
#
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_003_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

### 001_Wage Price Index All sectors excl Bonus q/q   003_004

########003 004
#WAGE PRICE INDEX
#TOTAL HOURLY RATES OF PAY EXCLUDING BONUSES
horizon_tb=24

aui_m_tickers = ['auswpi', 'auswpiv', 'auswpig',
                 'auneht', 'aunehtv', 'aunehtu', 'ausww', 'auswwlt', 'auswwlr']
hv_tb_au_003_004_q=Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_003_004_q)
#print(hv_tb_au_003_004_q.columns)

for x in range(len(aui_m_tickers)):
     #print(x)
     variable=str(aui_m_tickers[x])
     #print(variable)
     hv_tb_au_003_004_q[variable] = hv_tb_au_003_004_q[variable].pct_change(1).multiply(100).round(3)
     #print(hv_tb_au_003_004_q[variable])

#auswpt wage rpice index sa all secotrs excl bonus
#auswpiv wage index private sector excl. bonus
#auswpig wage price indx public sector sa excl bonus
#auneht wage price index all secotr incl bonus
#aunehty wage price index inlc bonus private sector
#aunehtu wage price index incl bonus public sector
#AVERAGE WEEKLY EARNINGS
#ausww avergae weekly erning
#auswwit avg weekly earnings ft total time
#auswwir avg weekly earnings ft ordinary time
hv_tb_au_003_004_q.rename(columns={"auswpi": "AU Wage Price All excl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswpiv": "AU Wage Price Private excl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswpig": "AU Wage Price Public excl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auneht": "AU Wage Price All incl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"aunehtv": "AU Wage Price Private incl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"aunehtu": "AU Wage Price Public incI-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"ausww": "AU Avg Weekly Earnings Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswwlt": "AU Avg Weekly Earnings Total time Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswwlr":"AU Avg Weekly Earnings Ordinary time Q/Q"}, inplace=True)

hv_tb_au_003_004_q.rename(columns={"auswpi": "AU Wage Price All excl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswpiv": "AU Wage Price Private excl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswpig": "AU Wage Price Public exc1-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auneht": "AU Wage Price All incl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"aunehtv": "AU Wage Price Private incl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"aunehtu": "AU Wage Price Public incl-B Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"ausww": "AU Avg Weekly Earnings Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswwlt": "AU Avg Weekly Earnings Total time Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"auswwlr":"AU Avg Weekly Earnings Ordinary time Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auswpi": "AU Wage Price Index All sectors exct Bonus Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auswpiv": "AU Wage Price Index private sectors exct Bonus Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auswpig": "AU Wage Price Index public sectors excl Bonus Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auneht": "AU Wage Price Index All sectors incl Bonus Q/Q"}, inplace=True)
hv_tb_au_003_004_q.rename(columns={"aunehty": "AU Wage Price Index private sectors incl Bonus Q/Q"}, inplace=True)
#hv_tb_ou_003_004_q.rename(columns={"aunehtu": "AU Wage Price Index public sectors incl Bonus Q/Q"}, inplace=True)
#hv_tb_ou_003_004_q.rename(columns={"ausww": "AU Avg Weekly Earnings Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auswwlt": "AU Avg Weekly Earnings Total time Q/Q"}, inplace=True)
#hv_tb_au_003_004_q.rename(columns={"auswwlr": "AU Avg Weekly Earnings Ordinary time Q/Q"}, inplace=True)

#hv_tb_au_003_004_q = hv_tb_au_003_004_q.tail(horizon_tb)
#hv_tb_au_003_004_q = hv_tb_au_003_004_q.transpose()
#hv_tb_au_003_004_q.index.names = ['Variable']
#dashboard.to_clipboard()#
#print(hv_tb_au_003_004_q)
#dashboard.to_clipboard()
#hv_tb_au_003_004_q.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_003_004_q)
#print("step2")
###### Some comments here
#print(hv_tb_au_003_004_q.columns)

hv_tb_au_003_004_q_g = hv_tb_au_003_004_q.copy()
hv_tb_au_003_004_q_g_001 = hv_tb_au_003_004_q.copy()

hv_tb_au_003_004_q.index=hv_tb_au_003_004_q.index.date
hv_tb_au_003_004_q = hv_tb_au_003_004_q.tail(horizon_tb)
hv_tb_au_003_004_t1=hv_tb_au_003_004_q.tail(horizon_tb)

hv_tb_au_003_004_t = hv_tb_au_003_004_q.transpose()
hv_tb_au_003_004_t.index.names = ['Variable']

hv_tb_au_003_004_t1_t = hv_tb_au_003_004_t1.transpose()
hv_tb_au_003_004_t1_t.index.names = ['Variable']






### 001_Wage Price Index All sectors excl Bonus q/q  003_004 table

############################################################
######Table 1

#####here*******
title_table="au_wage_qq_table"
df =hv_tb_au_003_004_t1.copy()
df_transposed = hv_tb_au_003_004_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_004_q_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_004_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_004_q_t_002.png')


### 001_Wage Price Index All sectors excl Bonus q/q v  graphs

title_r0 = "AU Wage Price Index Q/Q"
title_r = title_r0

y_label = "Index %"
x_label = title_r

list_c = ["AU Wage Price All excl-B Q/Q", "AU Wage Price Private excl-B Q/Q", "AU Wage Price Public excl-B Q/Q"]

df1 = hv_tb_au_003_004_q[list_c]

df1 = df1.tail(60)
g1 = df1.copy()

fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["AU Wage Price All excl-B Q/Q"], color="darkgreen", linewidth=11, linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Wage Price Private excl-B Q/Q"], color="darkblue", linewidth=11, linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Wage Price Public excl-B Q/Q"], color="darkred", linewidth=11, linestyle='-', marker='X', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')

title_r = "title_r"
y_label = "Index %"

x_label = title_r
list_c = ["AU Wage Price All excl-B Q/Q",
"AU Wage Price Private excl-B Q/Q",
"AU Wage Price Public excl-B Q/Q"]

df1 = hv_tb_au_003_004_q[list_c]
df1 = df1.tail(60)
g1 = df1.copy()

fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU Wage Price All excl-B Q/Q"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)

g1.plot(kind='line', ax=ax, y=["AU Wage Price Private excl-B Q/Q"], color="darkblue", linewidth=11, linestyle='-',
        marker="D", markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Wage Price Public excl-B Q/Q"], color="darkred", linewidth=11, linestyle='-',
        marker="X", markersize=s2)

# g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=L1, linestyle='-',
#        marker="s", markersize=s2)

plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use("default")

plt.ylabel(str(y_label), size=parameter3)

plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)

plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.savefig("hv_tb_au_003_004_q_g_001.png", bbox_inches="tight")
plt.close()

plt.close("all")
plt.clf()

plt.cla()
del g1

del df1
del list_c

del fig
del ax

del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["AU Wage Price All excl-B Q/Q",
          "AU Wage Price Private excl-B Q/Q",
          "AU Wage Price Public excl-B Q/Q"]

df1 = hv_tb_au_003_004_q[list_c]
df1 = df1.tail(60)

g1 = df1
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["AU Wage Price All excl-B Q/Q"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)

g1.plot(kind='line', ax=ax, y=["AU Wage Price Private excl-B Q/Q"], color="darkblue", linewidth=11, linestyle='-',
        marker='D', markersize=s2)

g1.plot(kind='line', ax=ax, y=["AU Wage Price Public excl-B Q/Q"], color="darkred", linewidth=11, linestyle='-',
        marker='X', markersize=s2)

# g1.plot(kind="Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=L1, linestyle="-",
#        marker='s', markersize=s2)

plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')

plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)

plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)

plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()

ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_004_q_g_001z.png", bbox_inches='tight')

plt.close()
plt.close('all')

plt.clf()
plt.cla()

del g1
del df1

del list_c
del fig

del ax
del ax2

### 001_AU Participation Rate NS 003_005_m

aui_m_tickers = ['aunelat', 'aunela1', 'aunela2', 'aunela3', 
                 'aunela4', 'aunela5', 'aunela6', 'aunela7', 'aunela8']
hv_tb_au_003_005_m = Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_003_005_m)
#print(hv_tb_au_003_005_m.columns)
hv_tb_au_003_005_m.rename(columns={'aunelat': 'AU Participation Rate NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela1': 'AU PR 15-19 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela2': 'AU PR 19-24 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela3': 'AU PR 25-34 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela4': 'AU PR 35-44 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela5': 'AU PR 45-55 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela6': 'AU PR 55-59 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela7': 'AU PR 60-64 NSA'}, inplace=True)
hv_tb_au_003_005_m.rename(columns={'aunela8': 'AU PR 65+ NSA'}, inplace=True)
#hv_tb_au_003_005_m_g_001 = hv_tb_au_003_005_m.copy()
#hv_tb_au_003_005_m = hv_tb_au_003_005_m.tail(horizon_tb)
#hv_tb_au_003_005_m hv_tb_au_003_005_m.transpose()
#hv_tb_au_003_005_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_003_005_m)
#dashboard.to_clipboard()

#hv_tb_au_003_005_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_003_005_m)
#print("step2")


hv_tb_au_003_005_m_g = hv_tb_au_003_005_m.copy()
hv_tb_au_003_005_m_g_001 = hv_tb_au_003_005_m.copy()

hv_tb_au_003_005_m.index=hv_tb_au_003_005_m.index.date
hv_tb_au_003_005_m = hv_tb_au_003_005_m.tail(horizon_tb)
hv_tb_au_003_005_t1=hv_tb_au_003_005_m.tail(horizon_tb)

hv_tb_au_003_005_m_t = hv_tb_au_003_005_m.transpose()
hv_tb_au_003_005_m_t.index.names = ['Variable']

hv_tb_au_003_005_t1_t = hv_tb_au_003_005_t1.transpose()
hv_tb_au_003_005_t1_t.index.names = ['Variable']


### 001_AU Participation Rate 003_005_m table

############################################################
######Table 1

#####here*******
title_table="au_participation_table"
df =hv_tb_au_003_005_t1.copy()
df_transposed = hv_tb_au_003_005_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_005_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_005_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_005_m_t_002.png')




### 001_AU Participation Rate 003_005_m graph




title_r = "Participation"
y_label = "Index %"
x_label = title_r
list_c=hv_tb_au_003_005_m.columns.tolist()
df1 = hv_tb_au_003_005_m[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
# title_r = str(list_c[0])
# _label = "Index %"
# _label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="black", linewidth=l1, linestyle='-', marker='.', markersize=s2)
# g1.plot(kind='line', ax=ax, y=list_c[8], color="darkblue", linewidth=L1, linestyle='', marker='D', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=L1, linestyle='-', marker='X', markersize=s2)
# g.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=L1, linestyle='-', marker='s', markersize=s2)
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=6,
                 ha='center', weight='bold')
for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))
# plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_005_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()

title_r = "Participation"
y_label = "Index %"
x_label = title_r
list_c=hv_tb_au_003_005_m.columns.tolist()
df1 = hv_tb_au_003_005_m[list_c]
df1 = df1.tail(36)
g1 = df1.copy()

fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="black", linewidth=l1, linestyle='-', marker='.', markersize=s2)


#g1.plot(kind='line', ax=ax, y=list_c[0], color="black", linewidth=11, linestyle='-', marker='P', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=list_c[8], color="darkblue", linewidth=11, linestyle="-", marker='D', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=11, linestyle="-", marker='X', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth=11, linestyle="-", marker='s', markersize=s2)
#
for x,y in zip(g1.index,g1[list_c[0]]):
    label = "{:.2f}".format(y)
    plt.annotate(label,  # this is the text
        (x,y),  # these are the coordinates to position the label
        textcoords="offset points",  # how to position the text
        xytext=(0,18),  # distance from text to points (x,y)
        size=6,
        ha='center', weight='bold')

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    #print(last_y_value)
    plt.annotate(f' {series_name}', xy=(g1.index.max(), last_y_value),
        xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

#plt.axhline(8, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_005_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c

### 001_AU AU Total Hours Worked SA 003_006

aui_m_tickers = ['auswh', 'auswha', 'auswhp',]
hv_tb_au_003_006_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_003_006_m)
#print(hv_tb_au_003_006_m.columns)
hv_tb_au_003_006_m.rename(columns={"auswh": "AU Total Hours Worked SA"}, inplace=True)
hv_tb_au_003_006_m.rename(columns={"auswha": "AU Total Hours Worked FT SA"}, inplace=True)
hv_tb_au_003_006_m.rename(columns={"auswhp": "AU Total Hours Worked PT SA"}, inplace=True)
#hv_tb_au_003_006_m_g_001 = hv_tb_au_003_006_m.copy()
#h#v_tb_au_003_006_m = hv_tb_au_003_006_m.tail(horizon_tb)
#h#v_tb_au_003_006_m = hv_tb_au_003_006_m.transpose()
#h#v_tb_au_003_006_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_003_006_m)
#dashboard.to_clipboard()

#hv_tb_au_003_006_m.to_csv (path_display, index = True, header = True)
#print(hv_tb_au_003_006_m)



hv_tb_au_003_006_m_g = hv_tb_au_003_006_m.copy()
hv_tb_au_003_006_m_g_001 = hv_tb_au_003_006_m.copy()

hv_tb_au_003_006_m.index=hv_tb_au_003_006_m.index.date
hv_tb_au_003_006_m = hv_tb_au_003_006_m.tail(horizon_tb)
hv_tb_au_003_006_t1=hv_tb_au_003_006_m.tail(horizon_tb)

hv_tb_au_003_006_m_t = hv_tb_au_003_006_m.transpose()
hv_tb_au_003_006_m_t.index.names = ['Variable']

hv_tb_au_003_006_t1_t = hv_tb_au_003_006_t1.transpose()
hv_tb_au_003_006_t1_t.index.names = ['Variable']


### 001_AU AU Total Hours Worked 003_006  table

############################################################
######Table 1

#####here*******
title_table="au_hours_worked"
df =hv_tb_au_003_006_t1.copy()
df_transposed = hv_tb_au_003_006_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_003_006_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_003_006_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_003_006_m_t_002.png')




### 001_AU AU Total Hours Worked 003_006 graphs 

df1 = hv_tb_au_003_006_m_g_001.copy()
df1 = df1.tail(60)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
# y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkorange", linewidth=11, linestyle='-',
        marker='P', markersize=s2)

for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f'({series_name})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))
# plt.axhline(6, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_006_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

df1 = hv_tb_au_003_006_m_g_001.copy()
df1 = df1.tail(60)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[1])
# y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="darkorange", linewidth=11, linestyle='-',
        marker='P', markersize=s2)

for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f'({series_name})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))
# plt.axhline(6, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_006_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig



df1 = hv_tb_au_003_006_m_g_001.copy()
df1 = df1.tail(60)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[2])
# y_label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkorange", linewidth=11, linestyle='-',
        marker='P', markersize=s2)

for series_name in list_c[2:3]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f'({series_name})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))
# plt.axhline(6, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_006_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig




### 001_AU AU Total Hours Worked SA 003 007

aui_m_tickers = ['auswh', 'auswha', 'auswhp',]
hv_tb_au_003_006_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_003_006_m)
#print(hv_tb_au_003_006_m.columns)
hv_tb_au_003_006_m.rename(columns={"auswh": "AU Total Hours Worked SA"}, inplace=True)
hv_tb_au_003_006_m.rename(columns={"auswha": "AU Total Hours Worked FT SA"}, inplace=True)
hv_tb_au_003_006_m.rename(columns={"auswhp": "AU Total Hours Worked PT SA"}, inplace=True)
#hv_tb_au_003_006_m_g_001 = hv_tb_au_003_006_m.copy()
#h#v_tb_au_003_006_m = hv_tb_au_003_006_m.tail(horizon_tb)
#h#v_tb_au_003_006_m = hv_tb_au_003_006_m.transpose()
#h#v_tb_au_003_006_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_003_006_m)
#dashboard.to_clipboard()

#hv_tb_au_003_006_m.to_csv (path_display, index = True, header = True)
#print(hv_tb_au_003_006_m)



hv_tb_au_003_006_m_g = hv_tb_au_003_006_m.copy()
hv_tb_au_003_006_m_g_001 = hv_tb_au_003_006_m.copy()

hv_tb_au_003_006_m.index=hv_tb_au_003_006_m.index.date
hv_tb_au_003_006_m = hv_tb_au_003_006_m.tail(horizon_tb)
hv_tb_au_003_006_t1=hv_tb_au_003_006_m.tail(horizon_tb)

hv_tb_au_003_006_m_t = hv_tb_au_003_006_m.transpose()
hv_tb_au_003_006_m_t.index.names = ['Variable']

hv_tb_au_003_006_t1_t = hv_tb_au_003_006_t1.transpose()
hv_tb_au_003_006_t1_t.index.names = ['Variable']






### 001_AU AU Total Hours Worked SA grapogs

print("step2")

df1=hv_tb_au_003_006_m_g_001.copy()
df1=df1.tail(66)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[0])
#y_Label="Index %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="darkgreen", linewidth= l1, linestyle='-',marker='x', markersize=s2)
#g1.plot(kind='line', ax=ax, y=list_c[8], color="darkblue", Linewidth= 11, Linestyle'-',
#marker='D', markersize=s2)
#1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth= L1, Linestyle='-',
#marker="X", markersize=s2)
##g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= Li, linestyle='-',
#marker="s", markersize=s2)
#
for series_name in list_c[0:1]:
    last_y_value = g1 [series_name] [-1]
    #print(Last_y_value)
    plt.annotate(f'(series_name)', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))
#pLt.axhline (6, color='black', Lw=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_007_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig



df1=hv_tb_au_003_006_m_g_001.copy()
df1=df1.tail(66)
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[1])
#y_label="Index %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[1], color="darkorange", linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
#g1.plot(kind='line', ax=ax, y=List_c[2], color="darkblue", Linewidth= L1, Linestyle='-',
#marker='D', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth= 11, linestyle="-',marker="X", markersize=s2)
##g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", linewidth= L1, Linestyle="-',marker's', markersize=s2)

for series_name in list_c[1:2]:
    last_y_value = g1 [series_name] [-1]
    #print(Last_y_value)
    pit.annotate(f' (series_name)', xy=(g1.index.max(), last_y_value),
    xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))
#pit.axhline(0, color='black', Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_007_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


df1 = hv_tb_au_003_006_m_g_001
df1 = df1.tail(60)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[2])
# y_Label = "Index %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[2], color="darkblue", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
# g1.plot(kind='line', ax=ax, y=list_c[2], color="darkblue", linewidth=11, linestyle,
#         marker='D', markersize=s2)
# g1.plot(kind="line', ax=ax, y=["CPI Headline YY NSA RBA Previous"], color="darkred", linewidth=L1, linestyle="-",
#         marker='X', markersize=s2)
# g1.plot(kind='line', ax=ax, y=["Nan Revolving Credit Outstanding Change SA"], color="darkred", linewidth=L1, linestyle='-',
#         marker='s', markersize=s2)
for series_name in list_c[2:3]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f'({series_name})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_003_007_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')

### 001_AU sentiemnt 004_001

#Wage price index
#Wage cost hourly rate
#Labor force participation
#Unemployment
#Change part time and full time

horizon_tb=24
aui_m_tickers = ['ausvcc', 'ausvcp', 'ausvcd', 'ausvcfl', 'ausvcfn', 'ausvce1', 'ausvce5', 'ausvct']
hv_tb_au_004_001_m=Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_004_001_m)
#print(hv_tb_au_004_001_m.columns)
hv_tb_au_004_001_m.rename(columns={"ausvcc":"Westpac Consumer Sentiment SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvcp": "Westpac Consumer Expectations SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvcd": "Current Condition Index SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvcfl": "Family Finances Last 12 Months SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvcfn": "Family Finances Next 12 Months SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvce1": "Economic Conditions Next 12 Months SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvce5": "Economic Conditions Next 5 Years SA"}, inplace=True)
hv_tb_au_004_001_m.rename(columns={"ausvcc":"Time to Buy Major Household Item SA"}, inplace=True)
#AUSVCC@ANZ Australia: Westpac-Melbourne Inst Consumer Sentiment Index (SA, 100+ Favorable)
#AUSVCFL@ANZ
#AUSVCFN@ANZ
#Australia: Family Finances Last 12 Months (SA, 100+=Favorable)
#Australia: Family Finances Next 12 Months (SA, 100+=Favorable)
#AUSVCE1@ANZ
#AUSVCE5@ANZ
#Australia: Economic Conditions Next 5 Years (SA, 100+ Favorable)
#AUSVCT@ANZ Australia: Time to Buy Major Household Items (SA, 100+ Favorable)
#Australia: Economic Conditions Next 12 Months (SA, 100+=Favorable)
#AUSVCD@ANZ Australia: Current Condition Index (SA, 100+ Favorable)
#AUSVCP@ANZ Australia: Westpac-Melbourne Inst Consumer Expectations Idx (SA, 100+ Favorable)
#hv_tb_au_004_001_m_g_001=hv_tb_au_004_001_m.copy()
#[["Westpac Consumer Sentiment SA"]]
#hv_tb_ou_004_001_m_g_001.index.names = "date"
#hv_tb_au_004_001_m = hv_tb_au_004_001_m.tail(horizon_tb)
#hv_tb_au_004_001_m = hv_tb_au_004_001_m.transpose()
#hv_tb_au_004_001_m.index.names=['Variable']
#dashboard.to_clipboard()
#print(hv_tb_au_004_001_m)
#dashboard.to_clipboard()

#hv_tb_au_004_001_m_g_001.to_csv (path_display, index True, header-True)


hv_tb_au_004_001_m_g = hv_tb_au_004_001_m.copy()
hv_tb_au_004_001_m_g_001 = hv_tb_au_004_001_m.copy()

hv_tb_au_004_001_m.index=hv_tb_au_004_001_m.index.date
hv_tb_au_004_001_m = hv_tb_au_004_001_m.tail(horizon_tb)
hv_tb_au_004_001_t1=hv_tb_au_004_001_m.tail(horizon_tb)

hv_tb_au_004_001_m_t = hv_tb_au_004_001_m.transpose()
hv_tb_au_004_001_m_t.index.names = ['Variable']

hv_tb_au_004_001_t1_t = hv_tb_au_004_001_t1.transpose()
hv_tb_au_004_001_t1_t.index.names = ['Variable']

### 001_AU sentiemnt 004_001 talbe

############################################################
######Table 1

#####here*******
title_table="au_cycle_table"
df =hv_tb_au_004_001_t1.copy()
df_transposed = hv_tb_au_004_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_004_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_004_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_004_001_m_t_002.png')


### 001_AU sentiemnt 004_001 graphs

title_r0="Westpac Consumer Sentiment SA"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["Westpac Consumer Sentiment SA",
        "Westpac Consumer Expectations SA","Current Condition Index SA"]
df1=hv_tb_au_004_001_m_g_001[list_c]                 
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Westpac Consumer Sentiment SA",], color="darkgreen", linewidth= 11, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Westpac Consumer Expectations SA"], color="darkblue",
        linewidth= 11, linestyle='-',marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Current Condition Index SA"], color="darkred", linewidth= 11, linestyle='-',
        marker='X', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= 11, linestyle='-',
#plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_004_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["Westpac Consumer Sentiment SA",
        "Westpac Consumer Expectations SA",
        "Current Condition Index SA"]
df1=hv_tb_au_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Westpac Consumer Sentiment SA",], color="darkgreen", linewidth= 11, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Westpac Consumer Expectations SA"], color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Current Condition Index SA"], color="darkred", linewidth= 11, linestyle='-',
        marker='X', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle="-",marker='s', markersize=s2)
#
#plt.axhline(0, color='black', Lw=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_004_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

### 001_AU ANZ Monthly Consumer Confidence 004_002

aui_m_tickers = ['aunvrmc', 'aunvrm', 'aunvrm6n',
                 'aunvrm7n', 'aunvrm8n', 'aunvrm9n']
#,#
#                 'aunvrmen']
hv_tb_au_004_002_m = Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_004_002_m)
#print(hv_tb_au_004_002_m.columns)
hv_tb_au_004_002_m.rename(columns={'aunvrmc': 'ANZ Monthly Consumer Confidence NSA'}, inplace=True)
hv_tb_au_004_002_m.rename(columns={'aunvrm': 'RM Consumer Confidence NSA'}, inplace=True)
hv_tb_au_004_002_m.rename(columns={'aunvrm6n': 'RM Family Financial Situation NSA'}, inplace=True)
hv_tb_au_004_002_m.rename(columns={'aunvrm7n': 'RM Australia Future Economics Conditions NSA'}, inplace=True)
hv_tb_au_004_002_m.rename(columns={'aunvrm8n': 'RM Personal Financial Conditions NSA'}, inplace=True)
hv_tb_au_004_002_m.rename(columns={'aunvrm9n': 'RM Perception Next 12 Months NSA'}, inplace=True)
#hv_tb_au_004_002_m.rename(columns={'aunvrmen': 'RM Broader Australian Financial Conditions NSA'}, inplace=True)
#hv_tb_au_004_002_m_g_001 = hv_tb_au_004_002_m.copy()
##[['ANZ Monthly Consumer Confidence NSA']]
##hv_tb_au_004_002_m_g_001.index.name = 'date'
#hv_tb_au_004_002_m = hv_tb_au_004_002_m.tail(horizon_tb)
#hv_tb_au_004_002_m = hv_tb_au_004_002_m.transpose()
#hv_tb_au_004_002_m.index.names = ['Variable']
##dashboard.to_clipboard()
##print(hv_tb_au_004_002_m)
##dashboard.to_clipboard()


#hv_tb_au_004_002_m_g_001.to_csv(path_display, index=True, header=True)


hv_tb_au_004_002_m_g = hv_tb_au_004_002_m.copy()
hv_tb_au_004_002_m_g_001 = hv_tb_au_004_002_m.copy()

hv_tb_au_004_002_m.index=hv_tb_au_004_002_m.index.date
hv_tb_au_004_002_m = hv_tb_au_004_002_m.tail(horizon_tb)
hv_tb_au_004_002_t1=hv_tb_au_004_002_m.tail(horizon_tb)

hv_tb_au_004_002_m_t = hv_tb_au_004_002_m.transpose()
hv_tb_au_004_002_m_t.index.names = ['Variable']

hv_tb_au_004_002_t1_t = hv_tb_au_004_002_t1.transpose()
hv_tb_au_004_002_t1_t.index.names = ['Variable']



### 001_AU ANZ Monthly Consumer Confidence 004_002 table

############################################################
######Table 1

#####here*******
title_table="au_consumer_mm_table"
df =hv_tb_au_004_002_t1.copy()
df_transposed = hv_tb_au_004_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_004_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_004_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_004_002_m_t_002.png')


### 001_AU ANZ Monthly Consumer Confidence 004_002 graphs

title_r0="ANZ Monthly Consumer Confidence NSA"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["ANZ Monthly Consumer Confidence NSA",
        "RM Consumer Confidence NSA",
        "RM Family Financial Situation NSA"]
df1=hv_tb_au_004_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["ANZ Monthly Consumer Confidence NSA",], color="darkgreen", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["RM Consumer Confidence NSA"], color="darkblue", linewidth= l1,  linestyle='-',
        marker='D',markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_004_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["ANZ Monthly Consumer Confidence NSA",
"RM Consumer Confidence NSA",
"RM Family Financial Situation NSA"]

df1=hv_tb_au_004_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["ANZ Monthly Consumer Confidence NSA",], color="darkgreen", linewidth= l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax,y=["RM Consumer Confidence NSA"], color="darkblue", linewidth= l1,  linestyle='-',
        marker='D',markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_004_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

### 001_AU Retail Turnover 005_001

aui_m_tickers = ['austrs', 'austrsf', 'austrsh', 
                 'austrsa', 'austrsd', 'austrso', 'austrss']
hv_tb_au_005_001_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_005_001_m)
print(hv_tb_au_005_001_m.columns)
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
#    print(variable)
    hv_tb_au_005_001_m[variable] = hv_tb_au_005_001_m[variable].pct_change(12).multiply(100).round(1)
#    print(hv_tb_au_005_001_m[variable])

hv_tb_au_005_001_m.rename(columns={"austrs": "AU Retail Turnover SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrsf": "AU Retail Food SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrsh": "AU Retail HH Goods SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrsa": "AU Retail Clothing SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrsd": "AU Retail Department Stores SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrso": "AU Retail Other SA"}, inplace=True)
hv_tb_au_005_001_m.rename(columns={"austrss": "AU Retail Cafes SA"}, inplace=True)
#hv_tb_au_005_001_m_g_001 = hv_tb_au_005_001_m.copy()
#hv_tb_au_005_001_m = hv_tb_au_005_001_m.tail(horizon_tb)
#hv_tb_au_005_001_m = hv_tb_au_005_001_m.transpose()
#hv_tb_au_005_001_m.index.names = ['Variable']
### dashboard.to_clipboard()
##print(hv_tb_au_005_001_m)
## dashboard.to_clipboard()

#hv_tb_au_005_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_au_005_001_m)
#print("step2")


hv_tb_au_005_001_m_g = hv_tb_au_005_001_m.copy()
hv_tb_au_005_001_m_g_001 = hv_tb_au_005_001_m.copy()

hv_tb_au_005_001_m.index=hv_tb_au_005_001_m.index.date
hv_tb_au_005_001_m = hv_tb_au_005_001_m.tail(horizon_tb)
hv_tb_au_005_001_t1=hv_tb_au_005_001_m.tail(horizon_tb)

hv_tb_au_005_001_m_t = hv_tb_au_005_001_m.transpose()
hv_tb_au_005_001_m_t.index.names = ['Variable']

hv_tb_au_005_001_t1_t = hv_tb_au_005_001_t1.transpose()
hv_tb_au_005_001_t1_t.index.names = ['Variable']

### 001_AU Retail Turnover 005_001 table

############################################################
######Table 1

#####here*******
title_table="au_retail_table"
df =hv_tb_au_005_001_t1.copy()
df_transposed = hv_tb_au_005_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_005_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_005_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_005_001_m_t_002.png')


### 001_AU Retail Turnover 005_001 graphs

title_r = "AU Retail Sales Value"
y_label = "Growth %"
x_label = title_r
list_c = "AU Retail Turnover SA"

### 001_AU ip 006_001

aui_m_tickers = ['ausdgv', 'ausdn', 'ausdm', 'ausdmf', 
                 'ausdmc', 'ausdme', 'ausdmm', 'ausdmo', 'ausde']
hv_tb_au_006_001_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_006_001_m)
#print(hv_tb_au_006_001_m.columns)
for x in range(len(aui_m_tickers)):
#    print(x)
    variable = str(aui_m_tickers[x])
#    print(variable)
    hv_tb_au_006_001_m[variable] = hv_tb_au_006_001_m[variable].pct_change(12).multiply(100).round(1)
#    print(hv_tb_au_006_001_m[variable])

hv_tb_au_006_001_m.rename(columns={"ausdgv": "AU IP excl Construction SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdn": "AU IP Mining SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdm": "AU IP Manufacturing SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdmf": "AU IP Food Beverages SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdmc": "AU IP Petroleum SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdme": "AU IP Machinery SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdmm": "AU IP Metals SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausdmo": "AU IP Other Manufacturing SA"}, inplace=True)
hv_tb_au_006_001_m.rename(columns={"ausde": "AU IP Electricity Gas Water SA"}, inplace=True)
#hv_tb_au_006_001_m_g_001 = hv_tb_au_006_001_m.copy()
#hv_tb_au_006_001_m = hv_tb_au_006_001_m.tail(horizon_tb)
#hv_tb_au_006_001_m = hv_tb_au_006_001_m.transpose()
#hv_tb_au_006_001_m.index.names = ['Variable']



hv_tb_au_006_001_m_g = hv_tb_au_006_001_m.copy()
hv_tb_au_006_001_m_g_001 = hv_tb_au_006_001_m.copy()

hv_tb_au_006_001_m.index=hv_tb_au_006_001_m.index.date
hv_tb_au_006_001_m = hv_tb_au_006_001_m.tail(horizon_tb)
hv_tb_au_006_001_t1=hv_tb_au_006_001_m.tail(horizon_tb)

hv_tb_au_006_001_m_t = hv_tb_au_006_001_m.transpose()
hv_tb_au_006_001_m_t.index.names = ['Variable']

hv_tb_au_006_001_t1_t = hv_tb_au_006_001_t1.transpose()
hv_tb_au_006_001_t1_t.index.names = ['Variable']

### 001_AU AU ip 006_001 table


############################################################
######Table 1

#####here*******
title_table="au_ip_table"
df =hv_tb_au_006_001_t1.copy()
df_transposed = hv_tb_au_006_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_006_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_006_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_006_001_m_t_002.png')



### 001_AU "AU ip 006_001 graphs

df1 = hv_tb_au_006_001_m_g_001.copy()
df1 = df1.tail(24)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Growth %"
x_label = title_r
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax,y=list_c[1], color="darkgreen", linewidth= 11, linestyle='-',marker="P", markersize=53)
for x,y in zip(g1.index,g1[list_c[1]]):
    label="{:.1f}".format(y)
    plt.annotate(label, # this is the text                                            
                 (x,y), #these are the coordinates to position the Label
    textcoords="offset points", # how to position the text
    xytext=(0,18), # distance from text to points (x,y)
    size=6,
    ha="center")

for series_name in list_c[1:2]:
    last_y_value = g1 [series_name] [-1]
    
    #print(Last_y_value)
    plt.annotate(f'(series_name)', xy=(g1.index.max(), last_y_value),
    xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_006_001_m_g_002.png", bbox_inches='tight')


### 001_AU  Real GDP SA Q/Q 007_001

aui_m_tickers = ['ausngdpc', 'ausngnpc', 'ausnddc', 'ausncc', 
                 'ausngc', 'ausnhc', 'ausnfc', 'ausnxc', 'ausnmc']
hv_tb_au_007_001_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_007_001_m)
#print(hv_tb_au_007_001_m.columns)
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_007_001_m[variable] = hv_tb_au_007_001_m[variable].pct_change(periods=1, fill_method='bfill').multiply(100).round(1)
    print(hv_tb_au_007_001_m[variable])

hv_tb_au_007_001_m.rename(columns={"ausngdpc": "AU Real GDP SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausngnpc": "AU Gross National Expenditure SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausnddc": "AU Domestic Final Demand SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausncc": "AU Final Consumption Expenditure SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausngc": "AU Expenditure Government SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausnhc": "AU Expenditure Household SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausnfc": "AU Gross Fixed Capital Formation SA Q/Q"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausnxc": "AU Exports G&S SA"}, inplace=True)
hv_tb_au_007_001_m.rename(columns={"ausnmc": "AU Imports G&S SA"}, inplace=True)



hv_tb_au_007_001_m_g = hv_tb_au_007_001_m.copy()
hv_tb_au_007_001_m_g_001 = hv_tb_au_007_001_m.copy()

hv_tb_au_007_001_m.index=hv_tb_au_007_001_m.index.date
hv_tb_au_007_001_m = hv_tb_au_007_001_m.tail(horizon_tb)
hv_tb_au_007_001_t1=hv_tb_au_007_001_m.tail(horizon_tb)

hv_tb_au_007_001_m_t = hv_tb_au_007_001_m.transpose()
hv_tb_au_007_001_m_t.index.names = ['Variable']

hv_tb_au_007_001_t1_t = hv_tb_au_007_001_t1.transpose()
hv_tb_au_007_001_t1_t.index.names = ['Variable']



#hv_tb_au_007_001_m_g_001 = hv_tb_au_007_001_m.copy()
##hv_tb_au_007_001_m_g_001.index.names = 'date'
#hv_tb_au_007_001_m = hv_tb_au_007_001_m.transpose()
#hv_tb_au_007_001_m.index.names = ['Variable']
#h#v_tb_au_007_001_m.tail(horizon_tb)
#
#dashboard.to_clipboard()
#print(hv_tb_au_007_001_m)
#print("step2")
#hv_tb_au_007_001_m_g_001 = hv_tb_au_007_001_m_g_001.tail(40)

#v_tb_au_007_001_m_g_001.to_csv(path_display, index=True, header=True)

### 001_AU  Real GDP SA Q/Q 007_001  table


############################################################
######Table 1

#####here*******
title_table="au_gdp_qq_table"
df =hv_tb_au_007_001_t1.copy()
df_transposed = hv_tb_au_007_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_007_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_007_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_007_001_m_t_002.png')

### 001_AU  Real GDP SA Q/Q 007_001 graphs 


title_r0="AU Real GDP SA Q/Q"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["AU Real GDP SA Q/Q",
        "AU Gross National Expenditure SA Q/Q",
        "AU Domestic Final Demand SA Q/Q"]
df1=hv_tb_au_007_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["AU Real GDP SA Q/Q",], color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Gross National Expenditure SA Q/Q"], color="darkblue", linewidth= l1, linestyle="-",
        marker="D", markersize=s2)
g1.plot(kind='line', ax=ax,y=["AU Domestic Final Demand SA Q/Q"], color="darkred", linewidth= l1, linestyle='-',
        marker="X", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], color="darkred", Linewidth= L1, Linestyle='-',marker='s', markersize=s2)
##pit.axhiine(0, color='black', Lw=1, Linestyle 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_007_001_q_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    "AU Real GDP SA Q/Q",
    "AU Gross National Expenditure SA Q/Q",
    "AU Domestic Final Demand SA Q/Q"]
df1 = hv_tb_au_007_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU Real GDP SA Q/Q"], color="darkgreen", linewidth=l1,
        linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Gross National Expenditure SA Q/Q"], color="darkblue", linewidth=l1, 
        linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["AU Domestic Final Demand SA Q/Q"], color="darkred", linewidth=l1, 
        linestyle='-', marker='X', markersize=s2)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_007_001_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_AU  Real GDP SA YY 007_002

aui_m_tickers = ['ausngdpc', 'ausngnpc', 'ausnddc', 'ausncc',
                 'ausngc', 'ausnhc', 'ausnfc', 'ausnxc', 'ausnmc']
hv_tb_au_007_002_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_007_002_m)
#print(hv_tb_au_007_002_m.columns)
for x in range(len(aui_m_tickers)):
    print(x)
    variable = str(aui_m_tickers[x])
    print(variable)
    hv_tb_au_007_002_m[variable] = hv_tb_au_007_002_m[variable].pct_change(4).multiply(100).round(1)
    print(hv_tb_au_007_002_m[variable])

hv_tb_au_007_002_m.rename(columns={"ausngdpc": "AU Real GDP SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausngnpc": "AU Gross National Expenditure SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausnddc": "AU Domestic Final Demand SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausncc": "AU Final Consumption Expenditure SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausngc": "AU Expenditure Government SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausnhc": "AU Expenditure Household SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausnfc": "AU Gross Fixed Capital Formation SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausnxc": "AU Exports G&S SA"}, inplace=True)
hv_tb_au_007_002_m.rename(columns={"ausnmc": "AU Imports G&S SA"}, inplace=True)
#hv_tb_au_007_002_m = hv_tb_au_007_002_m.tail(horizon_tb)
#hv_tb_au_007_002_m = hv_tb_au_007_002_m.transpose()
#hv_tb_au_007_002_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_au_007_002_m)
##dashboard.to_clipboard()
#hv_tb_au_007_002_m.to_csv(path_display, index=True, header=True)#
#print(hv_tb_au_007_002_m)
#print("step2")




hv_tb_au_007_002_m_g = hv_tb_au_007_002_m.copy()
hv_tb_au_007_002_m_g_001 = hv_tb_au_007_002_m.copy()

hv_tb_au_007_002_m.index=hv_tb_au_007_002_m.index.date
hv_tb_au_007_002_m = hv_tb_au_007_002_m.tail(horizon_tb)
hv_tb_au_007_002_t1=hv_tb_au_007_002_m.tail(horizon_tb)

hv_tb_au_007_002_m_t = hv_tb_au_007_002_m.transpose()
hv_tb_au_007_002_m_t.index.names = ['Variable']

hv_tb_au_007_002_t1_t = hv_tb_au_007_002_t1.transpose()
hv_tb_au_007_002_t1_t.index.names = ['Variable']

### 001_AU  Real GDP SA YY table 007_002

############################################################
######Table 1

#####here*******
title_table="au_gdp_yy_table"
df =hv_tb_au_007_002_t1.copy()
df_transposed = hv_tb_au_007_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_007_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_007_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_007_002_m_t_002.png')







### 001_AU  hours worked  SA 008_001

#### Hours worked, 
### unit labour costs
country_database="ANZ"





aui_m_tickers = ['ausahw', 'ausahwm',
                 'ausgahwm', 'ausnghw',
                 'ausecu',
                 'ausecuc', 'ausecun', 'ausecucn']
hv_tb_au_008_001_m=Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_008_001_m)
print(hv_tb_au_008_001_m.columns)
hv_tb_au_008_001_m.rename(columns={"ausahw": "AU Hours Worked SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausahwm": "Hours Hours Market Sector SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausgahwm": "Value Added per Hour SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausnghw": "GDP per Hour Worked SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausecu": "Unit Labor Cost Nominal SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausecuc": "Unit Labor Cost Real SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausecun": "Nonfarm Unit Labor Cost Nominal SA"}, inplace=True)
hv_tb_au_008_001_m.rename(columns={"ausecucn": "Nonfarm Unit Labor Cost Real SA"}, inplace=True)
hv_tb_au_008_001_q_g_001=hv_tb_au_008_001_m.copy()
#[["GDP per Hour Worked SA"]]
#hv_tb_au_008_001_m_g_001.index.name = "date"
hv_tb_au_008_001_m = hv_tb_au_008_001_m.tail(horizon_tb)
hv_tb_au_008_001_m = hv_tb_au_008_001_m.transpose()
hv_tb_au_008_001_m.index.names = ['Variable']
#dashboard.to_clipboard()
#dashboard.to_clipboard()

print("step2")

title_r0 = "GDP per Hour Worked SA"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["GDP per Hour Worked SA"]
df1 = hv_tb_au_008_001_q_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["GDP per Hour Worked SA"], color="darkgreen", linewidth=11, linestyle='-',
        marker='P', markersize=s2)
# plt.axhline(0, color='black', lw=1, Linestyle = "dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_001_q_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c

title_r = title_r
y_label = "Index %"
x_label = title_r
list_c = ["GDP per Hour Worked SA"]
# "AU Gross National Expenditure SA Q/Q",
# "AU Domestic Final Demand SA Q/Q"]
df1 = hv_tb_au_008_001_q_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["GDP per Hour Worked SA"], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_001_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r
y_label = "Index %"
x_label = title_r
list_c = ["GDP per Hour Worked SA"]
# "AU Gross National Expenditure SA Q/Q",
# "AU Domestic Final Demand SA Q/Q"]
df1 = hv_tb_au_008_001_q_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["GDP per Hour Worked SA"], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_001_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ AU Compensation Employees 008 002

aui_m_tickers = ["ausncdgv", "ausncda", "ausncdn", "ausncdm", "ausncde", 
                 "ausncdk", "ausncdw", "ausncdtr", "ausncdth", "ausncds", "ausncdc",
                 "ausncdf", "ausncdp", "ausncdpt", "ausncdas", "ausncdpa", "ausncded", 
                 "ausncdh", "ausncdr", "ausncdps"]
hv_tb_au_008_002_m = Haver.data(aui_m_tickers, country_database, dates=True)
print(hv_tb_au_008_002_m)
print(hv_tb_au_008_002_m.columns)
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_008_002_m[variable] = hv_tb_au_008_002_m[variable].pct_change(periods=4, fill_method='bfill').multiply(100).round(1)

hv_tb_au_008_002_m.rename(columns={"ausncdgv": "AU Compensation Employees SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncda": "Compensation Agriculture SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdn": "Compensation Mining SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdm": "Compensation Manufacturing SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncde": "Compensation Elect/Gas/Water services SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdk": "Compensation Construction SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdw": "Compensation Wholesale Trade SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdtr": "Compensation Retail Trade SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdth": "Compensation Accommodation Services SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncds": "Compensation Transport SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdc": "Compensation Information Media SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdf": "Compensation Financial SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdp": "Compensation Real Estate SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdpt": "Compensation Scientific SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdas": "Compensation Administration Serv SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdpa": "Compensation Public Administration SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncded": "Compensation Education SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdh": "Compensation Healthcare SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdr": "Compensation Education SA Y/Y"}, inplace=True)
hv_tb_au_008_002_m.rename(columns={"ausncdps": "Compensation Other Servcs SA Y/Y"}, inplace=True)

#hv_tb_au_008_002_q_g_001 = hv_tb_au_008_002_m.copy()
##[["AU Compensation Employees SA"]]
#hv_tb_au_008_002_m=hv_tb_au_008_002_m.tail(horizon_tb)
#hv_tb_au_008_002_m= hv_tb_au_008_002_m.transpose()
#hv_tb_au_008_002_m.index.names = ['Variable']
##dashboard.to_clipboard()
##hv_tb_ou_008_002_m_g_001=hv_tb_au_008_002_m_g_001.tail(40)

#hv_tb_au_008_002_m_g_001.to_csv (path_display, index True, header-True)
#print(hv_tb_au_008_002_m_a_001)


hv_tb_au_008_002_m_g = hv_tb_au_002_006_m.copy()
hv_tb_au_008_002_m_g_001 = hv_tb_au_008_002_m.copy()

hv_tb_au_008_002_m.index=hv_tb_au_008_002_m.index.date
hv_tb_au_008_002_m = hv_tb_au_008_002_m.tail(horizon_tb)
hv_tb_au_008_002_t1=hv_tb_au_008_002_m.tail(horizon_tb)

hv_tb_au_008_002_m_t = hv_tb_au_008_002_m.transpose()
hv_tb_au_008_002_m_t.index.names = ['Variable']

hv_tb_au_008_002_t1_t = hv_tb_au_008_002_t1.transpose()
hv_tb_au_008_002_t1_t.index.names = ['Variable']

### 001_ AU Compensation Employees tables


############################################################
######Table 1

#####here*******
title_table="au_compensation_yy_table"
df =hv_tb_au_008_002_t1.copy()
df_transposed = hv_tb_au_008_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_008_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_008_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_008_002_m_t_002.png')




### 001_ AU Compensation Employees graphs

title_r0="AU Compensation Employees SA Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["AU Compensation Employees SA Y/Y"]
df1=hv_tb_au_008_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["AU Compensation Employees SA Y/Y",], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["AU Gross National Expenditure SA Q/Q"], color="darkblue", Linewidth= Li, Linestyle="-",   
#marker='D', markersize=s2)
#g1.plot(kind="Line", ax=ax, y=["AU Domestic Final Demand SA Q/Q"1, color="darkred", Linewidth= L1, Linestyle="-",
#marker="X", markersize=s2)
#g1.plot(kind="Line', ax=ax, y=["Non Revolving Credit Outstanding Change SA"], 
#color="darkred", Linewidth= L1, Linestyle-'-',  marker='s', markersize=s2)
#plt.axhline(0, color="black", Lw=1,Linestyle 'dashed", alpha-0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size= parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_002_a_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1


title_r = title_r
y_label = "Index %"
x_label = title_r
list_c = ["AU Compensation Employees SA Y/Y",]
df1 = hv_tb_au_008_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU Compensation Employees SA Y/Y"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)
# plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_002_q_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ AU Compensation Employeesqq <a id="title_page"></a 

aui_m_tickers = ["ausncdgv", "ausncda", 
                 "ausncdn", "ausncdm", "ausncde",
                 "ausncdk", "ausncdw",
                 "ausncdtr", "ausncdth",
                 "ausncds", "ausncdc", 
                 "ausncdf", "ausncdp", "ausncdpt",
                 "ausncdas", "ausncdpa", "ausncded",
                 "ausncdh", "ausncdr", "ausncdps"]
hv_tb_au_008_003_m = Haver.data(aui_m_tickers, country_database, dates=True)
#print(hv_tb_au_008_003_m)
#print(hv_tb_au_008_003_m.columns)
for x in range(len(aui_m_tickers)):
    variable=str(aui_m_tickers[x])
    hv_tb_au_008_003_m[variable] = hv_tb_au_008_003_m[variable].pct_change(1).multiply(100).round(1)


hv_tb_au_008_003_m.rename(columns={"ausncdgv":"AU Compensation Employees SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncda":"Compensation Agriculture SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdn":"Compensation Mining SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdm":"Compensation Manufacturing SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncde":"Compensation Elect/Gas/Water services SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdk":"Compensation Construction SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdw":"Compensation Wholesale Trade SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdtr":"Compensation Retail Trade SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdth":"Compensation Accommodation Services SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncds":"Compensation Transport SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdc":"Compensation Information Media SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdf":"Compensation Financial SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdp":"Compensation Real Estate SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdpt":"Compensation Scientific SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdas":"Compensation Administration Serv SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdpa":"Compensation Public Administration SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncded":"Compensation Education SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdh":"Compensation Healthcare SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdr":"Compensation Education SA Q/Q"}, inplace=True)
hv_tb_au_008_003_m.rename(columns={"ausncdps":"Compensation Other Servcs SA Q/Q"}, inplace=True)
#hv_tb_au_008_003_m_g_001 = hv_tb_au_008_003_m.copy()
##hv_tb_au_008_003_m_g_001.index.name = 'date'
#hv_tb_au_008_003_m = hv_tb_au_008_003_m.tail(horizon_tb)
#hv_tb_au_008_003_m = hv_tb_au_008_003_m.transpose()
#hv_tb_au_008_003_m.index.names = ['Variable']
#dashboard.to_clipboard()


hv_tb_au_008_003_m_g = hv_tb_au_008_003_m.copy()
hv_tb_au_008_003_m_g_001 = hv_tb_au_008_003_m.copy()

hv_tb_au_008_003_m.index=hv_tb_au_008_003_m.index.date
hv_tb_au_008_003_m = hv_tb_au_008_003_m.tail(horizon_tb)
hv_tb_au_008_003_t1=hv_tb_au_008_003_m.tail(horizon_tb)

hv_tb_au_008_003_m_t = hv_tb_au_008_003_m.transpose()
hv_tb_au_008_003_m_t.index.names = ['Variable']

hv_tb_au_008_003_t1_t = hv_tb_au_008_003_t1.transpose()
hv_tb_au_008_003_t1_t.index.names = ['Variable']





### 001_ AU Compensation Employeesqq table


############################################################
######Table 1

#####here*******
title_table="au_compensation_qq_table"
df =hv_tb_au_008_003_t1.copy()
df_transposed = hv_tb_au_008_003_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_008_003_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_008_003_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_008_003_m_t_002.png')



### 001_ AU Compensation Employeesqq grapghs

title_r0 = "AU Compensation Employees SA Q/Q"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["AU Compensation Employees SA Q/Q",]
df1 = hv_tb_au_008_003_m_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU Compensation Employees SA Q/Q"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_003_q_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["AU Compensation Employees SA Q/Q",]
df1 = hv_tb_au_008_003_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["AU Compensation Employees SA Q/Q"], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_008_003_q_g_001z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c

### 001_ AU AU HH Spending <a id="title_page"></a 

aui_m_tickers = ["auwncpi", "auwncdi", 
                 "auwncni", "auwncgi", "auwncsi"]
hv_tb_au_009_001_m = Haver.data(aui_m_tickers, country_database, dates=True)

for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_009_001_m[variable] = hv_tb_au_009_001_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_009_001_m.rename(columns={"auwncpi": "AU HH Spending WDA"}, inplace=True)
hv_tb_au_009_001_m.rename(columns={"auwncdi": "AU HH Spending discretionary WDA"}, inplace=True)
hv_tb_au_009_001_m.rename(columns={"auwncni": "AU HH Spending nondiscretionary WDA"}, inplace=True)
hv_tb_au_009_001_m.rename(columns={"auwncgi": "AU HH Spending goods WDA"}, inplace=True)
hv_tb_au_009_001_m.rename(columns={"auwncsi": "AU HH Spending services WDA"}, inplace=True)
#hv_tb_au_009_001_m_g_001 = hv_tb_au_009_001_m.copy()
## ["AU Compensation Employees SA"]
## hv tb au 008 003 mg 001.index.name = 'date'
#hv_tb_au_009_001_m = hv_tb_au_009_001_m.tail(horizon_tb)
#hv_tb_au_009_001_m = hv_tb_au_009_001_m.transpose()
#hv_tb_au_009_001_m.index.names = ['Variable']
## dashboard.to_clipboard()
#print(hv_tb_au_009_001_m)


hv_tb_au_009_001_m_g = hv_tb_au_009_001_m.copy()
hv_tb_au_009_001_m_g_001 = hv_tb_au_009_001_m.copy()

hv_tb_au_009_001_m.index=hv_tb_au_009_001_m.index.date
hv_tb_au_009_001_m = hv_tb_au_009_001_m.tail(horizon_tb)
hv_tb_au_009_001_t1=hv_tb_au_009_001_m.tail(horizon_tb)

hv_tb_au_009_001_m_t = hv_tb_au_009_001_m.transpose()
hv_tb_au_009_001_m_t.index.names = ['Variable']

hv_tb_au_009_001_t1_t = hv_tb_au_009_001_t1.transpose()
hv_tb_au_009_001_t1_t.index.names = ['Variable']

### 001_ AU AU HH Spending table


############################################################
######Table 1

#####here*******
title_table="au_hh_spending_table"
df =hv_tb_au_009_001_t1.copy()
df_transposed = hv_tb_au_009_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_009_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_009_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_009_001_m_t_002.png')

### 001_ AU AU HH Spending graph

title_r0 = "AU HH spending"
title_r = title_r0
y_label = "Index %"
x_label = title_r
df1 = hv_tb_au_009_001_m_g_001.copy()
df1 = df1.tail(24)
list_c = df1.columns.tolist()
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[list_c[0]], color="darkgreen", linewidth=11, linestyle='-',
        marker="P", markersize=s2)

for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_009_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "title_r"
y_label = "Index %"
x_label = title_r
df1 = hv_tb_au_009_001_m_g_001.copy()
df1 = df1.tail(24)
list_c = df1.columns.tolist()
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="darkgreen", linewidth=l1, linestyle='-',
        marker="P", markersize=s2)
for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the Label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_009_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
df1 = hv_tb_au_009_001_m_g_001.copy()
df1 = df1.tail(24)
list_c = df1.columns.tolist()
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[list_c[2]], color="darkgreen", linewidth=11, linestyle='',
        marker='p', markersize=s2)
for x, y in zip(g1.index, g1[list_c[2]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 ha='center')
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_009_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001_ AU AU HH saving <a id="title_page"></a 

aui_m_tickers = ["auskhsng", "aunkhsng"]
hv_tb_au_009_002_m = Haver.data(aui_m_tickers, country_database, dates=True)
hv_tb_au_009_002_m.rename(columns={"auskhsng": "AU HH Net Saving SA"}, inplace=True)
hv_tb_au_009_002_m.rename(columns={"aunkhsng": "AU HH Net Saving NSA"}, inplace=True)
#hv_tb_au_009_002_m_g_001 = hv_tb_au_009_002_m.copy()
## ["AU Compensation Employees SA"
## hv_tb_au_008_003_m_g_001.index.name = 'date'
#hv_tb_au_009_002_m=hv_tb_au_009_002_m.tail(horizon_tb)
#hv_tb_au_009_002_m = hv_tb_au_009_002_m.transpose()
#hv_tb_au_009_002_m.tail(horizon_tb)
#hv_tb_au_009_002_m.index.names = ["Variable"]
## dashboard.to_clipboard()
#print(hv_tb_au_009_002_m)
## dashboard.to_clipboard()
#

hv_tb_au_009_002_m_g = hv_tb_au_009_002_m.copy()
hv_tb_au_009_002_m_g_001 = hv_tb_au_009_002_m.copy()

hv_tb_au_009_002_m.index=hv_tb_au_009_002_m.index.date
hv_tb_au_009_002_m = hv_tb_au_009_002_m.tail(horizon_tb)
hv_tb_au_009_002_t1=hv_tb_au_009_002_m.tail(horizon_tb)

hv_tb_au_009_002_m_t = hv_tb_au_009_002_m.transpose()
hv_tb_au_009_002_m_t.index.names = ['Variable']

hv_tb_au_009_002_t1_t = hv_tb_au_009_002_t1.transpose()
hv_tb_au_009_002_t1_t.index.names = ['Variable']

### 001_ AU AU HH Saving talbe

############################################################
######Table 1

#####here*******
title_table="au_saving_mm_table"
df =hv_tb_au_009_002_t1.copy()
df_transposed = hv_tb_au_009_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_au_009_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_au_009_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_au_009_002_m_t_002.png')

### 001_ AU AU HH Saving graph

title_r0= "AU HH Net Saving $"
title_r=title_r0
y_label="Index %"
x_label=title_r
df1=hv_tb_au_009_002_m_g_001.copy()
df1=df1.tail(24)
list_c=df1.columns.tolist()
df1_list=df1.columns.tolist()
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[list_c[0]], color="darkred", linewidth=l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="blue", linewidth=11, linestyle='-',
marker="P", markersize=s2)
for series_name in df1_list[0:2]:
    last_y_value = g1[series_name][-1]
    #print(last_y_value)
    plt.annotate(f'(series_name)', xy=(g1.index.max(), last_y_value),
    xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_009_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1





### 001_ Philips Curve")

print("Philips Curve")
aui_m_tickers = ['auwpcxh', 'auselur']
hv_tb_au_010_001_m = Haver.data(aui_m_tickers, "ANZ", dates=True)
hv_tb_au_010_001_m.index = hv_tb_au_010_001_m.index.floor('D')
aui_m_tickers = ['auwpcxh']
for x in range(len(aui_m_tickers)):
    variable = str(aui_m_tickers[x])
    hv_tb_au_010_001_m[variable] = hv_tb_au_010_001_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
    
hv_tb_au_010_001_m.rename(columns={'auwpcxh': 'AU Exp Monthly CPI ex Vol HT YY SA'}, inplace=True)
hv_tb_au_010_001_m.rename(columns={'auselur': 'AU Unemployment Rate Monthly'}, inplace=True)
hv_tb_au_010_001_m['year'] = hv_tb_au_010_001_m.index.year
hv_tb_au_010_001_m = hv_tb_au_010_001_m.tail(240)
print(hv_tb_au_010_001_m.tail(5))
x = hv_tb_au_010_001_m['AU Unemployment Rate Monthly']
y = hv_tb_au_010_001_m['AU Exp Monthly CPI ex Vol HT YY SA']
t = hv_tb_au_010_001_m['year']
y_label = "core"
x_label = "unemployment"
print(len(x))
print(len(y))




title_r="AU PHILLIPS CURVE CORE VS UNEMPLOYMENT"

df1=hv_tb_au_010_001_m
df1.index= df1.index.date

df1=df1.tail(72)
g1=df1.copy()

fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1['AU Unemployment Rate Monthly'], g1['AU Exp Monthly CPI ex Vol HT YY SA'], c=g1.year, cmap="brg", zorder=2)
plt.plot(g1['AU Unemployment Rate Monthly'], g1['AU Exp Monthly CPI ex Vol HT YY SA'], zorder=1)

#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 8):
    plt.annotate(
        g1.index[line],
        (g1['AU Unemployment Rate Monthly'].iloc[line], g1['AU Exp Monthly CPI ex Vol HT YY SA'].iloc[line]),
        va="top",
        ha='right',
        size=8
    )
x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_010_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()



print("Market services inflation and labour underutilisation")

print("Market services inflation and labour underutilisation")
#aunpcms
#aunudvtt
aui_m_tickers = ['aunpcms', 'aunudvtt']
hv_tb_au_010_001_m=Haver.data(aui_m_tickers, "ANZ", dates=True)
hv_tb_au_010_001_m.index= hv_tb_au_010_001_m.index.floor("D")
aui_m_tickers = ['aunpcms']
for x in range(len(aui_m_tickers)):
    variable=str(aui_m_tickers[x])
    hv_tb_au_010_001_m[variable] = hv_tb_au_010_001_m[variable].pct_change (periods=4, fill_method='bfill').multiply(100).round(3)

hv_tb_au_010_001_m.rename(columns={"aunpcms": "AU Quarterly Services Inflation"}, inplace=True)
hv_tb_au_010_001_m.rename(columns={"aunudvtt": "AU LFS Underutilisation rate Quarterly"}, inplace=True)
hv_tb_au_010_001_m["year"]=hv_tb_au_010_001_m.index.year
hv_tb_au_010_001_m=hv_tb_au_010_001_m.tail(600)
#print(hv_tb_au_010_001_m.tail(5))
# figure
# data
x=hv_tb_au_010_001_m['AU LFS Underutilisation rate Quarterly']
y=hv_tb_au_010_001_m['AU Quarterly Services Inflation']
t= hv_tb_au_010_001_m['year']
y_label="AU Quarterly Services Inflation"
x_label="AU LFS Underutilisation rate Quarterly"
print(len(x))
print(len(y))

title_r="Market services inflation and labour underutilisation"
df1=hv_tb_au_010_001_m.copy()
df1.index= df1.index.date
df1=df1.tail(144)
g1=df1.copy()
fig,ax=plt.subplots (figsize=(10,10))
plt.scatter(g1['AU LFS Underutilisation rate Quarterly'], g1['AU Quarterly Services Inflation'],
c=g1.year, cmap="brg", zorder=2)
plt.plot(g1['AU LFS Underutilisation rate Quarterly'], g1['AU Quarterly Services Inflation'], zorder=1)

# add annotations in every 3 data points with a loop
for line in range(0, g1.shape[0],1):
    plt.annotate(
        g1.index[line],
        (g1['AU LFS Underutilisation rate Quarterly'].iloc[line],
         g1['AU Quarterly Services Inflation'].iloc[line]),
        va='top',
        ha='right',
        size = 8
    )

x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_011_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
print("Market services inflation and labour underemployment")









### 001_ AU philipos curve <a id="title_page"></a 


print("Market services inflation and labour underemployment")
# aunpcms
# aunudrtt
aui_m_tickers = ['aunpcms', 'aunudrtt']
hv_tb_au_010_001_m = Haver.data(aui_m_tickers, "ANZ", dates=True)
hv_tb_au_010_001_m.index = hv_tb_au_010_001_m.index.floor('D')
aui_m_tickers = ['aunpcms']
for x in range(len(aui_m_tickers)):
    variable=str(aui_m_tickers[x])
    hv_tb_au_010_001_m[variable] = hv_tb_au_010_001_m[variable].pct_change(periods=4, fill_method='bfill').multiply(100).round(3)

hv_tb_au_010_001_m.rename(columns={"aunpcms": "AU Quarterly Services Inflation"}, inplace=True)
hv_tb_au_010_001_m.rename(columns={"aunudrtt": "AU LFS Underemployment rate Quarterly"}, inplace=True)
hv_tb_au_010_001_m["year"]=hv_tb_au_010_001_m.index.year
hv_tb_au_010_001_m=hv_tb_au_010_001_m.tail(600)
# print(hv_tb_au_010_001_m.tail(5))
# figure
# data
x=hv_tb_au_010_001_m['AU LFS Underemployment rate Quarterly']
y=hv_tb_au_010_001_m['AU Quarterly Services Inflation']
t= hv_tb_au_010_001_m['year']
y_label="AU Quarterly Services Inflation"
x_label="AU LFS Underemployment rate Quarterly"
print(len(x))
print(len(y))
title_r="Market services inflation and labour Underemployment"
df1=hv_tb_au_010_001_m.copy()
df1.index = df1.index.date
df1=df1.tail(144)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(10,10))
plt.scatter(g1['AU LFS Underemployment rate Quarterly'], g1['AU Quarterly Services Inflation'],
c=g1.year, cmap="brg", zorder=2)
plt.plot(g1['AU LFS Underemployment rate Quarterly'], g1['AU Quarterly Services Inflation'], zorder=1)
#add annotations in every 3 data points with a Loop
for line in range(0, g1.shape[0], 3):
    plt.annotate(
        (g1['AU LFS Underemployment rate Quarterly'].iloc[line], g1['AU Quarterly Services Inflation'].iloc[line]),
        xy=(g1['AU LFS Underemployment rate Quarterly'].iloc[line], g1['AU Quarterly Services Inflation'].iloc[line]),
        va="top",
        ha='right',
        size = 8
    )

x0 = x.iloc[range(len(x)-1)].values
x1 = x.iloc[range(1,len(x))].values
y0 = y.iloc[range(len(y)-1)].values
y1 = y.iloc[range(1,len(y))].values
xpos = (x0+x1)/2
ypos = (y0+y1)/2
xdir = x1-x0
ydir = y1-y0
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_au_012_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()


### 001_ AU heatmap <a id="title_page"></a 



###############heatmap

# # # Analysisis,
#######heatmap
#######heatmap
#######heatmap
#######heatmap
#######heatmap
#######heatmap
#######heatmap

country_database = "ANZ"
# nse series index
aunz_m_tickers = ['aunpc', 'aunpcf', 'aunpcb', 'aunpca', 'aunpch', 'aunpco',
                  "aunph", 'aunpct', 'aunpcc', 'aunpcr', 'aunpcd', 'aunpcif']
hv_tb_aunz_001_001_m=Haver.data(aunz_m_tickers, country_database, dates=True)
print(hv_tb_aunz_001_001_m)
# # all #food#alcohol #clothong#housing#furninshi
# # health#trasnpor#commu#recre#edu#insurance
aunz_m_tickers = ['nznpc', 'nznpcf', 'nznpcb', 'nznpca', 'nznpch', 'nznpco',
                  "nznph", 'nznpct', 'nznpcc', 'nznpcr', 'nznpce', 'nznpcif']
hv_tb_aunz_001_002_m=Haver.data(aunz_m_tickers, country_database, dates=True)
print(hv_tb_aunz_001_002_m)
hv_tb_aunz_001_001_m=pd.concat([hv_tb_aunz_001_001_m, hv_tb_aunz_001_002_m], axis=1, join="outer")

country_database = "ANZ"
horizon_00=120
print("monthly")
aui_m_tickers1 = ['auwncpi', 'auwncgi', 'auwncsi',
                  'austrs', 'auwpc',
                  'aunigi', 'aunigic',
                  'ausvcc', 'ausvcp',
                  'aunvrmc', 'aunvrm', 'ausvcd',
                  'aunelat', 'auselur', 'aunerlur', 'aunerlrd',
                  'auselel', 'auselep', 'auswha', 'auswhp',
                  'aumpc', 'aumpcx','aumpcmg','aumpcms', 
                  'aumpctr', 'aumpcntr', 'ausfm3', 'ausfcxy']

# print(hv_tb_au_000_001_m)
hv_tb_au_000_001_m = Haver.data(aui_m_tickers1, "ANZ", dates=True)
# ausww.annual

aui_m_tickers2 = ['ausngdpc', 'ausdgv', 'ausdn', 'ausdm',
                 'aunpc', 'auspctr',
                 'auswpi', 'auswpiv', 'auswpig', 'ausww', 'auswwlt', 'auswwlr',
                 'ausncdgv',
                 'ausahw', 'ausgahwm',
                 'aunhjn',
                 'aunpcy', 'aunpcxvy', 'aunpcxxy', 'aunpcxmy', 'aunfhddi']

hv_tb_au_000_002_m = Haver.data(aui_m_tickers2, "ANZ", dates=True)
# print(hv_tb_au_000_002_m)
hv_tb_au_000_001_m = pd.concat([hv_tb_au_000_001_m, hv_tb_au_000_002_m], axis=1, join="outer")
au_m_tickers = aui_m_tickers1 + aui_m_tickers2
hv_tb_au_000_001_m = hv_tb_au_000_001_m.fillna(method="bfill")
# hv_tb_au_000_001_m["ausngdpc"] = hv_tb_au_000_001_m["ausngdpc"].pct_change(periods=4, fill_method='bfill').multiply(100).round(3)
# hv_tb_au_000_001_m.rename(columns={"ausngdpc": "Real: GDP"}, inplace=True)
hv_tb_au_000_001_m["Real: GDP YY%"] = hv_tb_au_000_001_m["ausngdpc"].pct_change(periods=12,
                                                                                fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: GDP QQ%"] = hv_tb_au_000_001_m["ausngdpc"].pct_change(periods=3,
                                                                                fill_method='bfill').multiply(100).round(1)
# hv_tb_au_000_001_m.rename(columns={"austrs": "Real: Retail Turnover"}, inplace=True)
hv_tb_au_000_001_m["Real: Retail Turnover YY%"] = hv_tb_au_000_001_m["austrs"].pct_change(periods=12,
                                                                                  fill_method='bfill').multiply(100).round(1)
# hv_tb_au_000_001_m["ausdgv"] = hv_tb_au_000_001_m["ausdgv"].pct_change(periods=12,
#                                                                                  fill_method="bfill").multiply(100).round(3)
hv_tb_au_000_001_m["Real: HH Spending WDA YY%"] = hv_tb_au_000_001_m["auwncpi"].pct_change(periods=12,
                                                                                      fill_method="bfill").multiply(100).round(1)
hv_tb_au_000_001_m["Real: HH Spending Goods YY%"] = hv_tb_au_000_001_m["auwncgi"].pct_change(periods=12,
                                                                                      fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: HH Spending Services YY%"] = hv_tb_au_000_001_m["auwncsi"].pct_change(periods=12,
                                                                                      fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: IP excl Const YY%"] = hv_tb_au_000_001_m["ausdgv"].pct_change(periods=12,
                                                                                  fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: IP Mining YY%"] = hv_tb_au_000_001_m["ausdn"].pct_change(periods=12,
                                                                                fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: IP Manufacturing YY%"] = hv_tb_au_000_001_m["ausdm"].pct_change(periods=12,
                                                                                    fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Real: Hours Worked YY%"] = hv_tb_au_000_001_m["ausahw"].pct_change(periods=12,
                                                                                    fill_method='bfill').multiply(100).round(2)
hv_tb_au_000_001_m["Real: Retail Turnover YY%"] = hv_tb_au_000_001_m["austrs"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: HH Spending WDA YY%"] = hv_tb_au_000_001_m["auwncpi"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: HH Spending Goods YY%"] = hv_tb_au_000_001_m["auwncgi"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: HH Spending Services YY%"] = hv_tb_au_000_001_m["auwncsi"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: IP excl Const YY%"] = hv_tb_au_000_001_m["ausdgv"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: IP Mining YY%"] = hv_tb_au_000_001_m["ausdn"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: IP Manufacturing YY%"] = hv_tb_au_000_001_m["ausdm"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Real: Hours Worked YY%"] = hv_tb_au_000_001_m["ausahw"].pct_change(periods=12, fill_method='bfill').multiply(100).round(2)

hv_tb_au_000_001_m["Real: Value Added per Hour YY%"] = hv_tb_au_000_001_m["ausgahwm"].pct_change(periods=12, fill_method='bfill').multiply(100).round(2)

hv_tb_au_000_001_m.rename(columns={"auselur": "Employment: Unemployment Rate%"}, inplace=True)
hv_tb_au_000_001_m["Employment: Unemployment Rate%"] = hv_tb_au_000_001_m["Employment: Unemployment Rate%"].round(1)

hv_tb_au_000_001_m.rename(columns={"aunerlur": "Employment: Unemployment Rate% RM"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunerlrd": "Employment: Underemployment Rate% RM"}, inplace=True)

hv_tb_au_000_001_m.rename(columns={"aunelat": "Employment: Participation Rate%"}, inplace=True)
hv_tb_au_000_001_m["Employment: Participation Rate%"].round(0)

hv_tb_au_000_001_m["Employment: Employed FT K"] = hv_tb_au_000_001_m["auselel"].diff()
hv_tb_au_000_001_m["Employment: Employed FT K"] = hv_tb_au_000_001_m["Employment: Employed FT K"].round(0)

hv_tb_au_000_001_m["Employment: Employed PT K"] = hv_tb_au_000_001_m["auselep"].diff()
hv_tb_au_000_001_m["Employment: Employed PT K"] = hv_tb_au_000_001_m["Employment: Employed PT K"].round(0)

# hv_tb_au_000_001_m.rename(columns={"auswpiv": "Employment: Wage Price Index private"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpig": "Employment: Wage Price Index public"}, inplace=True)

# hv_tb_au_000_001_m.rename(columns={"ausww": "Employment: Avg Weekly Earnings"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"ausncdgv": "Employment: Compensation Employees"}, inplace=True)

# hv_tb_au_000_001_m.rename(columns={"auswpi": "AU Wage Price All excl-B Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpiv": "AU Wage Price Private excl-B Q/Q"}, inplace=True)

# hv_tb_au_000_001_m.rename(columns={"auswpig": "AU Wage Price Public excl-B Q/Q"}, inplace=True)


hv_tb_au_000_001_m["Employment: Employed FT K"] = hv_tb_au_000_001_m["auselel"].diff()
hv_tb_au_000_001_m["Employment: Employed FT K"] = hv_tb_au_000_001_m["Employment: Employed FT K"].round(0)

hv_tb_au_000_001_m["Employment: Employed PT K"] = hv_tb_au_000_001_m["auselep"].diff()
hv_tb_au_000_001_m["Employment: Employed PT K"] = hv_tb_au_000_001_m["Employment: Employed PT K"].round(0)

# hv_tb_au_000_001_m.rename(columns={"auswpiv": "Employment: Wage Price Index private"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpig": "Employment: Wage Price Index public"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"ausww": "Employment: Avg Weekly Earnings"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"ausncdgv": "Employment: Compensation Employees"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpi": "AU Wage Price All excl-B Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpiv": "AU Wage Price Private excl-B Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswpig": "AU Wage Price Public excl-B Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"ausww": "AU Avg Weekly Earnings Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswwlt": "AU Avg Weekly Earnings Total time Q/Q"}, inplace=True)
# hv_tb_au_000_001_m.rename(columns={"auswwLr": "AU Avg Weekly Earnings Ordinary time Q/Q"}, inplace=True)

hv_tb_au_000_001_m["Employment: Wage Price YY%"] = hv_tb_au_000_001_m["auswpi"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: Wage Price Private YY%"] = hv_tb_au_000_001_m["auswpiv"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: Wage Price Public YY%"] = hv_tb_au_000_001_m["auswpig"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: AWE YY%"] = hv_tb_au_000_001_m["ausww"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: AWE Total YY%"] = hv_tb_au_000_001_m["auswwlt"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: AWE Ordinary YY%"] = hv_tb_au_000_001_m["auswwlr"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: Hours Worked FT YY%"] = hv_tb_au_000_001_m["auswha"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)

hv_tb_au_000_001_m["Employment: Hours Worked PT YY%"] = hv_tb_au_000_001_m["auswhp"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)


#hv_tb_au_003_006_m.rename(columns={"auswha": "AU Total Hours Worked FT SA"}, inplace=True)
#hv_tb_au_003_006_m.rename(columns={"auswhp": "AU Total Hours Worked PT SA"}, inplace=True)

#hv_tb_au_000_001_m.rename(columns={"ausahw": "Real: Hours Worked"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"ausgahwm": "Real: Value Added per Hour"}, inplace=True)

#hv_tb_au_000_001_m.rename(columns={"auwncpi": "Real: Household Spending"}, inplace=True)

hv_tb_au_000_001_m.rename(columns={"ausvcc":"Cycle: Westpac Consumer Sentiment"}, inplace=True)
hv_tb_au_000_001_m["Cycle: Westpac Consumer Sentiment"]=hv_tb_au_000_001_m["Cycle: Westpac Consumer Sentiment"].round(0)

hv_tb_au_000_001_m.rename(columns={"ausvcp": "Cycle: Westpac Consumer Expectations"}, inplace=True)
hv_tb_au_000_001_m["Cycle: Westpac Consumer Expectations"]=hv_tb_au_000_001_m["Cycle: Westpac Consumer Expectations"].round(0)

hv_tb_au_000_001_m.rename(columns={"ausvcd": "Cycle: Westpac Current Condition Index SA"}, inplace=True)
hv_tb_au_000_001_m["Cycle: Westpac Current Condition Index SA"]=hv_tb_au_000_001_m[ "Cycle: Westpac Current Condition Index SA"].round(0)

hv_tb_au_000_001_m.rename(columns={"aunvrmc": "Cycle: ANZ Monthly Consumer Confidence"}, inplace=True)
hv_tb_au_000_001_m["Cycle: ANZ Monthly Consumer Confidence"]=hv_tb_au_000_001_m[ "Cycle: ANZ Monthly Consumer Confidence"].round(0)
hv_tb_au_000_001_m.rename(columns={"aunvrm": "Cycle: RM Consumer Confidence"}, inplace=True)

hv_tb_au_000_001_m["Cycle: RM Consumer Confidence"]=hv_tb_au_000_001_m["Cycle: RM Consumer Confidence"].round(0)


#hv_tb_au_000_001_m.rename(columns={"aunpc": "Price: CPI ALL Groups"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"auspctr": "Price: CPI Trimmed"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpcy":"Price: CPI All Groups NSA YY%"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpcxvy": "Price: CPI Excluding Volatile NSA YY%"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpcxxy": "Price: CPI Tradables NSA YY%"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunpcxmy": "Price: CPI Non Tradables NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpc": "Price: Monthly CPI Headline NSA YY%"}, inplace=True)
#hy to au 000_001 m.rename(columns={"aumpcx": "Price: Monthly CPI ex VOL NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcmg": "Price: Monthly CPI Goods NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcms": "Price: Monthly CPI Services NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpctr": "Price: Monthly CPI Tradeables NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcntr": "Price: Monthly CPI nontradeables NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpc": "Price: Monthly CPI HeadLine NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcx": "Price: Monthly CPI ex Vol NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcmg": "Price: Monthly CPI Goods NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcms": "Price: Monthly CPI Services NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpctr": "Price: Monthly CPI Tradeables NSA YY%"}, inplace=True)
#hv_tb_au_000_001_m.rename(columns={"aumpcntr": "Price: Monthly CPI nontradeables NSA YY%"}, inplace=True)

hv_tb_au_000_001_m["Price: Monthly CPI Headline NSA YY%"] = hv_tb_au_000_001_m["aumpc"].pct_change(periods=12,
                                                                                                   fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Price: Monthly CPI ex Vol NSA YY%"]= hv_tb_au_000_001_m["aumpcx"].pct_change (periods=12,
                                                                                                  fill_method='bfill').multiply (100).round(1)
hv_tb_au_000_001_m["Price: Monthly CPI Goods NSA YY%"] = hv_tb_au_000_001_m["aumpcmg"].pct_change (periods=12,
                                                                                                   fill_method='bfill').multiply (100).round(1)
hv_tb_au_000_001_m["Price: Monthly CPI Services NSA YY%"]= hv_tb_au_000_001_m["aumpcms"].pct_change (periods=12,
                                                                                                     fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m["Price: Monthly CPI Tradeables NSA YY%"]= hv_tb_au_000_001_m["aumpctr"].pct_change (periods=12,
                                                                                                       fill_method='bfill').multiply (100).round(1)
hv_tb_au_000_001_m["Price: Monthly CPI nontradeables NSA YY%"]= hv_tb_au_000_001_m["aumpcntr"].pct_change(periods=12, 
                                                                                                          fill_method='bfill').multiply (100).round(1) 
hv_tb_au_000_001_m["ausfm3"]= hv_tb_au_000_001_m["ausfm3"].pct_change(periods=12,fill_method='bfill').multiply(100).round(1)
hv_tb_au_000_001_m.rename(columns={"ausfm3": "Financial: m3 yy sa"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"ausfcxy": "Financial: credit growth yy"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aunfhddi": "Financial: debt to disposable income nsa quarterly"}, inplace=True)
#unemployment rate
#nad unemples rm,
# added by james









###############heatmap

###############heatmap
###############heatmap
###############heatmap
###############heatmap


#monthly inflation
#rba comm price.
#ip clec constructions, ip mnings, ip manfactirun,
#retail sales values, tinrovers,
hv_tb_au_000_001_m.index=hv_tb_au_000_001_m.index.date
list_c=["Real: GDP YY%",
        "Real: GDP QQ%",
        "Real: HH Spending WDA YY%",
        "Real: HH Spending Goods YY%",
        "Real: HH Spending Services YY%",
        "Real: Retail Turnover YY%",
        "Real: IP excl Const YY%",
        "Real: IP Mining YY%",
        "Real: IP Manufacturing YY%",
        "Real: Hours Worked YY%",
        "Real: Value Added per Hour YY%",
        "Employment: Unemployment Rate%",
        "Employment: Unemployment Rate% RM",
        "Employment: Underemployment Rate% RM",
        "Employment: Participation Rate%",
        "Employment: Employed FT K",
        "Employment: Employed PT K",
        "Employment: Wage Price YY%",
        "Employment: Wage Price Private YY%",
        "Employment: Wage Price Public YY%",
        "Employment: AWE YY%",
        "Employment: AWE Total YY%",
        "Employment: AWE Ordinary YY%",
        "Employment: Hours Worked FT YY%",
        "Employment: Hours Worked PT YY%",
        "Price: CPI All Groups NSA YY%",
        "Price: CPI Excluding Volatile NSA YY%",
        "Price: CPI Tradables NSA YY%",
        "Price: CPI Non Tradables NSA YY%",
        "Price: Monthly CPI Headline NSA YY%",
        "Price: Monthly CPI ex Vol NSA YY%",
        "Price: Monthly CPI Goods NSA YY%",
        "Price: Monthly CPI Services NSA YY%",
        "Price: Monthly CPI Tradeables NSA YY%",
        "Price: Monthly CPI nontradeables NSA YY%",
        "Cycle: Westpac Consumer Sentiment",
        "Cycle: Westpac Consumer Expectations",
        "Cycle: Westpac Current Condition Index SA",
        "Cycle: ANZ Monthly Consumer Confidence",
        "Cycle: RM Consumer Confidence",
        "Financial: m3 yy sa",
        "Financial: credit growth yy",
        "Financial: debt to disposable income nsa quarterly",]

hv_tb_au_000_001_m = hv_tb_au_000_001_m[list_c]
hv_tb_au_000_001_m_c = hv_tb_au_000_001_m.copy()
hv_tb_au_000_001_m_c = hv_tb_au_000_001_m_c.tail(120)
hv_tb_au_000_001_m = hv_tb_au_000_001_m.tail(60)

print(hv_tb_au_000_001_m.shape[0])
print(hv_tb_au_000_001_m.shape[1])

n_time = 36
#width
size1 = 28
#height
size2 = 23
font_size_h = 12
number_vbs = 43
x_sizel = 16
x2_sizel = x_sizel - 4
xlabel_size = 20
title_s = 25

df1=hv_tb_au_000_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    locals() [str(str("data_r")+str(x))] = pd.DataFrame ([df1.iloc[x]])

for x in range(num_rows):#print(x)
    locals()[str(str("vmin_")+str(x))] = hv_tb_au_000_001_m_c.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = hv_tb_au_000_001_m_c.iloc[:,x].max()

print(vmin_0)
print(vmax_0)
#data np.random.random((10,12))
#df=pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue=sns.color_palette("coolwarm")
reversed_red_to_blue=list(reversed (reversed_red_to_blue))
blue_to_red=reversed_red_to_blue
#sns.color_palette ("coolwarm", as_cmap=True)
fig, axes = plt.subplots (number_vbs, 1,  figsize=(size1, size2),  sharex=True,)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=reversed_red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=reversed_red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=reversed_red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=blue_to_red, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r16, cmap=blue_to_red, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r17, cmap=blue_to_red, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r18, cmap=blue_to_red, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r19, cmap=blue_to_red, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r20, cmap=blue_to_red, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r21, cmap=blue_to_red, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r22, cmap=blue_to_red, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r23, cmap=blue_to_red, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r24, cmap=blue_to_red, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r25, cmap=blue_to_red, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r26, cmap=blue_to_red, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r27, cmap=blue_to_red, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r28, cmap=blue_to_red, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r29, cmap=blue_to_red, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r30, cmap=blue_to_red, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r31, cmap=blue_to_red, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r32, cmap=blue_to_red, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r33, cmap=blue_to_red, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r34, cmap=blue_to_red, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r35, cmap=blue_to_red, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r36, cmap=blue_to_red, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r40, cmap=red_to_blue, annot=True, ax=axes[40], cbar=False, vmin=vmin_40, vmax=vmax_40, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r41, cmap=red_to_blue, annot=True, ax=axes[41], cbar=False, vmin=vmin_41, vmax=vmax_41, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r42, cmap=red_to_blue, annot=True, ax=axes[42], cbar=False, vmin=vmin_42, vmax=vmax_42, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    n = (n + 1)

# axes[0].set_xticks([])
# axes[1].set_xticks([])
# axes[1].set_xticks([])

axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=8, Labelrotation=45)
# .set_xticks([])
#lt.set_xticks([])
fig.suptitle("Australia Economic Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "Australia Economic Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('australia_heatmap_001.png', bbox_inches='tight',dpi=200)
plt.savefig('australia_heatmap_001.jpg', bbox_inches='tight',dpi=200)
plt.show()
plt.close()

#Monntjhly Cpi headlines
#Cmponetes of ONTLHY CPI
#MONTOSN ON MOENTS ANNUALEIS
#LBEOEUNRNGY cPu
#rba com cprices
#unemployment
#particiaptins rates
#WAGE
#COMPOENSATION
#GDP
#gap PER HORUS WORERD
#hh soending s
#industrial rpodcutions
#ip mining
#ip manuacturing
#RETAIL SAELS
#westpac ocnusmuer sneitnesn
#ANZ
#ROY MORGAN
#parnetincaiosns
#print(hv_tb_au_000_001_m.columns)
#hv_tb_au_000_001_m_c.to_clipboard()

print("Complete")












###### Forecasts
###### Forecasts
###### Forecasts
###### Forecasts

#print("Complete")
#from PIL import Image
##import kaleido
##image = Image.open('australia_heatmap_001.png")
##image.save('australia_heatmap_001.png',format = 'PNG', compress_level=9)
##image = Image.open('australia_heatmap_001.png')
##image.save("australia_heatmap_001.jpg',format*PNG", compress_level=9)
#print("Complete")
#import plotly.graph_objects as go
#file_path = r'forecasts\au_forecasts.xlsx'
#df_uk=pd.read_excel(file_path, sheet_name='headline_y')
#df=df_uk.copy()
#fig-go.Figure(data=[go.Table(header=dict(values=list(df.columns)), cells-dict(values=df.transpose().values.tolist()))])
#fig.update_layout(autosize=False,width=1600,
#fig.write_image('au_headline_y.jpg')  height=750,)
#file_path = r'\au_forecasts.xlsx"
#df_uk=pd.read_excel(file_path, sheet_name='headline_q')
#df=df_uk.copy()
#fig-go.Figure(data=[go.Table(header=dict(values=list(df.columns)), cells-dict(values=df.transpose().values.tolist()))])
#fig.update_layout(autosize=False, width=1600,
#fig.write_image('au_headline_q.jpg')    fig.update_layout(autosize=False,width=1600, height=750,)
#fig.write_image('au_headline_q.jpg')
#df_uk = pd.read_excel(file_path, sheet_name='trimmed_y')
#df = df_uk.copy()#
#fig = go.Figure(data=[go.Table(header=dict(values=list(df.columns)),
#                                    cells=dict(values=df.transpose().values.tolist()))
#                                    )])###
#fig.update_layout(autosize=False,
#                  width=1600,
#                  height=750,)
#
#fig.write_image('au_trimmed_y.jpg')#
#df_uk = pd.read_excel(file_path, sheet_name='trimmed_q')
#df = df_uk.copy()
#fig = go.Figure(data=[go.Table(header=dict(values=list(df.columns)),
#                                    cells=dict(values=df.transpose().values.tolist()))
#                                    )])
#fig.update_layout(autosize=False,
#                  width=1600,
#                  height=750,)
#fig.write_image('au_trimmed_q.jpg')


### 001_ AU Forecasts <a id="title_page"></a 

###### Forecasts
###### Forecasts
###### Forecasts
###### Forecasts
###### Forecasts



print("Complete")

###paye data
country_database = "ANZ"
aui_m_tickers = ['augp', 'auhc', 'auem', 'auue', 'auwp', 'aupc',
                'auin','aucr','autwi','aupbr']
hv_tb_au_000_001_m=Haver.data(aui_m_tickers, "ANZ", dates=True)
print(hv_tb_au_000_001_m)
hv_tb_au_000_001_m.rename(columns={"augp": "RBA  GDP forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auhc": "RBA  GDP Household Consumption forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auem": "RBA Employment forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auue": "RBA Unemployment forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auwp": "RBA Wage Price Index forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aupc": "RBA CPI forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"auin": "RBA CPI Trimmed mean forecast"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aucr": "RBA assumption cash rate"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"autwi": "RBA assumption trade weighted index"}, inplace=True)
hv_tb_au_000_001_m.rename(columns={"aupbr": "RBA assumption brent crude oil price"}, inplace=True)

df = hv_tb_au_000_001_m.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df.fillna(" ", inplace=True)

#hv_tb_us_000_001_m_g_001=hv_tb_us_000_001_m
#print(hv_tb_us_000_001_m)
#hv_tb_us_000_001_m=hv_tb_us_000_001_m.tail(48)
df = df.transpose()
df.index.names = ['Variable']
#print(hv_tb_us_000_001_m)
#df = df.transpose()
df["Index"] = df.index
#df["Index"] = df.index
column_to_move = "Index"
# Reorder columns
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
print(df)


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=15),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center',
        #columnwidth=[900, 100, 100, 100, 100, 100, 100, 100, 100]
    ),
    # Specify column widths here, adjust values as needed
    # 
)])

fig.update_layout(autosize=False,
                  width=1400,
                  height=500,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_rba_forecast_001.png')

###################Diffusion
###################Diffusion
###################Diffusion


# ### quarterly
m_tickers = ["AUNPCFM", "AUNPCFH", "AUNPFIC", "AUNPFBR", "AUNPFSW", "AUNPFCI",
"AUNPFCI1", "AUNPCF1", "AUNPCF4", "AUNPCF2", "AUNPCF3", "AUNPFO", "AUNPFCS",
"AUNPCFF", "AUNPCFV", "AUNPCFTR", "AUNPCFTF", "AUNPCFG", "AUNPFFS", "AUNPCFO",
"AUNPCFSC", "AUNPCFBN", "AUNPCBC", "AUNPCBJ", "AUNPCB7", "AUNPCB8", "AUNPCB9",
"AUNPCBT", "AUNPCAJ", "AUNPCAV", "AUNPCAK", "AUNPCKM", "AUNPCKW", "AUNPCKC", "AUNPCAA",
"AUNPCAR", "AUNPCHR", "AUNPCHE", "AUNPCHG", "AUNPCHW", "AUNPCHS",
"AUNPCHC", "AUNPCHM", "AUNPCGH", "AUNPCGCF", "AUNPCGT", "AUNPCGJ", "AUNPCGS", "AUNPCGG",
"AUNPCGE", "AUNPCG1", "AUNPCOT", "AUNPCG3", "AUNPCOC", "AUNPCOH", "AUNPCOHS",
"AUNPCMPH", "AUNPCMQ", "AUNPC861", "AUNPC86C", "AUNPCTM", "AUNPCTF", "AUNPCTG",
"AUNPCTA", "AUNPCTO", "AUNPCTU", "AUNPCCX", "AUNPCCT", "AUNPCCAE", "AUNPCCAM",
"AUNPCRBK", "AUNPCRNM", "AUNPCRDA","AUNPCRIA", "AUNPCRES",

"AUNPCRGT", "AUNPCRSP", "AUNPCROS", "AUNPCRPS", "AUNPCRVP", "AUNPCE1", "AUNPCE2",
"AUNPCE3", "AUNPCODL", "AUNPCOZ", "AUNPCOIS"]

print("getting from api")
print("Historical data")

table_h = Haver.data(m_tickers, "ANZ", dates=True)
print(table_h.head(5))

table_h.rename(columns={"aunpcfm":"food_milk"}, inplace=True)
table_h.rename(columns={"aunpcfh": "food_cheese"}, inplace=True)
table_h.rename(columns={"aunpfic": "food_icecream_dairy"}, inplace=True)
table_h.rename(columns={"aunpfbr": "food_bread"}, inplace=True)
table_h.rename(columns={"aunpfsw": "food_cake"}, inplace=True)
table_h.rename(columns={"aunpfci": "food_breakfast_cereal"}, inplace=True)
table_h.rename(columns={"aunpfci1": "food_other_cereal"}, inplace=True)
table_h.rename(columns={"aunpcf1": "food_beef"}, inplace=True)
table_h.rename(columns={"aunpcf4": "food_lamb"}, inplace=True)
table_h.rename(columns={"aunpcf2": "food_pork"}, inplace=True)
table_h.rename(columns={"aunpcf3": "food_poultry"}, inplace=True)
table_h.rename(columns={"aunpfo":"food_other_fresh_meat"}, inplace=True)
table_h.rename(columns={"aunpfcs": "food_fish_seafood"}, inplace=True)
table_h.rename(columns={"aunpcff": "food_fruit"}, inplace=True)
table_h.rename(columns={"aunpcfv":"food_vegetables"}, inplace=True)
table_h.rename(columns={"aunpcftr": "food_restaurant_meals"}, inplace=True)
table_h.rename(columns={"aunpcftf": "food_takeaway"}, inplace=True)
table_h.rename(columns={"aunpcfg":"food_eggs"}, inplace=True)
table_h.rename(columns={"aunpffs": "food_jam"}, inplace=True)
table_h.rename(columns={"aunpcfo": "food_fats_oils"}, inplace=True)

table_h.rename(columns={"aunpcfsc": "food_snacks"}, inplace=True)
table_h.rename(columns={"aunpcfbn": "food_other_food_products"}, inplace=True)
table_h.rename(columns={"aunpcbc": "food_tea_coffee"}, inplace=True)
table_h.rename(columns={"aunpcbj": "food_soft_drinks"}, inplace=True)
table_h.rename(columns={"aunpcb7": "alcohol_spirits"}, inplace=True)
table_h.rename(columns={"aunpcb8": "alcohol_wine"}, inplace=True)
table_h.rename(columns={"aunpcb9": "alcohol_beer"}, inplace=True)
table_h.rename(columns={"aunpcbt": "tobacco"}, inplace=True)
table_h.rename(columns={"aunpcaj": "clothing_men"}, inplace=True)
table_h.rename(columns={"aunpcav": "clothing_women"}, inplace=True)
table_h.rename(columns={"aunpcak": "clothing_infant_children"}, inplace=True)
table_h.rename(columns={"aunpckm": "footwear_men"}, inplace=True)
table_h.rename(columns={"aunpckw": "footwear_women"}, inplace=True)
table_h.rename(columns={"aunpckc": "footwear_infant_children"}, inplace=True)
table_h.rename(columns={"aunpcaa": "clothing_accessories"}, inplace=True)
table_h.rename(columns={"aunpcar": "clothing_services"}, inplace=True)
table_h.rename(columns={"aunpchr": "housing_rents"}, inplace=True)
table_h.rename(columns={"aunpche": "housing_electricity"}, inplace=True)
table_h.rename(columns={"aunpchg": "housing_gas_fuels"}, inplace=True)
table_h.rename(columns={"aunpchw": "housing_water_sewerage"}, inplace=True)
table_h.rename(columns={"aunpchs": "housing_house_purchase"}, inplace=True)
table_h.rename(columns={"aunpchc": "housing_other_housing_property_rates"}, inplace=True)
table_h.rename(columns={"aunpchm": "housing_other_housing_repairs"}, inplace=True)
table_h.rename(columns={"aunpcgh": "household_furniture"}, inplace=True)
table_h.rename(columns={"aunpcgcf": "household_carpets"}, inplace=True)
table_h.rename(columns={"aunpcgt": "household_textiles"}, inplace=True)
table_h.rename(columns={"aunpcgj": "household_major_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgs": "household_small_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgg": "household_glassware"}, inplace=True)
table_h.rename(columns={"aunpcge": "household_tools_garden"}, inplace=True)
table_h.rename(columns={"aunpcg1": "household_supplies_cleaning"}, inplace=True)

table_h.rename(columns={"aunpfcil": "food_other_cereal"}, inplace=True)
table_h.rename(columns={"aunpcf1": "food_beef"}, inplace=True)
table_h.rename(columns={"aunpcf4": "food_lamb"}, inplace=True)
table_h.rename(columns={"aunpcf2": "food_pork"}, inplace=True)
table_h.rename(columns={"aunpcf3": "food_poultry"}, inplace=True)
table_h.rename(columns={"aunpfo": "food_other_fresh_meat"}, inplace=True)
table_h.rename(columns={"aunpfcs": "food_fish_seafood"}, inplace=True)


table_h.rename(columns={"aunpcff": "food_fruit"}, inplace=True)
table_h.rename(columns={"aunpcfv": "food_vegetables"}, inplace=True)
table_h.rename(columns={"aunpcftr": "food_restaurant_meals"}, inplace=True)
table_h.rename(columns={"aunpcftf": "food_takeaway"}, inplace=True)
table_h.rename(columns={"aunpcfg": "food_eggs"}, inplace=True)
table_h.rename(columns={"aunpffs": "food_jam"}, inplace=True)
table_h.rename(columns={"aunpcfo": "food_fats_oils"}, inplace=True)
table_h.rename(columns={"aunpcfsc": "food_snacks"}, inplace=True)
table_h.rename(columns={"aunpcfbn": "food_other_food_products"}, inplace=True)
table_h.rename(columns={"aunpcbc": "food_tea_coffee"}, inplace=True)
table_h.rename(columns={"aunpcbj": "food_soft_drinks"}, inplace=True)
table_h.rename(columns={"aunpcb7": "alcohol_spirits"}, inplace=True)
table_h.rename(columns={"aunpcb8": "alcohol_wine"}, inplace=True)
table_h.rename(columns={"aunpcb9": "alcohol_beer"}, inplace=True)
table_h.rename(columns={"aunpcbt": "tobacco"}, inplace=True)
table_h.rename(columns={"aunpcaj": "clothing_men"}, inplace=True)
table_h.rename(columns={"aunpcav": "clothing_women"}, inplace=True)
table_h.rename(columns={"aunpcak": "clothing_infant_children"}, inplace=True)
table_h.rename(columns={"aunpckm": "footwear_men"}, inplace=True)
table_h.rename(columns={"aunpckw": "footwear_women"}, inplace=True)
table_h.rename(columns={"aunpckc": "footwear_infant_children"}, inplace=True)
table_h.rename(columns={"aunpcaa": "clothing_accessories"}, inplace=True)
table_h.rename(columns={"aunpcar": "clothing_services"}, inplace=True)
table_h.rename(columns={"aunpchr": "housing_rents"}, inplace=True)
table_h.rename(columns={"aunpche": "housing_electricity"}, inplace=True)
table_h.rename(columns={"aunpchg": "housing_gas_fuels"}, inplace=True)
table_h.rename(columns={"aunpchw": "housing_water_sewerage"}, inplace=True)
table_h.rename(columns={"aunpchs": "housing_house_purchase"}, inplace=True)
table_h.rename(columns={"aunpchc": "housing_other_housing_property_rates"}, inplace=True)
table_h.rename(columns={"aunpchm": "housing_other_housing_repairs"}, inplace=True)
table_h.rename(columns={"aunpcgh": "household_furniture"}, inplace=True)
table_h.rename(columns={"aunpcgcf": "household_carpets"}, inplace=True)
table_h.rename(columns={"aunpcgt": "household_textiles"}, inplace=True)
table_h.rename(columns={"aunpcg": "household_major_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgs": "household_small_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgg": "household_glassware"}, inplace=True)
table_h.rename(columns={"aunpcge": "household_tools_garden"}, inplace=True)

table_h.rename(columns={"aunpchm":"housing_other_housing_repairs"}, inplace=True)
table_h.rename(columns={"aunpcgh":"household_furniture"}, inplace=True)
table_h.rename(columns={"aunpcgcf":"household_carpets"}, inplace=True)
table_h.rename(columns={"aunpcgt":"household_textiles"}, inplace=True)
table_h.rename(columns={"aunpcgj":"household_major_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgs":"household_small_hh_appliances"}, inplace=True)
table_h.rename(columns={"aunpcgg":"household_glassware"}, inplace=True)
table_h.rename(columns={"aunpcge":"household_tools_garden"}, inplace=True)
table_h.rename(columns={"aunpcg1":"household_supplies_cleaning"}, inplace=True)
table_h.rename(columns={"aunpcot":"household_supplies_toiletries"}, inplace=True)
table_h.rename(columns={"aunpcg3":"household_supplies_other"}, inplace=True)
table_h.rename(columns={"aunpcoc":"household_services_childcare"}, inplace=True)
table_h.rename(columns={"aunpcoh":"household_servies_hairdressing"}, inplace=True)
table_h.rename(columns={"aunpcohs":"household_other_hh_services"}, inplace=True)
table_h.rename(columns={"aunpcmph":"health_pharmaceutical_products"}, inplace=True)
table_h.rename(columns={"aunpcmq":"health_therapeutic"}, inplace=True)
table_h.rename(columns={"aunpc861":"health_medical_services"}, inplace=True)
table_h.rename(columns={"aunpc86c":"health_dental_services"}, inplace=True)
table_h.rename(columns={"aunpctm":"transportation_private_motor_vehicles"}, inplace=True)
table_h.rename(columns={"aunpctf":"transportation_private_automotive"}, inplace=True)
table_h.rename(columns={"aunpctg":"transportation_private_motor_repair"}, inplace=True)
table_h.rename(columns={"aunpcta":"transportation_private_motor_parts"}, inplace=True)
table_h.rename(columns={"aunpcto":"transportation_private_other_charges"}, inplace=True)
table_h.rename(columns={"aunpctu":"transportation_urban_transport_fares"}, inplace=True)
table_h.rename(columns={"aunpccx":"communication_postal_services"}, inplace=True)
table_h.rename(columns={"aunpcct":"communication_telecommunication"}, inplace=True)
table_h.rename(columns={"aunpccae":"recreation_equipment"}, inplace=True)
table_h.rename(columns={"aunpccam":"recreation_media_services"}, inplace=True)
table_h.rename(columns={"aunpcrbk":"recreation_books"}, inplace=True)
table_h.rename(columns={"aunpcrnm":"recreation_newspapers"}, inplace=True)
table_h.rename(columns={"aunpcrda":"recreation_domestic_holiday"}, inplace=True)
table_h.rename(columns={"aunpcria":"recreation_international_holiday"}, inplace=True)
table_h.rename(columns={"aunpcres":"recreation_sports_equipment"}, inplace=True)
table_h.rename(columns={"aunpcrgt":"recreation_game"}, inplace=True)
table_h.rename(columns={"aunpcrsp":"recreation_sports_participation"}, inplace=True)
table_h.rename(columns={"aunpcros":"recreation_other_recreational"}, inplace=True)
table_h.rename(columns={"aunpcrps":"recreation_pets"}, inplace=True)
table_h.rename(columns={"aunpcrvp":"recreation_veterinary"}, inplace=True)
table_h.rename(columns={"aunpce1":"education_preschool"}, inplace=True)
table_h.rename(columns={"aunpce2":"education_secondary"}, inplace=True)
table_h.rename(columns={"aunpce3":"education_tertiary"}, inplace=True)
table_h.rename(columns={"aunpcodl":"financial_services_deposit"}, inplace=True)
table_h.rename(columns={"aunpcoz":"financial_services_other"}, inplace=True)
table_h.rename(columns={"aunpcois":"insurance"}, inplace=True)


table_h.rename(columns={"aunpcria": "recreation_international_holiday"}, inplace=True)
table_h.rename(columns={"aunpcrsp": "recreation_sports_participation"}, inplace=True)
table_h.rename(columns={"aunpcrgt": "recreation_game"}, inplace=True)
table_h.rename(columns={"aunpcrps": "recreation_pets"}, inplace=True)
table_h.rename(columns={"aunpce1": "education_preschool"}, inplace=True)
table_h.rename(columns={"aunpce2": "education_secondary"}, inplace=True)
table_h.rename(columns={"aunpce3": "education_tertiary"}, inplace=True)
table_h.rename(columns={"aunpcodl": "financial_services_deposit"}, inplace=True)
table_h.rename(columns={"aunpcoz": "financial_services_other"}, inplace=True)
table_h.rename(columns={"aunpcois": "insurance"}, inplace=True)

print(table_h.columns.tolist())









m_tickers=["auncwfi", "auncwfh",
"auncwdp", "auncwfx", "auncwcb", "auncwfz", "auncwcp",
"auncwf1", "auncwf5", "auncwf2", "auncwf3", "auncwf9",
"auncwfa", "auncwfl", "auncwfv", "auncwbw", "auncwbc", "auncwfr",
"auncwfj", "auncwcd", "auncwfn",
"auncwfq", "auncwfg",
"auncwbs", "auncwb7", "auncwb8", "auncwb9", "auncwbt",
"auncwaj", "auncwav", "auncwak", "auncwam", "auncwaw", "auncwac",
"auncwaa", "auncwar", "auncwh", "auncwpe", "auncwpg", "auncwhs",
"auncwhp", "auncwhr", "auncwhf", "auncwgn", "auncwca", "auncwht",
"auncwga", "auncwg2", "auncwgu", "auncwgm", "auncwgy",
"auncwgt", "auncwgk", "auncwgd", "auncwgh", "auncwgo",
"auncwmh", "auncwmt", "auncwmx", "auncwmd", "auncwta",
"auncwts", "auncwtk", "auncwtz", "auncwtv", "auncwtt",
"auncwcx", "auncwcc", "auncwra", "auncwrm", "auncwrb",
"auncwrw", "auncwrq", "auncwrd",
"auncwrf", "auncwre", "auncwro", "auncwrt", "auncwdh",
"auncwrr", "auncwee", "auncwec", "auncweh", "auncwol",
"auncwoo", "auncwoi"]

print("getting from api")
print("Historical data")

table_w=Haver.data(m_tickers, "ANZ", dates=True)
#print(table_h)





table_w.rename(columns={"auncwfi": "food_milk"}, inplace=True)
table_w.rename(columns={"auncwfh": "food_cheese"}, inplace=True)
table_w.rename(columns={"auncwdp": "food_icecream_dairy"}, inplace=True)
table_w.rename(columns={"auncwfx": "food_bread"}, inplace=True)
table_w.rename(columns={"auncwcb": "food_cake"}, inplace=True)
table_w.rename(columns={"auncwfz": "food_breakfast_cereal"}, inplace=True)
table_w.rename(columns={"auncwcp": "food_other_cereal"}, inplace=True)
table_w.rename(columns={"auncwf1": "food_beef"}, inplace=True)
table_w.rename(columns={"auncwf5": "food_lamb"}, inplace=True)
table_w.rename(columns={"auncwf2": "food_pork"}, inplace=True)
table_w.rename(columns={"auncwf3": "food_poultry"}, inplace=True)
table_w.rename(columns={"auncwf9":"food_other_fresh_meat"}, inplace=True)
table_w.rename(columns={"auncwfa": "food_fish_seafood"}, inplace=True)
table_w.rename(columns={"auncwfl": "food_fruit"}, inplace=True)
table_w.rename(columns={"auncwfv": "food_vegetables"}, inplace=True)
table_w.rename(columns={"auncwbw": "food_restaurant_meals"}, inplace=True)
table_w.rename(columns={"auncwbc": "food_takeaway"},inplace=True)
table_w.rename(columns={"auncwfr":"food_eggs"}, inplace=True)
table_w.rename(columns={"auncwfq":"food_jam"}, inplace=True)
table_w.rename(columns={"auncwfg":"food_fats_oils"}, inplace=True)
table_w.rename(columns={"auncwfj":"food_snacks"}, inplace=True)
table_w.rename(columns={"auncwcd":"food_other_food_products"}, inplace=True)
table_w.rename(columns={"auncwfn": "food_tea_coffee"}, inplace=True)
table_w.rename(columns={"auncwbs": "food_soft_drinks"}, inplace=True)
table_w.rename(columns={"auncwb7": "alcohol_spirits"}, inplace=True)
table_w.rename(columns={"auncwb8":"alcohol_wine"}, inplace=True)
table_w.rename(columns={"auncwb9":"alcohol_beer"}, inplace=True)
table_w.rename(columns={"auncwbt": "tobacco"}, inplace=True)
table_w.rename(columns={"auncwaj":"clothing_men"}, inplace=True)
table_w.rename(columns={"auncwav":"clothing_women"}, inplace=True)
table_w.rename(columns={"auncwak":"clothing_infant_children"}, inplace=True)   
table_w.rename(columns={"auncwam":"footwear_men"}, inplace=True)
table_w.rename(columns={"auncwaw": "footwear_women"}, inplace=True)
table_w.rename(columns={"auncwac": "footwear_infant_children"}, inplace=True)


table_w.rename(columns={"auncwfj":"food_snacks"}, inplace=True)
table_w.rename(columns={"auncwcd":"food_other_food_products"}, inplace=True)
table_w.rename(columns={"auncwfn":"food_tea_coffee"}, inplace=True)
table_w.rename(columns={"auncwbs": "food_soft_drinks"}, inplace=True)
table_w.rename(columns={"auncwb7": "alcohol_spirits"}, inplace=True)
table_w.rename(columns={"auncwb8":"alcohol_wine"}, inplace=True)
table_w.rename(columns={"auncwb9":"alcohol_beer"}, inplace=True)
table_w.rename(columns={"auncwbt": "tobacco"}, inplace=True)
table_w.rename(columns={"auncwaj":"clothing_men"}, inplace=True)
table_w.rename(columns={"auncwav":"clothing_women"}, inplace=True)
table_w.rename(columns={"auncwak":"clothing_infant_children"}, inplace=True)
table_w.rename(columns={"auncwam": "footwear_men"}, inplace=True)
table_w.rename(columns={"auncwaw": "footwear_women"}, inplace=True)
table_w.rename(columns={"auncwac": "footwear_infant_children"}, inplace=True)
table_w.rename(columns={"auncwaa":"clothing_accessories"}, inplace=True)
table_w.rename(columns={"auncwar":"clothing_services"}, inplace=True)
table_w.rename(columns={"auncwh": "housing_rents"}, inplace=True)
table_w.rename(columns={"auncwpe": "housing_electricity"}, inplace=True)
table_w.rename(columns={"auncwpg": "housing_gas_fuels"}, inplace=True)
table_w.rename(columns={"auncwhs": "housing_water_sewerage"}, inplace=True)
table_w.rename(columns={"auncwhp": "housing_house_purchase"}, inplace=True)
table_w.rename(columns={"auncwhr":"housing_other_housing_property_rates"}, inplace=True)
table_w.rename(columns={"auncwhf": "housing_other_housing_repairs"}, inplace=True)
table_w.rename(columns={"auncwgn": "household_furniture"}, inplace=True)
table_w.rename(columns={"auncwca": "household_carpets"}, inplace=True)
table_w.rename(columns={"auncwht": "household_textiles"}, inplace=True)
table_w.rename(columns={"auncwga": "household_major_hh_appliances"}, inplace=True)
table_w.rename(columns={"auncwg2": "household_small_hh_appliances"}, inplace=True)
table_w.rename(columns={"auncwgu": "household_glassware"}, inplace=True)
table_w.rename(columns={"auncwgm": "household_tools_garden"}, inplace=True)
table_w.rename(columns={"auncwgy": "household_supplies_cleaning"}, inplace=True)
table_w.rename(columns={"auncwgt": "household_supplies_toiletries"}, inplace=True)
table_w.rename(columns={"auncwgk": "household_supplies_other"}, inplace=True)
table_w.rename(columns={"auncwgd": "household_services_childcare"}, inplace=True)
table_w.rename(columns={"auncwgh": "household_servies_hairdressing"}, inplace=True)
table_w.rename(columns={"auncwgo": "household_other_hh_services"}, inplace=True)
table_w.rename(columns={"auncwmh":"health_pharmaceutical_products"}, inplace=True)
table_w.rename(columns={"auncwmt":"health_therapeutic"}, inplace=True)
table_w.rename(columns={"auncwmx":"health_medical_services"}, inplace=True)
table_w.rename(columns={"auncwmd":"health_dental_services"}, inplace=True)
table_w.rename(columns={"auncwta": "transportation_private_motor_vehicles"}, inplace=True)
table_w.rename(columns={"auncwts": "transportation_private_automotive"}, inplace=True)
table_w.rename(columns={"auncwtk":"transportation_private_motor_repair"}, inplace=True)
table_w.rename(columns={"auncwtz":"transportation_private_motor_parts"}, inplace=True)
table_w.rename(columns={"auncwtv":"transportation_private_other_charges"}, inplace=True)

table_w.rename(columns={"auncwmh":"health_pharmaceutical_products"}, inplace=True)
table_w.rename(columns={"auncwmt": "health_therapeutic"}, inplace=True)
table_w.rename(columns={"auncwmx": "health_medical_services"}, inplace=True)
table_w.rename(columns={"auncwmd":"health_dental_services"}, inplace=True)
table_w.rename(columns={"auncwta": "transportation_private_motor_vehicles"}, inplace=True)

table_w.rename(columns={"auncwts":"transportation_private_automotive"}, inplace=True)
table_w.rename(columns={"auncwtk": "transportation_private_motor_repair"}, inplace=True)
table_w.rename(columns={"auncwtz": "transportation_private_motor_parts"}, inplace=True)
table_w.rename(columns={"auncwtv": "transportation_private_other_charges"}, inplace=True)
table_w.rename(columns={"auncwtt": "transportation_urban_transport_fares"}, inplace=True)
table_w.rename(columns={"auncwcx": "communication_postal_services"}, inplace=True)
table_w.rename(columns={"auncwcc":"communication_telecommunication"}, inplace=True)
table_w.rename(columns={"auncwra": "recreation_equipment"}, inplace=True)
table_w.rename(columns={"auncwrm":"recreation_media_services"}, inplace=True)
table_w.rename(columns={"auncwrb": "recreation_books"}, inplace=True)
table_w.rename(columns={"auncwrw":"recreation_newspapers"}, inplace=True)
table_w.rename(columns={"auncwrq":"recreation_domestic_holiday"}, inplace=True)
table_w.rename(columns={"auncwrd": "recreation_international_holiday"}, inplace=True)       
table_w.rename(columns={"auncwrf": "recreation_sports_equipment"},inplace=True)

table_w.rename(columns={"auncwre": "recreation_game"}, inplace=True)
table_w.rename(columns={"auncwro": "recreation_sports_participation"}, inplace=True)
table_w.rename(columns={"auncwrt": "recreation_other_recreational"},inplace=True)
table_w.rename(columns={"auncwdh": "recreation_pets"}, inplace=True)
table_w.rename(columns={"auncwrr": "recreation_veterinary"}, inplace=True)
table_w.rename(columns={"auncwee": "education_preschool"}, inplace=True)
table_w.rename(columns={"auncwec": "education_secondary"}, inplace=True)
table_w.rename(columns={"auncweh": "education_tertiary"}, inplace=True)
table_w.rename(columns={"auncwol": "financial_services_deposit"}, inplace=True)
table_w.rename(columns={"auncwoo": "financial_services_other"}, inplace=True)
table_w.rename(columns={"auncwoi":"insurance"}, inplace=True)

print(table_w.columns.tolist())
table_w =table_w.apply(lambda x: x / x.sum(), axis=1)
table_w_t=table_w.copy()
table_w_t['Total'] = table_w_t.sum(axis=1)


table_h = table_h.sort_index(axis=1)
table_w = table_w.sort_index(axis=1)


num_columns_h = len(table_h.columns)
num_columns_w = len(table_w.columns)





print(num_columns_h)
print(num_columns_w)

# Convert column names to sets for comparison
columns_df1 = set(table_w.columns)
columns_df2 = set(table_h.columns)

# Check if both DataFrames have the same column names
if columns_df1 == columns_df2:
    print("Both DataFrames have the same column names.")
else:
    # Identify the differences
    not_in_df2 = columns_df1 - columns_df2
    not_in_df1 = columns_df2 - columns_df1

    if not_in_df2:
        print(f"Columns in DataFrame 1 but not in DataFrame 2: {not_in_df2}")

    if not_in_df1:
        print(f"Columns in DataFrame 2 but not in DataFrame 1: {not_in_df1}")

# 'reading_other_reading_material',
# 'transport_public_other_public',

# Columns in DataFrame 1 but not in DataFrame 2: ['cwemo', 'household_furninshing_equipment_nec'}
# Columns in DataFrame 2 but not in DataFrame 1: {'healthcare_goods_medicinal_cannabis'}

table_h1 = table_h.copy()
m_tickers = table_h1.columns.tolist()

for x in range(len(table_h1.columns.tolist())):
    variable = str(m_tickers[x])
    table_h1[(str(variable))] = table_h1[variable].pct_change(periods=4, fill_method="bfill").multiply(100).round(3)




##################################
table_h1_q = table_h.copy()
m_tickers = table_h1_q.columns.tolist()

for x in range(len(table_h1_q.columns.tolist())):
    variable = str(m_tickers[x])
    table_h1_q[(str(variable))] = table_h1_q[(str(variable))].pct_change(periods=1, fill_method='bfill') + 1
    table_h1_q[(str(variable))] = table_h1_q[(str(variable))].apply(lambda x: x**4)
    table_h1_q[(str(variable))] = table_h1_q[(str(variable))] - 1
    table_h1_q[(str(variable))] = table_h1_q[(str(variable))].multiply(100).round(3)



table_h2=table_h1.copy()
table_h2_q=table_h1_q.copy()

def adjust_values(val):
    if val > 6:
        return "f"
    if 5 < val <= 6:
        return "e"
    if 4 < val <= 5:
        return "d"
    if 3 < val <= 4:
        return "c"
    elif 2 < val <= 3:
        return "b"
    else:
        return "a"


# Create a new DataFrame by applying the rule
table_h3 = table_h2.applymap(adjust_values)
table_h3_q = table_h2_q.applymap(adjust_values)


df_categories =table_h3.copy()
df_weights= table_w.copy()
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
df_categories=df_categories.tail(120)
df_categories.index = pd.to_datetime(df_categories.index)
df_categories.index=df_categories.index.date
df_weights.index= pd.to_datetime(df_weights.index)
df_weights.index=df_weights.index.date
mask = df_weights.index.isin(df_categories.index)
df_weights = df_weights[mask]


print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())

df_aggregated_weights = pd.DataFrame(0,  index=df_categories.index,
                                     columns=['a', 'b', 'c', 'd', 'e', 'f'])

# Aggregate weights by category for each row
for index, row in df_categories.iterrows():
    for category in df_aggregated_weights.columns:
        # Find columns that match the current category
        matching_columns = row ==category
        # Sum the weights for these columns from df_weights
        aggregated_weight = df_weights.loc[index, matching_columns].sum()
        # Assign the aggregated weight to the corresponding cell in the result Dataframe
        df_aggregated_weights.at[index, category] = aggregated_weight


# Result
df_aggregated_weights.columns = ["below 2%",
                                 "between 2%-3%", 
                                 "between 3%-4%", 
                                 "between 4%-5%", 
                                 "between 5%-6%", 
                                 "above 6%"]

fig, ax = plt.subplots(figsize=(15, 7))
df1 = df_aggregated_weights.copy()
df1 = df1.tail(96)
# df1g.set_index('date')
df1.plot(kind='area', ax=ax, stacked=True, color=['green', 'blue', 'red', 'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("australia inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left")
plt.title(str("australia inflation Diffusion: green <2%, blue [2%:3%], red[3%:4%], black [4%:5%], purple [5%:6%], yellow>6%"), size=12)
plt.savefig('australia_diffusion_001.png', bbox_inches='tight', dpi=200)
plt.show()




fig, ax = plt.subplots(figsize=(15, 7))
df1 = df_aggregated_weights.copy()
df1 = df1.tail(16)
df1.plot(kind='area', ax=ax, stacked=True, color=['green', 'blue', 'red', 'black', 'purple', 'yellow'])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("Australia inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left", fontsize=16)
plt.title(str("au Diffusion: green <2%, blue [2%:3%], red [3%:4%], black [4%:5%], purple [5%:6%], yellow>6%"), size=12)
plt.savefig('australia_diffusion_002.png', bbox_inches='tight', dpi=200)
plt.show()



df_categories =table_h3_q.copy()
df_weights= table_w.copy()
print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())
df_categories=df_categories.tail(120)
df_categories.index = pd.to_datetime(df_categories.index)
df_categories.index=df_categories.index.date
df_weights.index= pd.to_datetime(df_weights.index)
df_weights.index=df_weights.index.date
mask = df_weights.index.isin(df_categories.index)
df_weights = df_weights[mask]


print(df_categories.index.min())
print(df_categories.index.max())
print(df_weights.index.min())
print(df_weights.index.max())

df_aggregated_weights = pd.DataFrame(0,  index=df_categories.index,
                                     columns=['a', 'b', 'c', 'd', 'e', 'f'])

# Aggregate weights by category for each row
for index, row in df_categories.iterrows():
    for category in df_aggregated_weights.columns:
        # Find columns that match the current category
        matching_columns = row ==category
        # Sum the weights for these columns from df_weights
        aggregated_weight = df_weights.loc[index, matching_columns].sum()
        # Assign the aggregated weight to the corresponding cell in the result Dataframe
        df_aggregated_weights.at[index, category] = aggregated_weight


# Result
df_aggregated_weights.columns = ["below 2%",
                                 "between 2%-3%", 
                                 "between 3%-4%", 
                                 "between 4%-5%", 
                                 "between 5%-6%", 
                                 "above 6%"]


fig,ax = plt.subplots(figsize=(15,7))
df1=df_aggregated_weights.copy()
df1=df1.tail(96)
#df1g.set_index('date')
df1.plot(kind="area", ax=ax, stacked=True,color=["green", "blue", "red", "black", "purple", "yellow"])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("Australia inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left")
plt.title(str("Australia inflation cpi q/q ann Diffusion: green <2%, blue [2%:3%], red[3%:4%], black[4%:5%], purple[5%:6%], yellow>6%"), size=12)
plt.savefig('australia_diffusion_003.png', bbox_inches='tight', dpi=200)
plt.show()

fig,ax = plt.subplots(figsize=(15,7))
df1=df_aggregated_weights.copy()
df1=df1.tail(16)
df1.plot(kind="area", ax=ax, stacked=True,color=["green", "blue", "red", "black", "purple", "yellow"])
plt.ylabel(str("Inflation Basket Weight"), size=20)
plt.xlabel(str("Australia inflation Diffusion"), size=12)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.legend(loc="lower left", fontsize=16)
plt.title(str("Australia inflation cpi q/q ann Diffusion: green <2%, blue [2%:3%], red [3%:4%], black[4%:5%], purple [5%:6%], yellow>6%"), size=12)
plt.savefig('australia_diffusion_004.png', bbox_inches='tight',dpi=200)
plt.show()

### cleaning  

import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()

print("Compelte")



### end
